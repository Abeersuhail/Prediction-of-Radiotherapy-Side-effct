# %% [markdown]
# <a href="https://colab.research.google.com/github/Abeersuhail/Prediction-of-Radiotherapy-Side-effct/blob/main/Arm_lymphedema_Feature_selection_7Sets_of_Features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using ML techniques to predict RT side effect as patients who affected by cancer and took RT after removing cancer part could be affercted by some RT side effect which can influence their quality of life such as arm_lymphoedema side effect. The data that had been collected contain clinical and genetic data

# %%
##### 'breast_Arm_Lymphoedema24m' ###########

# %% [markdown]
# #**1) Data collection**

# %% [markdown]
# The data is stores as csv file and previously had been taken from the hospitals of 9 regiens, and all of these pateints had breast cancer before and acure with RT afterward the operation.

# %% [markdown]
# ##importing some libraries in order to upload data

# %%
# importing Pandas and NumPy library
import pandas as pd
import numpy as np
from numpy import sqrt
import statsmodels.api as sm
import statsmodels.formula.api as smf

# for visualising and metrics
from sklearn.decomposition import PCA
from sklearn import metrics
# for color heatmap
from matplotlib import cm

# for error
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from numpy import sqrt, argmax

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# Step 1: Dynamically compute class weights
from collections import Counter
import numpy as np

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
import matplotlib.cm as cm

## This with pipeline of standarise scaling
from tqdm import tqdm

# %%
# for ML models
# For statistic Method
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

from scipy.stats import chi2_contingency

# for calculate geometric mean
from numpy import argmax
from numpy import interp

from tabulate import tabulate

#from sklearn import feature_selection
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import classification_report

# Importing ML models
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier as KNN
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import VotingClassifier
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# Import Keras for implementing autoencoders
import keras
from imblearn.over_sampling import SMOTE



from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier # Import HistGradientBoostingClassifier
from sklearn.model_selection import RepeatedStratifiedKFold # import RepeatedStratifiedKFold
from sklearn.ensemble import HistGradientBoostingClassifier

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold

import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import MinMaxScaler
from collections import Counter
import matplotlib.pyplot as plt
from tabulate import tabulate

# %% [markdown]
# ## uploading the data

# %%
# Read the data from original file (use relative paths)
data1 = pd.read_csv('/content/FinalRTmerged_data28.12.24.csv')
#data1 = pd.read_csv('/content/FinalRTmerged_data8.10.25.csv')
data2= pd.read_csv('/content/ArmlymphedemaSNPs.csv')

# %%
list(data1.columns)
# Out:
# ['subject_id',
#  'date',
#  'height_cm',
#  'weight_at_cancer_diagnosis_kg',
#  'age',
#  'bra_cup_size',
#  'band_size',
#  'smoker',
#  'smoking_duration_yrs',
#  'tobacco_products_per_day',
#  'smoking_time_since_quitting_yrs',
#  'tobacco_product',
#  'alcohol_intake',
#  'alcohol_previous_consumption',
#  'alcohol_current_consumption',
#  'menopausal_status',
#  'monopause_age_yrs',
#  'hormone_replacement_therapy',
#  'diabetes',
#  'diabetes_duration_yrs',
#  'history_of_heart_disease',
#  'history_of_heart_disease_duration_yrs',
#  'ra',
#  'ra_duration_yrs',
#  'systemic_lupus_erythematosus',
#  'systemic_lupus_erythematosus_duration_yrs',
#  'other_collagen_vascular_disease',
#  'other_collagen_vascular_disease_duration_yrs',
#  'hypertension',
#  'hypertension_duration_yrs',
#  'depression',
#  'depression_duration_yrs',
#  'antidiabetic',
#  'antidiabetic_duration_yrs',
#  'ace_inhibitor',
#  'ace_inhibitor_duration_yrs',
#  'other_antihypertensive_drug',
#  'other_antihypertensive_drug_duration_yrs',
#  'on_statin',
#  'on_statin_duration_yrs',
#  'other_lipid_lowering_drugs',
#  'other_lipid_lowering_drugs_duration_yrs',
#  'amiodarone',
#  'amiodarone_duration_yrs',
#  'analgesics',
#  'analgesics_duration_yrs',
#  'antidepressant',
#  'antidepressant_duration_yrs',
#  'breast_cancer_family_history_1st_degree',
#  'radiotherapy_toxicity_family_history',
#  'other_comorbidity',
#  'ethnicity',
#  'ethnicity_other',
#  'education_profession',
#  'secondary_school_selection',
#  'secondary_school_other',
#  'professional_school_type',
#  'education_profession_other',
#  'household_income',
#  'household_members',
#  'previous_malignancies',
#  'previous_malignancies_icd10',
#  'previous_malignancies_icd_o_3',
#  'previous_malignancies_therapy_surgery',
#  'previous_malignancies_therapy_hormonal_therapy',
#  'previous_malignancies_therapy_chemotherapy',
#  'previous_malignancies_therapy_radiotherapy',
#  'previous_malignancies_therapy_other_therapy',
#  'previous_malignancies_therapy_no_therapy',
#  'previous_malignancies_last_therapy_date',
#  'previous_malignancies_date',
#  'Sequence Num_x',
#  'Date',
#  'Visit_y',
#  'CRFversion_y',
#  'surgery',
#  'surgery_type',
#  'surgery_date',
#  'nodes_involved',
#  'nodes_examined',
#  'post_operative_haematoma',
#  'post_operative_oedema',
#  'post_operative_infection',
#  'infection_antibiotics',
#  'delayed_healing',
#  'tumour_side_of_primary',
#  'tumour_quadrant',
#  'tumour_quadrant_other',
#  'tumour_locality',
#  'tumour_histological_grade',
#  'tumour_histological_type',
#  'tumour_histological_type_other',
#  'tumour_size_mm',
#  't_stage',
#  'n_stage',
#  'm_stage',
#  'r_stage',
#  'neo_adj_uicc_t_stage',
#  'neo_adj_uicc_n_stage',
#  'neo_adj_uicc_m_stage',
#  'ki_67_status_pc',
#  'er_status',
#  'her2_status',
#  'pr_status',
#  'chemo_neo_adjuvant',
#  'chemo_neoadjuvant_anthracycline',
#  'chemo_neoadjuvant_anthracycline_date',
#  'chemo_neoadjuvant_anthracycline_cycles',
#  'chemo_neoadjuvant_anthracycline_drugs',
#  'chemo_neoadjuvant_nonanthracycline',
#  'chemo_neoadjuvant_nonanthracycline_date',
#  'chemo_neoadjuvant_nonanthracycline_cycles',
#  'chemo_neoadjuvant_nonanthracycline_drugs',
#  'chemo_adjuvant',
#  'chemo_adjuvant_anthracycline',
#  'chemo_adjuvant_anthracycline_date',
#  'chemo_adjuvant_anthracycline_cycles',
#  'chemo_adjuvant_anthracycline_drugs',
#  'chemo_adjuvant_nonanthracycline',
#  'chemo_adjuvant_nonanthracycline_date',
#  'chemo_adjuvant_nonanthracycline_cycles',
#  'chemo_adjuvant_nonanthracycline_drugs',
#  'sys_treatment',
#  'sys_tamoxifen',
#  'sys_tamoxifen_date',
#  'sys_aromatase',
#  'sys_aromatase_date',
#  'sys_antiher2',
#  'sys_tki',
#  'sys_tki_drug',
#  'sys_tki_date',
#  'sys_tki_cycles',
#  'sys_mab',
#  'sys_mab_drug',
#  'sys_mab_date',
#  'sys_mab_cycles',
#  'radio_breast_startdate',
#  'radio_breast_enddate',
#  'radio_interrupted',
#  'radio_interrupted_days',
#  'radio_interrupted_reason',
#  'radio_breast_dose_Gy',
#  'radio_photon_dose_MV',
#  'radio_photon_2nd_dose_MV',
#  'radio_breast_fractions',
#  'radio_breast_ct_volume_cm3',
#  'radio_breast_delineation',
#  'radio_breast_delineation_others',
#  'radio_breast_internal_mammary_volume_cm3',
#  'radio_skin_max_dose_Gy',
#  'radio_skin_delineation',
#  'radio_skin_delineation_others',
#  'radio_heart_mean_dose_Gy',
#  'radio_heart_delineation',
#  'radio_heart_delineation_others',
#  'radio_hot_spots_107',
#  'radio_hot_spots_dose_cm3',
#  'radio_hot_spots_area',
#  'radio_ipsilateral_lung_mean_Gy',
#  'radio_imrt',
#  'radio_type_imrt',
#  'radio_treatment_pos',
#  'radio_3d',
#  'radio_treated_breast',
#  'axillary_levels',
#  'radio_axillary_other',
#  'radio_supraclavicular_fossa',
#  'radio_boost',
#  'radio_boost_startdate',
#  'radio_boost_enddate',
#  'radio_boost_type',
#  'radio_elec_boost_field_x_cm',
#  'radio_elec_boost_field_y_cm',
#  'radio_elec_energy_MeV',
#  'radio_boost_diameter_cm',
#  'radio_photon_boost_volume_cm3',
#  'radio_photon_energy_MV or kV',
#  'radio_bolus',
#  'radio_boost_sequence',
#  'chemo_neoadjuvant_anthracycline_enddate',
#  'chemo_neoadjuvant_nonanthracycline_enddate',
#  'chemo_adjuvant_anthracycline_enddate',
#  'chemo_adjuvant_nonanthracycline_enddate',
#  'sys_tki_more',
#  'sys_tki2_date',
#  'sys_tki2_cycles',
#  'sys_tki2_drug',
#  'sys_mab_more',
#  'sys_mab2_date',
#  'sys_mab2_cycles',
#  'sys_mab2_drug',
#  'surgery_axilla_type',
#  'radio_breast_fractions_dose_per_fraction_Gy',
#  'radio_breast_fractions_per_week',
#  'radio_photon_2nd',
#  'radio_photon_2nd_fractions',
#  'radio_photon_2nd_dose_per_fraction_Gy',
#  'radio_photon_2nd_dose_fractions_per_week',
#  'radio_hot_spots_quadrant',
#  'radio_hot_spots_quadrant_other',
#  'radio_photon_boostdose_precise_Gy',
#  'radio_photon_boost_fractions',
#  'radio_photon_boost_fractions_per_week',
#  'radio_photon_boost_dose_per_fraction_Gy',
#  'radio_second_photon',
#  'radio_second_photon_energy_MV or kV',
#  'radio_second_photon_boost_volume_cm3',
#  'radio_second_photon_boostdose_precise_Gy',
#  'radio_second_photon_boost_fractions',
#  'radio_second_photon_boost_dose_per_fraction_Gy',
#  'radio_second_photon_boost_fractions_per_week',
#  'radio_elec_boost_dose_precise_Gy',
#  'radio_boost_fractions_per_week',
#  'radio_elec_boost_fractions',
#  'radio_elec_boost_dose_per_fraction_Gy',
#  'Site',
#  'Sequence Num_y',
#  'Visit_baseline',
#  'Sequence Num_baseline',
#  'Date_baseline',
#  'CRFversion_baseline',
#  'CRFstatus_baseline',
#  'breast_atrophy_baseline',
#  'breast_nipple_retraction_baseline',
#  'breast_nipple_retraction MV Indicator_baseline',
#  'breast_oedema_baseline',
#  'breast_skin_ulceration_baseline',
#  'breast_telangiectasia_tumour_bed_baseline',
#  'breast_telangiectasia_outside_tumour_bed_baseline',
#  'breast_skin_induration_tumour_bed_baseline',
#  'breast_skin_induration_outside_tumour_bed_baseline',
#  'breast_erythema_baseline',
#  'breast_arm_lymphodema_baseline',
#  'breast_skin_hyperpigmentation_baseline',
#  'breast_pneumontis_baseline',
#  'breast_pain_baseline',
#  'breast_pain_severity_baseline',
#  'breast_pain_medication_baseline',
#  'breast_pain_medication_name_baseline',
#  'breast_pain_medication_dose_and_freq_baseline',
#  'breast_swollen_arm_baseline',
#  'breast_swollen_arm_interferes_with_normal_activity_baseline',
#  'breast_left_arm_circumfrence_mm_baseline',
#  'breast_right_arm_circumfrence_mm_baseline',
#  'breast_arm_measuring_date_baseline',
#  'Site_baseline',
#  'Visit_postRT',
#  'Sequence Num_postRT',
#  'Date_postRT',
#  'CRFversion_postRT',
#  'CRFstatus_postRT',
#  'breast_atrophy_postRT',
#  'breast_nipple_retraction_postRT',
#  'breast_nipple_retraction MV Indicator_postRT',
#  'breast_oedema_postRT',
#  'breast_skin_ulceration_postRT',
#  'breast_telangiectasia_tumour_bed_postRT',
#  'breast_telangiectasia_outside_tumour_bed_postRT',
#  'breast_skin_induration_tumour_bed_postRT',
#  'breast_skin_induration_outside_tumour_bed_postRT',
#  'breast_erythema_postRT',
#  'breast_arm_lymphodema_postRT',
#  'breast_skin_hyperpigmentation_postRT',
#  'breast_pneumontis_postRT',
#  'breast_pain_postRT',
#  'breast_pain_severity_postRT',
#  'breast_pain_medication_postRT',
#  'breast_pain_medication_name_postRT',
#  'breast_pain_medication_dose_and_freq_postRT',
#  'breast_swollen_arm_postRT',
#  'breast_swollen_arm_interferes_with_normal_activity_postRT',
#  'breast_left_arm_circumfrence_mm_postRT',
#  'breast_right_arm_circumfrence_mm_postRT',
#  'breast_arm_measuring_date_postRT',
#  'Site_postRT',
#  'Visit_12m',
#  'Sequence Num_12m',
#  'Date_12m',
#  'CRFversion_12m',
#  'CRFstatus_12m',
#  'breast_atrophy_12m',
#  'breast_nipple_retraction_12m',
#  'breast_nipple_retraction MV Indicator_12m',
#  'breast_oedema_12m',
#  'breast_skin_ulceration_12m',
#  'breast_telangiectasia_tumour_bed_12m',
#  'breast_telangiectasia_outside_tumour_bed_12m',
#  'breast_skin_induration_tumour_bed_12m',
#  'breast_skin_induration_outside_tumour_bed_12m',
#  'breast_erythema_12m',
#  'breast_arm_lymphodema_12m',
#  'breast_skin_hyperpigmentation_12m',
#  'breast_pneumontis_12m',
#  'breast_pain_12m',
#  'breast_pain_severity_12m',
#  'breast_pain_medication_12m',
#  'breast_pain_medication_name_12m',
#  'breast_pain_medication_dose_and_freq_12m',
#  'breast_swollen_arm_12m',
#  'breast_swollen_arm_interferes_with_normal_activity_12m',
#  'breast_left_arm_circumfrence_mm_12m',
#  'breast_right_arm_circumfrence_mm_12m',
#  'breast_arm_measuring_date_12m',
#  'Site_12m',
#  'Visit_24m',
#  'Sequence Num_24m',
#  'Date_24m',
#  'CRFversion_24m',
#  'CRFstatus_24m',
#  'breast_atrophy_24m',
#  'breast_nipple_retraction_24m',
#  'breast_nipple_retraction MV Indicator_24m',
#  'breast_oedema_24m',
#  'breast_skin_ulceration_24m',
#  'breast_telangiectasia_tumour_bed_24m',
#  'breast_telangiectasia_outside_tumour_bed_24m',
#  'breast_skin_induration_tumour_bed_24m',
#  'breast_skin_induration_outside_tumour_bed_24m',
#  'breast_erythema_24m',
#  'breast_arm_lymphodema_24m',
#  'breast_skin_hyperpigmentation_24m',
#  'breast_pneumontis_24m',
#  'breast_pain_24m',
#  'breast_pain_severity_24m',
#  'breast_pain_medication_24m',
#  'breast_pain_medication_name_24m',
#  'breast_pain_medication_dose_and_freq_24m',
#  'breast_swollen_arm_24m',
#  'breast_swollen_arm_interferes_with_normal_activity_24m',
#  'breast_left_arm_circumfrence_mm_24m',
#  'breast_right_arm_circumfrence_mm_24m',
#  'breast_arm_measuring_date_24m',
#  'Site_24m',
#  'Visit_36m',
#  'Sequence Num_36m',
#  'Date_36m',
#  'CRFversion_36m',
#  'CRFstatus_36m',
#  'breast_atrophy_36m',
#  'breast_nipple_retraction_36m',
#  'breast_nipple_retraction MV Indicator_36m',
#  'breast_oedema_36m',
#  'breast_skin_ulceration_36m',
#  'breast_telangiectasia_tumour_bed_36m',
#  'breast_telangiectasia_outside_tumour_bed_36m',
#  'breast_skin_induration_tumour_bed_36m',
#  'breast_skin_induration_outside_tumour_bed_36m',
#  'breast_erythema_36m',
#  'breast_arm_lymphodema_36m',
#  'breast_skin_hyperpigmentation_36m',
#  'breast_pneumontis_36m',
#  'breast_pain_36m',
#  'breast_pain_severity_36m',
#  'breast_pain_medication_36m',
#  'breast_pain_medication_name_36m',
#  'breast_pain_medication_dose_and_freq_36m',
#  'breast_swollen_arm_36m',
#  'breast_swollen_arm_interferes_with_normal_activity_36m',
#  'breast_left_arm_circumfrence_mm_36m',
#  'breast_right_arm_circumfrence_mm_36m',
#  'breast_arm_measuring_date_36m',
#  'Site_36m',
#  'Visit_48m',
#  'Sequence Num_48m',
#  'Date_48m',
#  'CRFversion_48m',
#  'CRFstatus_48m',
#  'breast_atrophy_48m',
#  'breast_nipple_retraction_48m',
#  'breast_nipple_retraction MV Indicator_48m',
#  'breast_oedema_48m',
#  'breast_skin_ulceration_48m',
#  'breast_telangiectasia_tumour_bed_48m',
#  'breast_telangiectasia_outside_tumour_bed_48m',
#  'breast_skin_induration_tumour_bed_48m',
#  'breast_skin_induration_outside_tumour_bed_48m',
#  'breast_erythema_48m',
#  'breast_arm_lymphodema_48m',
#  'breast_skin_hyperpigmentation_48m',
#  'breast_pneumontis_48m',
#  'breast_pain_48m',
#  'breast_pain_severity_48m',
#  'breast_pain_medication_48m',
#  'breast_pain_medication_name_48m',
#  'breast_pain_medication_dose_and_freq_48m',
#  'breast_swollen_arm_48m',
#  'breast_swollen_arm_interferes_with_normal_activity_48m',
#  'breast_left_arm_circumfrence_mm_48m',
#  'breast_right_arm_circumfrence_mm_48m',
#  'breast_arm_measuring_date_48m',
#  'Site_48m',
#  'Visit_60m',
#  'Sequence Num_60m',
#  'Date_60m',
#  'CRFversion_60m',
#  'CRFstatus_60m',
#  'breast_atrophy_60m',
#  'breast_nipple_retraction_60m',
#  'breast_nipple_retraction MV Indicator_60m',
#  'breast_oedema_60m',
#  'breast_skin_ulceration_60m',
#  'breast_telangiectasia_tumour_bed_60m',
#  'breast_telangiectasia_outside_tumour_bed_60m',
#  'breast_skin_induration_tumour_bed_60m',
#  'breast_skin_induration_outside_tumour_bed_60m',
#  'breast_erythema_60m',
#  'breast_arm_lymphodema_60m',
#  'breast_skin_hyperpigmentation_60m',
#  'breast_pneumontis_60m',
#  'breast_pain_60m',
#  'breast_pain_severity_60m',
#  'breast_pain_medication_60m',
#  'breast_pain_medication_name_60m',
#  'breast_pain_medication_dose_and_freq_60m',
#  'breast_swollen_arm_60m',
#  'breast_swollen_arm_interferes_with_normal_activity_60m',
#  'breast_left_arm_circumfrence_mm_60m',
#  'breast_right_arm_circumfrence_mm_60m',
#  'breast_arm_measuring_date_60m',
#  'Site_60m',
#  'Visit_72m',
#  'Sequence Num_72m',
#  'Date_72m',
#  'CRFversion_72m',
#  'CRFstatus_72m',
#  'breast_atrophy_72m',
#  'breast_nipple_retraction_72m',
#  'breast_nipple_retraction MV Indicator_72m',
#  'breast_oedema_72m',
#  'breast_skin_ulceration_72m',
#  'breast_telangiectasia_tumour_bed_72m',
#  'breast_telangiectasia_outside_tumour_bed_72m',
#  'breast_skin_induration_tumour_bed_72m',
#  'breast_skin_induration_outside_tumour_bed_72m',
#  'breast_erythema_72m',
#  'breast_arm_lymphodema_72m',
#  'breast_skin_hyperpigmentation_72m',
#  'breast_pneumontis_72m',
#  'breast_pain_72m',
#  'breast_pain_severity_72m',
#  'breast_pain_medication_72m',
#  'breast_pain_medication_name_72m',
#  'breast_pain_medication_dose_and_freq_72m',
#  'breast_swollen_arm_72m',
#  'breast_swollen_arm_interferes_with_normal_activity_72m',
#  'breast_left_arm_circumfrence_mm_72m',
#  'breast_right_arm_circumfrence_mm_72m',
#  'breast_arm_measuring_date_72m',
#  'Site_72m',
#  'Visit_84m',
#  'Sequence Num_84m',
#  'Date_84m',
#  'CRFversion_84m',
#  'CRFstatus_84m',
#  'breast_atrophy_84m',
#  'breast_nipple_retraction_84m',
#  'breast_nipple_retraction MV Indicator_84m',
#  'breast_oedema_84m',
#  'breast_skin_ulceration_84m',
#  'breast_telangiectasia_tumour_bed_84m',
#  'breast_telangiectasia_outside_tumour_bed_84m',
#  'breast_skin_induration_tumour_bed_84m',
#  'breast_skin_induration_outside_tumour_bed_84m',
#  'breast_erythema_84m',
#  'breast_arm_lymphodema_84m',
#  'breast_skin_hyperpigmentation_84m',
#  'breast_pneumontis_84m',
#  'breast_pain_84m',
#  'breast_pain_severity_84m',
#  'breast_pain_medication_84m',
#  'breast_pain_medication_name_84m',
#  'breast_pain_medication_dose_and_freq_84m',
#  'breast_swollen_arm_84m',
#  'breast_swollen_arm_interferes_with_normal_activity_84m',
#  'breast_left_arm_circumfrence_mm_84m',
#  'breast_right_arm_circumfrence_mm_84m',
#  'breast_arm_measuring_date_84m',
#  'Site_84m',
#  'Visit_96m',
#  'Sequence Num_96m',
#  'Date_96m',
#  'CRFversion_96m',
#  'CRFstatus_96m',
#  'breast_atrophy_96m',
#  'breast_nipple_retraction_96m',
#  'breast_nipple_retraction MV Indicator_96m',
#  'breast_oedema_96m',
#  'breast_skin_ulceration_96m',
#  'breast_telangiectasia_tumour_bed_96m',
#  'breast_telangiectasia_outside_tumour_bed_96m',
#  'breast_skin_induration_tumour_bed_96m',
#  'breast_skin_induration_outside_tumour_bed_96m',
#  'breast_erythema_96m',
#  'breast_arm_lymphodema_96m',
#  'breast_skin_hyperpigmentation_96m',
#  'breast_pneumontis_96m',
#  'breast_pain_96m',
#  'breast_pain_severity_96m',
#  'breast_pain_medication_96m',
#  'breast_pain_medication_name_96m',
#  'breast_pain_medication_dose_and_freq_96m',
#  'breast_swollen_arm_96m',
#  'breast_swollen_arm_interferes_with_normal_activity_96m',
#  'breast_left_arm_circumfrence_mm_96m',
#  'breast_right_arm_circumfrence_mm_96m',
#  'breast_arm_measuring_date_96m',
#  'Site_96m']

# %%
# Select the dependent variable here
dependent1 = 'breast_arm_lymphodema_24m'

# %% [markdown]
# ## implementing functions

# %%
# to show all rows and columns in dataframe
def max_val(df):
  pd.set_option('display.max_columns', None)
  pd.set_option('display.max_rows', None)

# %%
from IPython.display import display, HTML

def bold(text):
  display(HTML(f"<p style='font-size:16pt;'>{text}</p>"))

# %%
# To chech the percenage of null value in each feature
def nullP(df):
  count_null= ((pd.isnull(df).sum()/len(df))*100).round()
  print(count_null.sort_values(ascending=False))
  count_null.to_csv('count_null_all.csv')

# %%
# calculate uniq data in X coloumn
def Cuniq(df, x):
  print(df[x].sort_values().value_counts())

# %%
# This finction is used to print the uniques values in each feature in the dataset
def uniq(data):
  for col in list(data):
    print(col, "Unique Values are:\n ", data[col].unique())
    print("===================================================================================")

# %%
# This function is used to Remove all features that contain X % Missing values

def X_per_removed(data1, dep, perc):

    min_count = int(((100 - perc) / 100) * data1.shape[0] + 1)

    cols_to_keep = [
        col for col in data1.columns
        if col == dep or data1[col].count() >= min_count
    ]

    feat_data = data1[cols_to_keep]

    print(feat_data.shape)
    print(list(feat_data.columns))

    return feat_data

# %%
def remove_duplicate(df):

  duplicate_cols = []
  cols = df.columns
  for i in range(len(cols)):
      for j in range(i + 1, len(cols)):

          col1 = df[cols[i]]
          col2 = df[cols[j]]

          # Compare ignoring NaNs
          same = ((col1 == col2) | col1.isna() | col2.isna()).all()

          if same:

              # Keep column with fewer NaNs
              if col1.isna().sum() <= col2.isna().sum():
                  duplicate_cols.append(cols[j])
              else:
                  duplicate_cols.append(cols[i])

  print("Columns to drop:")
  print(set(duplicate_cols))

  # Drop duplicates
  n_df = df.drop(columns=set(duplicate_cols))
  print(n_df.shape)
  return n_df

# %%
import numpy as np
import pandas as pd

def pairwisecorr(df, col=None, threshold=0.70):

    # Save ID/target column if provided
    keep_col = None
    if col is not None and col in df.columns:
        keep_col = df[[col]]
        X = df.drop(columns=[col])
    else:
        X = df.copy()

    # Numeric columns only for correlation
    numeric_features = X.select_dtypes(include=np.number).columns
    X_numeric = X[numeric_features]

    corr_matrix = X_numeric.corr().abs()

    mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
    tri_df = corr_matrix.mask(mask)

    to_drop = []
    correlated_pairs = []

    for c in tri_df.columns:
        for index, value in tri_df[c].items():

            if pd.notna(value) and value > threshold:

                correlated_pairs.append((c, index, value))

                # Drop lower-variance feature
                if X_numeric[c].var() > X_numeric[index].var():
                    to_drop.append(index)
                else:
                    to_drop.append(c)

    to_drop = list(set(to_drop))

    reduced_X = X.drop(columns=to_drop, errors='ignore')

    # Add col back to final dataset
    if keep_col is not None:
        reduced_X = pd.concat([keep_col, reduced_X], axis=1)

    print(f"Highly correlated feature pairs > {threshold}:")
    for c1, c2, corr in correlated_pairs:
        print(f"{c1} and {c2}: {corr:.2f}")

    print("\nRemoved features:")
    print(to_drop)

    print("\nFinal shape:", reduced_X.shape)

    return reduced_X

# %%
# VIF measures how much a feature (column) is correlated with the other features in your dataset. It's used to detect multicollinearity, which is when features are too similar to each other.
#A high VIF (e.g., > 5 or 10) means the feature is highly correlated with other features.
#This can make models like regression unstable or hard to interpret.
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(df, threshold):
    # Store Subject_Id separately
    subject_ids = df['Subject Id']

    # Drop Subject_Id and non-numeric, drop rows with missing values
    df_snp = df.drop(columns=['Subject Id'])
    df_snp = df_snp.select_dtypes(include=[float, int])
    df_snp = df_snp.dropna()

    # Keep matching Subject_Id values (after dropna)
    subject_ids = subject_ids.loc[df_snp.index]

    dropped = True
    while dropped:
        vif_data = pd.DataFrame()
        vif_data["SNP"] = df_snp.columns
        vif_data["VIF"] = [variance_inflation_factor(df_snp.values, i)
                           for i in range(df_snp.shape[1])]

        max_vif = vif_data["VIF"].max()
        if max_vif > threshold:
            drop_snp = vif_data.sort_values("VIF", ascending=False).iloc[0]["SNP"]
            df_snp = df_snp.drop(columns=[drop_snp])
            print(f"Dropped {drop_snp} with VIF {max_vif:.2f}")
        else:
            dropped = False

    # Add Subject_Id back safely
    df_snp['Subject Id'] = subject_ids.values

    return df_snp

# %%
# Using Cross Validation to Get the Best Value of k in KNN model
# The function below shows us the best value for K in KNN using cross validation

def BestK(X, y, k_values=range(1, 21)):
    scores = []
    scaler = StandardScaler()
    # Keep only the rows in y that match X's indices
    y = y.loc[y.index.intersection(X.index)]
    X = X.loc[y.index]  # Also make sure X only keeps matching rows

    X_scaled = scaler.fit_transform(X)

    for k in k_values:
        knn = KNeighborsClassifier(n_neighbors=k)
        cv_scores = cross_val_score(knn, X_scaled, y, cv=10, scoring="roc_auc")
        scores.append(np.mean(cv_scores))

    best_index = np.argmax(scores)
    best_k = k_values[best_index]
    print("Best K:", best_k)
    print("Best Score:", scores[best_index])
    return best_k

# %% [markdown]
# # **2) Data Cleaning visualization**

# %% [markdown]
# Which involves presenting data in a visual format such as charts and graphs to make it easier to understand and to identify patterns anf drends in the data.

# %% [markdown]
# ## Navigating & Labeling**

# %%
print(data1.shape + data2.shape)
# Out:
# (2067, 507, 5087, 31)

# %%
data1.head()
# Out:
#   subject_id        date  height_cm  weight_at_cancer_diagnosis_kg  age  \
# 0  RQ00001-2  24/06/2014      164.0                           78.0   62
# 1  RQ00002-0  08/07/2014      162.0                           57.0   47
# 2  RQ00004-9  17/06/2014      171.0                           82.0   56
# 3  RQ00005-4  06/08/2014      156.0                           76.0   63
# 4  RQ00006-5  02/07/2014      164.0                           59.0   68
#
#    bra_cup_size  band_size  smoker  smoking_duration_yrs  \
# 0           5.0        8.0     1.0                  30.0
# 1           3.0        3.0     3.0                  30.0
# 2           5.0        9.0     0.0                   NaN
# 3           5.0        8.0     0.0                   NaN
# 4           5.0        5.0     1.0                  17.0
#
#    tobacco_products_per_day  ...  breast_pain_severity_96m  \
# 0                      10.0  ...                       NaN
# 1                      15.0  ...                       NaN
# 2                       NaN  ...                       NaN
# 3                       NaN  ...                       NaN
# 4                       3.0  ...                       NaN
#
#   breast_pain_medication_96m  breast_pain_medication_name_96m  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
#
#    breast_pain_medication_dose_and_freq_96m  breast_swollen_arm_96m  \
# 0                                       NaN                     NaN
# 1                                       NaN                     NaN
# 2                                       NaN                     NaN
# 3                                       NaN                     NaN
# 4                                       NaN                     NaN
#
#    breast_swollen_arm_interferes_with_normal_activity_96m  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    breast_left_arm_circumfrence_mm_96m  breast_right_arm_circumfrence_mm_96m  \
# 0                                  NaN                                   NaN
# 1                                  NaN                                   NaN
# 2                                  NaN                                   NaN
# 3                                  NaN                                   NaN
# 4                                  NaN                                   NaN
#
#    breast_arm_measuring_date_96m  Site_96m
# 0                            NaN       NaN
# 1                            NaN       NaN
# 2                            NaN       NaN
# 3                            NaN       NaN
# 4                            NaN       NaN
#
# [5 rows x 507 columns]

# %%
print(list(data1.columns))
# Out:
# ['subject_id', 'date', 'height_cm', 'weight_at_cancer_diagnosis_kg', 'age', 'bra_cup_size', 'band_size', 'smoker', 'smoking_duration_yrs', 'tobacco_products_per_day', 'smoking_time_since_quitting_yrs', 'tobacco_product', 'alcohol_intake', 'alcohol_previous_consumption', 'alcohol_current_consumption', 'menopausal_status', 'monopause_age_yrs', 'hormone_replacement_therapy', 'diabetes', 'diabetes_duration_yrs', 'history_of_heart_disease', 'history_of_heart_disease_duration_yrs', 'ra', 'ra_duration_yrs', 'systemic_lupus_erythematosus', 'systemic_lupus_erythematosus_duration_yrs', 'other_collagen_vascular_disease', 'other_collagen_vascular_disease_duration_yrs', 'hypertension', 'hypertension_duration_yrs', 'depression', 'depression_duration_yrs', 'antidiabetic', 'antidiabetic_duration_yrs', 'ace_inhibitor', 'ace_inhibitor_duration_yrs', 'other_antihypertensive_drug', 'other_antihypertensive_drug_duration_yrs', 'on_statin', 'on_statin_duration_yrs', 'other_lipid_lowering_drugs', 'other_lipid_lowering_drugs_duration_yrs', 'amiodarone', 'amiodarone_duration_yrs', 'analgesics', 'analgesics_duration_yrs', 'antidepressant', 'antidepressant_duration_yrs', 'breast_cancer_family_history_1st_degree', 'radiotherapy_toxicity_family_history', 'other_comorbidity', 'ethnicity', 'ethnicity_other', 'education_profession', 'secondary_school_selection', 'secondary_school_other', 'professional_school_type', 'education_profession_other', 'household_income', 'household_members', 'previous_malignancies', 'previous_malignancies_icd10', 'previous_malignancies_icd_o_3', 'previous_malignancies_therapy_surgery', 'previous_malignancies_therapy_hormonal_therapy', 'previous_malignancies_therapy_chemotherapy', 'previous_malignancies_therapy_radiotherapy', 'previous_malignancies_therapy_other_therapy', 'previous_malignancies_therapy_no_therapy', 'previous_malignancies_last_therapy_date', 'previous_malignancies_date', 'Sequence Num_x', 'Date', 'Visit_y', 'CRFversion_y', 'surgery', 'surgery_type', 'surgery_date', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'post_operative_infection', 'infection_antibiotics', 'delayed_healing', 'tumour_side_of_primary', 'tumour_quadrant', 'tumour_quadrant_other', 'tumour_locality', 'tumour_histological_grade', 'tumour_histological_type', 'tumour_histological_type_other', 'tumour_size_mm', 't_stage', 'n_stage', 'm_stage', 'r_stage', 'neo_adj_uicc_t_stage', 'neo_adj_uicc_n_stage', 'neo_adj_uicc_m_stage', 'ki_67_status_pc', 'er_status', 'her2_status', 'pr_status', 'chemo_neo_adjuvant', 'chemo_neoadjuvant_anthracycline', 'chemo_neoadjuvant_anthracycline_date', 'chemo_neoadjuvant_anthracycline_cycles', 'chemo_neoadjuvant_anthracycline_drugs', 'chemo_neoadjuvant_nonanthracycline', 'chemo_neoadjuvant_nonanthracycline_date', 'chemo_neoadjuvant_nonanthracycline_cycles', 'chemo_neoadjuvant_nonanthracycline_drugs', 'chemo_adjuvant', 'chemo_adjuvant_anthracycline', 'chemo_adjuvant_anthracycline_date', 'chemo_adjuvant_anthracycline_cycles', 'chemo_adjuvant_anthracycline_drugs', 'chemo_adjuvant_nonanthracycline', 'chemo_adjuvant_nonanthracycline_date', 'chemo_adjuvant_nonanthracycline_cycles', 'chemo_adjuvant_nonanthracycline_drugs', 'sys_treatment', 'sys_tamoxifen', 'sys_tamoxifen_date', 'sys_aromatase', 'sys_aromatase_date', 'sys_antiher2', 'sys_tki', 'sys_tki_drug', 'sys_tki_date', 'sys_tki_cycles', 'sys_mab', 'sys_mab_drug', 'sys_mab_date', 'sys_mab_cycles', 'radio_breast_startdate', 'radio_breast_enddate', 'radio_interrupted', 'radio_interrupted_days', 'radio_interrupted_reason', 'radio_breast_dose_Gy', 'radio_photon_dose_MV', 'radio_photon_2nd_dose_MV', 'radio_breast_fractions', 'radio_breast_ct_volume_cm3', 'radio_breast_delineation', 'radio_breast_delineation_others', 'radio_breast_internal_mammary_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_skin_delineation', 'radio_skin_delineation_others', 'radio_heart_mean_dose_Gy', 'radio_heart_delineation', 'radio_heart_delineation_others', 'radio_hot_sp ...

# %%
data2.head()
# Out:
#   Subject_Id  rs2101893  rs77405610  rs67342194  rs2954011  rs1788750  \
# 0  RQ22067-0      1.564       0.192       0.999      1.174      0.877
# 1  RQ34365-4      1.802       0.000       0.000      1.991      2.000
# 2  RQ34616-4      1.769       0.000       0.066      0.198      0.000
# 3  RQ34720-1      1.672       0.773       0.993      1.307      0.995
# 4  RQ14799-8      1.984       0.000       0.000      0.009      0.992
#
#    rs10764743  rs4859721  rs7195405  rs6009631  ...  rs13132305  rs10945395  \
# 0       0.069      0.128      1.002      0.003  ...       1.988       1.987
# 1       0.966      1.972      1.028      0.007  ...       2.000       0.002
# 2       0.986      1.998      0.008      0.463  ...       2.000       1.000
# 3       1.856      1.103      1.971      0.845  ...       1.042       0.000
# 4       0.668      1.151      0.006      0.011  ...       2.000       1.972
#
#    rs461769  rs7179547  rs61912468  rs72857489  rs35410275  rs61912469  \
# 0     2.000      2.000         0.0       0.000       0.000         0.0
# 1     1.000      2.000         0.0       0.000       0.000         0.0
# 2     1.000      1.996         0.0       0.000       0.000         0.0
# 3     1.005      1.995         0.0       0.095       0.000         0.0
# 4     1.000      1.996         0.0       0.000       0.012         0.0
#
#    rs885170  rs11631993
# 0     0.996       2.000
# 1     0.000       2.000
# 2     0.012       1.998
# 3     0.015       2.000
# 4     0.004       2.000
#
# [5 rows x 31 columns]

# %%
# Show the length of data
len(data2)
# Out:
# 5087

# %%
# Rename the subject id column to the id in order to be mereged
data2.rename(columns = {'Subject_Id':'Subject Id'}, inplace = True)
data1.rename(columns = {'subject_id':'Subject Id'}, inplace = True)

# %%
data2 = data2[data2['Subject Id'].isin(data1['Subject Id'])]

# %%
data2.shape
# Out:
# (1912, 31)

# %%
data1.describe()
# Out:
#          height_cm  weight_at_cancer_diagnosis_kg          age  bra_cup_size  \
# count  2057.000000                    2053.000000  2067.000000   1997.000000
# mean    162.794361                      70.110083    58.248670      3.899349
# std       6.820660                      14.919588    11.048345      1.250805
# min     140.000000                      36.000000    23.000000      1.000000
# 25%     158.000000                      60.000000    50.000000      3.000000
# 50%     163.000000                      68.000000    58.000000      4.000000
# 75%     168.000000                      78.000000    66.000000      5.000000
# max     187.000000                     187.000000    90.000000     11.000000
#
#          band_size       smoker  smoking_duration_yrs  \
# count  1975.000000  2045.000000            823.000000
# mean      6.031899     0.749144             23.407047
# std       1.887004     1.048788             13.296206
# min       1.000000     0.000000              1.000000
# 25%       5.000000     0.000000             10.000000
# 50%       6.000000     0.000000             23.000000
# 75%       7.000000     1.000000             34.000000
# max      10.000000     3.000000             64.000000
#
#        tobacco_products_per_day  smoking_time_since_quitting_yrs  \
# count                815.000000                       483.000000
# mean                  12.597546                        19.571429
# std                    9.529728                        13.529305
# min                    0.000000                         0.000000
# 25%                    5.000000                         9.000000
# 50%                   10.000000                        18.000000
# 75%                   20.000000                        30.000000
# max                   80.000000                        65.000000
#
#        alcohol_intake  ...  breast_pneumontis_96m  breast_pain_96m  \
# count     2010.000000  ...              30.000000        30.000000
# mean         1.579602  ...               0.600000         4.300000
# std          1.455113  ...               2.283373         4.480994
# min          0.000000  ...               0.000000         0.000000
# 25%          0.000000  ...               0.000000         0.000000
# 50%          2.000000  ...               0.000000         1.000000
# 75%          3.000000  ...               0.000000         9.000000
# max          3.000000  ...               9.000000         9.000000
#
#        breast_pain_severity_96m  breast_pain_medication_96m  \
# count                       1.0                         1.0
# mean                        1.0                         0.0
# std                         NaN                         NaN
# min                         1.0                         0.0
# 25%                         1.0                         0.0
# 50%                         1.0                         0.0
# 75%                         1.0                         0.0
# max                         1.0                         0.0
#
#        breast_pain_medication_name_96m  \
# count                              0.0
# mean                               NaN
# std                                NaN
# min                                NaN
# 25%                                NaN
# 50%                                NaN
# 75%                                NaN
# max                                NaN
#
#        breast_pain_medication_dose_and_freq_96m  breast_swollen_arm_96m  \
# count                                       0.0               30.000000
# mean                                        NaN                7.766667
# std                                         NaN                3.103761
# min                                         NaN                0.000000
# 25%                                         NaN                9.000000
# 50%                                         NaN                9.000000
# 75%                                         NaN                9.000000
# max                                         NaN                9.000000
#
#        breast_swollen_arm_interferes_with_normal_activity_96m  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        breast_left_arm_circumfrence_mm_96m  \
# count                            30.000000
# mean                            302.333333
# std                              38.523019
# min                             240.000000
# 25%                             276.250000
# 50%                             295.000000
# 75%                             330.000000
# max                             385.000000
#
#        breast_right_arm_circumfrence_mm_96m
# count                             30.000000
# mean                             299.833333
# std                               34.826747
# min                              240.000000
# 25%                              276.250000
# 50%                              292.500000
# 75%                              320.000000
# max                              375.000000
#
# [8 rows x 373 columns]

# %%
data2.describe()
# Out:
#          rs2101893   rs77405610   rs67342194    rs2954011    rs1788750  \
# count  1912.000000  1912.000000  1912.000000  1912.000000  1912.000000
# mean      1.779041     0.110039     0.493405     1.112940     1.049048
# std       0.250131     0.226129     0.596734     0.593418     0.678163
# min       0.251000     0.000000     0.000000     0.000000     0.000000
# 25%       1.705750     0.000000     0.000000     0.812250     0.850000
# 50%       1.871000     0.001000     0.028000     1.076000     0.996000
# 75%       1.954000     0.094250     0.995000     1.495000     1.835250
# max       2.000000     1.792000     2.000000     2.000000     2.000000
#
#         rs10764743    rs4859721    rs7195405    rs6009631    rs2954007  ...  \
# count  1912.000000  1912.000000  1912.000000  1912.000000  1912.000000  ...
# mean      0.985759     1.731134     0.680379     0.144159     0.776401  ...
# std       0.613357     0.431270     0.640959     0.299560     0.573873  ...
# min       0.000000     0.029000     0.000000     0.000000     0.000000  ...
# 25%       0.516500     1.282500     0.013000     0.000000     0.160750  ...
# 50%       0.997000     1.979000     0.913500     0.005000     0.829000  ...
# 75%       1.359250     1.994000     1.012000     0.071250     0.982000  ...
# max       2.000000     2.000000     2.000000     1.981000     1.989000  ...
#
#         rs13132305   rs10945395     rs461769    rs7179547   rs61912468  \
# count  1912.000000  1912.000000  1912.000000  1912.000000  1912.000000
# mean      1.881428     0.398370     1.302837     1.596113     0.184874
# std       0.319286     0.548836     0.656008     0.567571     0.370002
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.992000     0.000000     1.000000     1.003000     0.000000
# 50%       2.000000     0.002000     1.060500     1.997000     0.000000
# 75%       2.000000     0.999000     1.999000     2.000000     0.107500
# max       2.000000     2.000000     2.000000     2.000000     2.000000
#
#         rs72857489   rs35410275   rs61912469     rs885170   rs11631993
# count  1912.000000  1912.000000  1912.000000  1912.000000  1912.000000
# mean      0.131022     0.278590     0.100631     0.401267     1.597183
# std       0.333938     0.462316     0.287914     0.535351     0.568476
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     1.002000
# 50%       0.000000     0.003000     0.000000     0.023000     1.999000
# 75%       0.000250     0.739500     0.002000     0.942000     2.000000
# max       1.995000     1.998000     2.000000     2.000000     2.000000
#
# [8 rows x 30 columns]

# %%
data1.columns = data1.columns.str.strip()  # Removes leading/trailing spaces

# %%
print(data1[dependent1].isna().sum()) # How many values missing in this varible
print(len(data1))  # Total rows
# Out:
# 376
# 2067

# %%
print(data1[dependent1].dtype)
# Out:
# float64

# %%
# Show the unique value of specific coloumn
data1[dependent1].unique()
# Out:
# array([ 0., nan,  1.,  2.])

# %% [markdown]
# ## Data preprocessing
# such as Data formatting, Data cleaning, Data anonymization and Data sampling.

# %%
# Manipulate unclear values
data1 = data1.replace('?', np.nan)  # replace ? with nan
data1 = data1.replace('x', np.nan)  # replace ? with nan
data1 = data1.replace('0.0%', 0)  # replace ? with nan
data1 = data1.replace('0', 0)  # replace 0 char with num
data1 = data1.replace('1', 1)  # replace 1 char with num
data1 = data1.replace('2', 2)  # replace 2 char with num
data1 = data1.replace('3', 3)  # replace 3 char with num
data1 = data1.replace('^\s+', np.nan, regex=True)  # replace empty spaces with nan value

# %%
# Handling some missing values
data1["smoker"].fillna(0, inplace=True) # notice from data sheet that null values in smokers have value 0 in smoking
data1["alcohol_intake"].fillna(0, inplace=True) # notice from data sheet that non alcohol drinker dont have alcoholintaker

# %%
nullP(data1)
# Out:
# breast_nipple_retraction MV Indicator_96m                 100.0
# CRFstatus_96m                                             100.0
# breast_swollen_arm_interferes_with_normal_activity_96m    100.0
# breast_swollen_arm_interferes_with_normal_activity_84m    100.0
# breast_pain_medication_dose_and_freq_84m                  100.0
#                                                           ...
# ace_inhibitor                                               0.0
# age                                                         0.0
# height_cm                                                   0.0
# date                                                        0.0
# Subject Id                                                  0.0
# Length: 507, dtype: float64

# %%
data1.shape
# Out:
# (2067, 507)

# %%
#Remove all features that contain 50% or more null
n_data1= X_per_removed(data1,dependent1, 50)
# Out:
# (2067, 182)
# ['Subject Id', 'date', 'height_cm', 'weight_at_cancer_diagnosis_kg', 'age', 'bra_cup_size', 'band_size', 'smoker', 'alcohol_intake', 'alcohol_current_consumption', 'menopausal_status', 'monopause_age_yrs', 'hormone_replacement_therapy', 'diabetes', 'history_of_heart_disease', 'ra', 'systemic_lupus_erythematosus', 'other_collagen_vascular_disease', 'hypertension', 'depression', 'antidiabetic', 'ace_inhibitor', 'other_antihypertensive_drug', 'on_statin', 'other_lipid_lowering_drugs', 'amiodarone', 'analgesics', 'antidepressant', 'breast_cancer_family_history_1st_degree', 'radiotherapy_toxicity_family_history', 'ethnicity', 'education_profession', 'household_members', 'Sequence Num_x', 'Date', 'Visit_y', 'surgery', 'surgery_type', 'surgery_date', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'post_operative_infection', 'delayed_healing', 'tumour_side_of_primary', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'tumour_histological_type', 'tumour_size_mm', 't_stage', 'n_stage', 'm_stage', 'r_stage', 'ki_67_status_pc', 'er_status', 'her2_status', 'pr_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'sys_treatment', 'sys_tamoxifen', 'sys_aromatase', 'sys_antiher2', 'radio_breast_startdate', 'radio_breast_enddate', 'radio_interrupted', 'radio_breast_dose_Gy', 'radio_photon_dose_MV', 'radio_breast_fractions', 'radio_breast_ct_volume_cm3', 'radio_breast_delineation', 'radio_breast_internal_mammary_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_skin_delineation', 'radio_heart_mean_dose_Gy', 'radio_heart_delineation', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'radio_imrt', 'radio_treatment_pos', 'radio_3d', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_boost', 'radio_boost_startdate', 'radio_boost_enddate', 'radio_boost_type', 'radio_bolus', 'radio_boost_sequence', 'surgery_axilla_type', 'radio_breast_fractions_dose_per_fraction_Gy', 'radio_breast_fractions_per_week', 'radio_photon_2nd', 'radio_photon_boostdose_precise_Gy', 'radio_photon_boost_fractions', 'radio_photon_boost_fractions_per_week', 'radio_photon_boost_dose_per_fraction_Gy', 'Site', 'Sequence Num_y', 'Visit_baseline', 'Sequence Num_baseline', 'CRFversion_baseline', 'breast_atrophy_baseline', 'breast_nipple_retraction_baseline', 'breast_oedema_baseline', 'breast_skin_ulceration_baseline', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_skin_induration_tumour_bed_baseline', 'breast_skin_induration_outside_tumour_bed_baseline', 'breast_erythema_baseline', 'breast_arm_lymphodema_baseline', 'breast_skin_hyperpigmentation_baseline', 'breast_pneumontis_baseline', 'breast_pain_baseline', 'breast_swollen_arm_baseline', 'breast_left_arm_circumfrence_mm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'Site_baseline', 'Visit_postRT', 'Sequence Num_postRT', 'CRFversion_postRT', 'breast_atrophy_postRT', 'breast_nipple_retraction_postRT', 'breast_oedema_postRT', 'breast_skin_ulceration_postRT', 'breast_telangiectasia_tumour_bed_postRT', 'breast_telangiectasia_outside_tumour_bed_postRT', 'breast_skin_induration_tumour_bed_postRT', 'breast_skin_induration_outside_tumour_bed_postRT', 'breast_erythema_postRT', 'breast_arm_lymphodema_postRT', 'breast_skin_hyperpigmentation_postRT', 'breast_pneumontis_postRT', 'breast_pain_postRT', 'breast_swollen_arm_postRT', 'breast_left_arm_circumfrence_mm_postRT', 'breast_right_arm_circumfrence_mm_postRT', 'Site_postRT', 'Visit_12m', 'Sequence Num_12m', 'CRFversion_12m', 'breast_atrophy_12m', 'breast_nipple_retraction_12m', 'breast_oedema_12m', 'breast_skin_ulceration_12m', 'breast_telangiectasia_tumour_bed_12m', 'breast_telangiectasia_outside_tumour_bed_12m', 'breast_skin_induration_tumour_bed_12m', 'breast_skin_induration_outside_tumour_bed_12m', 'breast_erythema_12m', 'breast_arm_lymphodema_12m', 'breast_skin_hyperpigmentation_12m', 'breast_pneumontis_12m', 'breast_pain_12m', 'brea ...

# %%
n_data1= remove_duplicate(n_data1)
# Out:
# Columns to drop:
# {'Visit_postRT', 'CRFversion_12m', 'surgery', 'Site_24m', 'Sequence Num_baseline', 'CRFversion_24m', 'CRFversion_postRT', 'Site_postRT', 'Sequence Num_postRT', 'Site_12m', 'Site_baseline'}
# (2067, 171)

# %% [markdown]
# **Correct datatypes in dataframe**

# %%
n_data1.dtypes.to_csv('data1_dtypes.csv')

# %%
#uniq(n_data1)

# %%
# 4. ID columns
n_data1['Subject Id'] = n_data1['Subject Id'].astype('string')


# 5. Date columns
date_cols = [col for col in n_data1.columns if 'date' in col.lower()]

for col in date_cols:
    n_data1[col] = pd.to_datetime(n_data1[col], errors='coerce')

# %%
# 6. Keep real continuous numeric columns
continuous_cols = [
    'height_cm',
    'weight_at_cancer_diagnosis_kg',
    'age',
    'monopause_age_yrs',
    'nodes_involved',
    'nodes_examined',
    'tumour_size_mm',
    'ki_67_status_pc',
    'radio_breast_dose_Gy',
    'radio_photon_dose_MV',
    'radio_breast_fractions',
    'radio_breast_ct_volume_cm3',
    'radio_breast_internal_mammary_volume_cm3',
    'radio_skin_max_dose_Gy',
    'radio_heart_mean_dose_Gy',
    'radio_ipsilateral_lung_mean_Gy',
    'radio_breast_fractions_dose_per_fraction_Gy',
    'radio_breast_fractions_per_week',
    'radio_photon_boostdose_precise_Gy',
    'radio_photon_boost_fractions',
    'radio_photon_boost_fractions_per_week',
    'radio_photon_boost_dose_per_fraction_Gy',
    'breast_left_arm_circumfrence_mm_baseline',
    'breast_right_arm_circumfrence_mm_baseline',
    'breast_left_arm_circumfrence_mm_postRT',
    'breast_right_arm_circumfrence_mm_postRT',
    'breast_left_arm_circumfrence_mm_12m',
    'breast_right_arm_circumfrence_mm_12m',
    'breast_left_arm_circumfrence_mm_24m',
    'breast_right_arm_circumfrence_mm_24m'
]

continuous_cols = [col for col in continuous_cols if col in n_data1.columns]

for col in continuous_cols:
    n_data1[col] = pd.to_numeric(n_data1[col], errors='coerce')

# %%
# 7. Everything else with low unique values becomes category
exclude_cols = ['Subject Id'] + date_cols + continuous_cols

cat_cols = [col for col in n_data1.columns if col not in exclude_cols]

for col in cat_cols:
    n_data1[col] = n_data1[col].astype('category')


# 8. Check final result
print(n_data1.dtypes)
# Out:
# Subject Id                              string[python]
# date                                    datetime64[ns]
# height_cm                                      float64
# weight_at_cancer_diagnosis_kg                  float64
# age                                              int64
#                                              ...
# breast_pneumontis_24m                         category
# breast_pain_24m                               category
# breast_swollen_arm_24m                        category
# breast_left_arm_circumfrence_mm_24m            float64
# breast_right_arm_circumfrence_mm_24m           float64
# Length: 171, dtype: object

# %%
# 8. Check final result
n_data1.dtypes.to_csv('data1_dtypes_clean2.csv')

# %%
# Remove Columns With Only One Unique Non-NaN Value
constant_cols = []

for col in n_data1.columns:

    unique_non_nan = n_data1[col].dropna().nunique()

    if unique_non_nan <= 1:
        constant_cols.append(col)

print("Constant columns:")
print(constant_cols)

# Drop them
n_data1 = n_data1.drop(columns=constant_cols)
n_data1.shape
# Out:
# Constant columns:
# ['Sequence Num_x', 'Visit_y', 'Sequence Num_y', 'Visit_baseline', 'CRFversion_baseline', 'Visit_12m', 'Sequence Num_12m', 'Visit_24m', 'Sequence Num_24m']
# (2067, 162)

# %%
# same result as above
#df_clean = df.loc[:, df.nunique(dropna=True) > 1]

# %%
print(list(n_data1.columns))
# Out:
# ['Subject Id', 'date', 'height_cm', 'weight_at_cancer_diagnosis_kg', 'age', 'bra_cup_size', 'band_size', 'smoker', 'alcohol_intake', 'alcohol_current_consumption', 'menopausal_status', 'monopause_age_yrs', 'hormone_replacement_therapy', 'diabetes', 'history_of_heart_disease', 'ra', 'systemic_lupus_erythematosus', 'other_collagen_vascular_disease', 'hypertension', 'depression', 'antidiabetic', 'ace_inhibitor', 'other_antihypertensive_drug', 'on_statin', 'other_lipid_lowering_drugs', 'amiodarone', 'analgesics', 'antidepressant', 'breast_cancer_family_history_1st_degree', 'radiotherapy_toxicity_family_history', 'ethnicity', 'education_profession', 'household_members', 'Date', 'surgery_type', 'surgery_date', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'post_operative_infection', 'delayed_healing', 'tumour_side_of_primary', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'tumour_histological_type', 'tumour_size_mm', 't_stage', 'n_stage', 'm_stage', 'r_stage', 'ki_67_status_pc', 'er_status', 'her2_status', 'pr_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'sys_treatment', 'sys_tamoxifen', 'sys_aromatase', 'sys_antiher2', 'radio_breast_startdate', 'radio_breast_enddate', 'radio_interrupted', 'radio_breast_dose_Gy', 'radio_photon_dose_MV', 'radio_breast_fractions', 'radio_breast_ct_volume_cm3', 'radio_breast_delineation', 'radio_breast_internal_mammary_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_skin_delineation', 'radio_heart_mean_dose_Gy', 'radio_heart_delineation', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'radio_imrt', 'radio_treatment_pos', 'radio_3d', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_boost', 'radio_boost_startdate', 'radio_boost_enddate', 'radio_boost_type', 'radio_bolus', 'radio_boost_sequence', 'surgery_axilla_type', 'radio_breast_fractions_dose_per_fraction_Gy', 'radio_breast_fractions_per_week', 'radio_photon_2nd', 'radio_photon_boostdose_precise_Gy', 'radio_photon_boost_fractions', 'radio_photon_boost_fractions_per_week', 'radio_photon_boost_dose_per_fraction_Gy', 'Site', 'breast_atrophy_baseline', 'breast_nipple_retraction_baseline', 'breast_oedema_baseline', 'breast_skin_ulceration_baseline', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_skin_induration_tumour_bed_baseline', 'breast_skin_induration_outside_tumour_bed_baseline', 'breast_erythema_baseline', 'breast_arm_lymphodema_baseline', 'breast_skin_hyperpigmentation_baseline', 'breast_pneumontis_baseline', 'breast_pain_baseline', 'breast_swollen_arm_baseline', 'breast_left_arm_circumfrence_mm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'breast_atrophy_postRT', 'breast_nipple_retraction_postRT', 'breast_oedema_postRT', 'breast_skin_ulceration_postRT', 'breast_telangiectasia_tumour_bed_postRT', 'breast_telangiectasia_outside_tumour_bed_postRT', 'breast_skin_induration_tumour_bed_postRT', 'breast_skin_induration_outside_tumour_bed_postRT', 'breast_erythema_postRT', 'breast_arm_lymphodema_postRT', 'breast_skin_hyperpigmentation_postRT', 'breast_pneumontis_postRT', 'breast_pain_postRT', 'breast_swollen_arm_postRT', 'breast_left_arm_circumfrence_mm_postRT', 'breast_right_arm_circumfrence_mm_postRT', 'breast_atrophy_12m', 'breast_nipple_retraction_12m', 'breast_oedema_12m', 'breast_skin_ulceration_12m', 'breast_telangiectasia_tumour_bed_12m', 'breast_telangiectasia_outside_tumour_bed_12m', 'breast_skin_induration_tumour_bed_12m', 'breast_skin_induration_outside_tumour_bed_12m', 'breast_erythema_12m', 'breast_arm_lymphodema_12m', 'breast_skin_hyperpigmentation_12m', 'breast_pneumontis_12m', 'breast_pain_12m', 'breast_swollen_arm_12m', 'breast_left_arm_circumfrence_mm_12m', 'breast_right_arm_circumfrence_mm_12m', 'breast_atrophy_24m', 'breast_nipple_retraction_24m', 'breast_oedema_24m', 'breast_skin_ulceration_24m', 'breast_telangiectasia_tumour_bed_24m', 'breast_telangiectasia ...

# %%
# no need to add it as it will be removed with pairwise correlation method below
#df['bmi'] = (df['weight_at_cancer_diagnosis_kg'] / df['height_cm'].div(1000).pow(2)).div(100)

# %%
# remove features with any post RT data
n_data11= n_data1[['Subject Id', 'date', 'height_cm', 'weight_at_cancer_diagnosis_kg', 'age', 'bra_cup_size', 'band_size', 'smoker', 'alcohol_intake', 'alcohol_current_consumption', 'menopausal_status', 'monopause_age_yrs', 'hormone_replacement_therapy', 'diabetes', 'history_of_heart_disease', 'ra', 'systemic_lupus_erythematosus', 'other_collagen_vascular_disease', 'hypertension', 'depression', 'antidiabetic', 'ace_inhibitor', 'other_antihypertensive_drug', 'on_statin', 'other_lipid_lowering_drugs', 'amiodarone', 'analgesics', 'antidepressant', 'breast_cancer_family_history_1st_degree', 'radiotherapy_toxicity_family_history', 'ethnicity', 'education_profession', 'household_members', 'Date', 'surgery_type', 'surgery_date', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'post_operative_infection', 'delayed_healing', 'tumour_side_of_primary', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'tumour_histological_type', 'tumour_size_mm', 't_stage', 'n_stage', 'm_stage', 'r_stage', 'ki_67_status_pc', 'er_status', 'her2_status', 'pr_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'sys_treatment', 'sys_tamoxifen', 'sys_aromatase', 'sys_antiher2', 'radio_breast_startdate', 'radio_breast_enddate', 'radio_interrupted', 'radio_breast_dose_Gy', 'radio_photon_dose_MV', 'radio_breast_fractions', 'radio_breast_ct_volume_cm3', 'radio_breast_delineation', 'radio_breast_internal_mammary_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_skin_delineation', 'radio_heart_mean_dose_Gy', 'radio_heart_delineation', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'radio_imrt', 'radio_treatment_pos', 'radio_3d', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_boost', 'radio_boost_startdate', 'radio_boost_enddate', 'radio_boost_type', 'radio_bolus', 'radio_boost_sequence', 'surgery_axilla_type', 'radio_breast_fractions_dose_per_fraction_Gy', 'radio_breast_fractions_per_week', 'radio_photon_2nd', 'radio_photon_boostdose_precise_Gy', 'radio_photon_boost_fractions', 'radio_photon_boost_fractions_per_week', 'radio_photon_boost_dose_per_fraction_Gy', 'Site', 'breast_atrophy_baseline', 'breast_nipple_retraction_baseline', 'breast_oedema_baseline', 'breast_skin_ulceration_baseline', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_skin_induration_tumour_bed_baseline', 'breast_skin_induration_outside_tumour_bed_baseline', 'breast_erythema_baseline', 'breast_arm_lymphodema_baseline', 'breast_skin_hyperpigmentation_baseline', 'breast_pneumontis_baseline', 'breast_pain_baseline', 'breast_swollen_arm_baseline', 'breast_left_arm_circumfrence_mm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'breast_arm_lymphodema_24m']]

# %%
n_data11= pairwisecorr(n_data11, dependent1, threshold=0.7)
# Out:
# Highly correlated feature pairs > 0.7:
# weight_at_cancer_diagnosis_kg and radio_breast_ct_volume_cm3: 0.73
# weight_at_cancer_diagnosis_kg and breast_left_arm_circumfrence_mm_baseline: 0.81
# weight_at_cancer_diagnosis_kg and breast_right_arm_circumfrence_mm_baseline: 0.82
# radio_breast_dose_Gy and radio_breast_fractions: 0.98
# radio_breast_dose_Gy and radio_skin_max_dose_Gy: 0.76
# radio_breast_dose_Gy and radio_breast_fractions_dose_per_fraction_Gy: 0.84
# radio_breast_fractions and radio_skin_max_dose_Gy: 0.74
# radio_breast_fractions and radio_breast_fractions_dose_per_fraction_Gy: 0.82
# radio_photon_boost_fractions_per_week and radio_photon_boost_dose_per_fraction_Gy: 0.87
# breast_left_arm_circumfrence_mm_baseline and breast_right_arm_circumfrence_mm_baseline: 0.97
#
# Removed features:
# ['radio_breast_fractions', 'radio_photon_boost_fractions_per_week', 'weight_at_cancer_diagnosis_kg', 'radio_breast_dose_Gy', 'radio_breast_fractions_dose_per_fraction_Gy', 'breast_left_arm_circumfrence_mm_baseline']
#
# Final shape: (2067, 109)

# %%
print(list(n_data11.columns))
# Out:
# ['breast_arm_lymphodema_24m', 'Subject Id', 'date', 'height_cm', 'age', 'bra_cup_size', 'band_size', 'smoker', 'alcohol_intake', 'alcohol_current_consumption', 'menopausal_status', 'monopause_age_yrs', 'hormone_replacement_therapy', 'diabetes', 'history_of_heart_disease', 'ra', 'systemic_lupus_erythematosus', 'other_collagen_vascular_disease', 'hypertension', 'depression', 'antidiabetic', 'ace_inhibitor', 'other_antihypertensive_drug', 'on_statin', 'other_lipid_lowering_drugs', 'amiodarone', 'analgesics', 'antidepressant', 'breast_cancer_family_history_1st_degree', 'radiotherapy_toxicity_family_history', 'ethnicity', 'education_profession', 'household_members', 'Date', 'surgery_type', 'surgery_date', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'post_operative_infection', 'delayed_healing', 'tumour_side_of_primary', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'tumour_histological_type', 'tumour_size_mm', 't_stage', 'n_stage', 'm_stage', 'r_stage', 'ki_67_status_pc', 'er_status', 'her2_status', 'pr_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'sys_treatment', 'sys_tamoxifen', 'sys_aromatase', 'sys_antiher2', 'radio_breast_startdate', 'radio_breast_enddate', 'radio_interrupted', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_breast_delineation', 'radio_breast_internal_mammary_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_skin_delineation', 'radio_heart_mean_dose_Gy', 'radio_heart_delineation', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'radio_imrt', 'radio_treatment_pos', 'radio_3d', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_boost', 'radio_boost_startdate', 'radio_boost_enddate', 'radio_boost_type', 'radio_bolus', 'radio_boost_sequence', 'surgery_axilla_type', 'radio_breast_fractions_per_week', 'radio_photon_2nd', 'radio_photon_boostdose_precise_Gy', 'radio_photon_boost_fractions', 'radio_photon_boost_dose_per_fraction_Gy', 'Site', 'breast_atrophy_baseline', 'breast_nipple_retraction_baseline', 'breast_oedema_baseline', 'breast_skin_ulceration_baseline', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_skin_induration_tumour_bed_baseline', 'breast_skin_induration_outside_tumour_bed_baseline', 'breast_erythema_baseline', 'breast_arm_lymphodema_baseline', 'breast_skin_hyperpigmentation_baseline', 'breast_pneumontis_baseline', 'breast_pain_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline']

# %%
print(list(data2.columns))
# Out:
# ['Subject Id', 'rs2101893', 'rs77405610', 'rs67342194', 'rs2954011', 'rs1788750', 'rs10764743', 'rs4859721', 'rs7195405', 'rs6009631', 'rs2954007', 'rs200456488', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs13132305', 'rs10945395', 'rs461769', 'rs7179547', 'rs61912468', 'rs72857489', 'rs35410275', 'rs61912469', 'rs885170', 'rs11631993']

# %%
data2.shape
# Out:
# (1912, 31)

# %%
data2 = calculate_vif(data2, 5)
# Out:
# Dropped rs7179547 with VIF 24982.99
# Dropped rs11631993 with VIF 100.95
# Dropped rs2101893 with VIF 33.66
# Dropped rs13132305 with VIF 23.93
# Dropped rs2954011 with VIF 23.18
# Dropped rs4859721 with VIF 12.01
# Dropped rs200456488 with VIF 7.88

# %%
data2.shape
# Out:
# (1912, 24)

# %%
data2= pairwisecorr(data2, dependent1, threshold=0.7)
# Out:
# Highly correlated feature pairs > 0.7:
# rs61912468 and rs61912469: 0.80
#
# Removed features:
# ['rs61912469']
#
# Final shape: (1912, 23)

# %%
data2.head()
# Out:
#    rs77405610  rs67342194  rs1788750  rs10764743  rs7195405  rs6009631  \
# 0       0.192       0.999      0.877       0.069      1.002      0.003
# 1       0.000       0.000      2.000       0.966      1.028      0.007
# 2       0.000       0.066      0.000       0.986      0.008      0.463
# 3       0.773       0.993      0.995       1.856      1.971      0.845
# 4       0.000       0.000      0.992       0.668      0.006      0.011
#
#    rs2954007  rs57288348  rs35035095  rs72977387  ...  rs3748569  rs79223472  \
# 0      0.730       0.000       0.005       0.093  ...      1.814       0.000
# 1      1.809       0.002       0.982       0.150  ...      1.003       0.000
# 2      0.005       0.011       0.947       0.010  ...      1.968       0.000
# 3      0.937       0.006       0.028       0.034  ...      0.113       0.002
# 4      0.002       0.003       1.968       0.120  ...      0.003       0.000
#
#    rs74853756  rs10945395  rs461769  rs61912468  rs72857489  rs35410275  \
# 0       0.999       1.987     2.000         0.0       0.000       0.000
# 1       0.000       0.002     1.000         0.0       0.000       0.000
# 2       0.000       1.000     1.000         0.0       0.000       0.000
# 3       1.000       0.000     1.005         0.0       0.095       0.000
# 4       0.000       1.972     1.000         0.0       0.000       0.012
#
#    rs885170  Subject Id
# 0     0.996   RQ22067-0
# 1     0.000   RQ34365-4
# 2     0.012   RQ34616-4
# 3     0.015   RQ34720-1
# 4     0.004   RQ14799-8
#
# [5 rows x 23 columns]

# %%
data2 = data2.drop_duplicates(subset='Subject Id')

# %% [markdown]
# **2.2.4) Data transformation such as Scaling, Decomposition and Aggregation**

# %%
# Mapping data1 and data2 together by the id column

n_df = pd.merge(n_data11, data2,on = 'Subject Id', how='left')
#n_df = data1

print(n_df.shape)
# Out:
# (2067, 131)

# %%
# no need because already done this for both data
#uncorrelated_df= pairwisecorr(n_df, dependent1, threshold=0.7)

# %%
uncorrelated_df= n_df

# %%
# I f I want to use clinic data only
#n_df= data1

# %%
# from this dataset we can divide the features into clinic, snps or the combined which has all
print(list(uncorrelated_df))
# Out:
# ['breast_arm_lymphodema_24m', 'Subject Id', 'date', 'height_cm', 'age', 'bra_cup_size', 'band_size', 'smoker', 'alcohol_intake', 'alcohol_current_consumption', 'menopausal_status', 'monopause_age_yrs', 'hormone_replacement_therapy', 'diabetes', 'history_of_heart_disease', 'ra', 'systemic_lupus_erythematosus', 'other_collagen_vascular_disease', 'hypertension', 'depression', 'antidiabetic', 'ace_inhibitor', 'other_antihypertensive_drug', 'on_statin', 'other_lipid_lowering_drugs', 'amiodarone', 'analgesics', 'antidepressant', 'breast_cancer_family_history_1st_degree', 'radiotherapy_toxicity_family_history', 'ethnicity', 'education_profession', 'household_members', 'Date', 'surgery_type', 'surgery_date', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'post_operative_infection', 'delayed_healing', 'tumour_side_of_primary', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'tumour_histological_type', 'tumour_size_mm', 't_stage', 'n_stage', 'm_stage', 'r_stage', 'ki_67_status_pc', 'er_status', 'her2_status', 'pr_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'sys_treatment', 'sys_tamoxifen', 'sys_aromatase', 'sys_antiher2', 'radio_breast_startdate', 'radio_breast_enddate', 'radio_interrupted', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_breast_delineation', 'radio_breast_internal_mammary_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_skin_delineation', 'radio_heart_mean_dose_Gy', 'radio_heart_delineation', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'radio_imrt', 'radio_treatment_pos', 'radio_3d', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_boost', 'radio_boost_startdate', 'radio_boost_enddate', 'radio_boost_type', 'radio_bolus', 'radio_boost_sequence', 'surgery_axilla_type', 'radio_breast_fractions_per_week', 'radio_photon_2nd', 'radio_photon_boostdose_precise_Gy', 'radio_photon_boost_fractions', 'radio_photon_boost_dose_per_fraction_Gy', 'Site', 'breast_atrophy_baseline', 'breast_nipple_retraction_baseline', 'breast_oedema_baseline', 'breast_skin_ulceration_baseline', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_skin_induration_tumour_bed_baseline', 'breast_skin_induration_outside_tumour_bed_baseline', 'breast_erythema_baseline', 'breast_arm_lymphodema_baseline', 'breast_skin_hyperpigmentation_baseline', 'breast_pneumontis_baseline', 'breast_pain_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']

# %%
# Drop date-type features
#n_df = n_df.drop(columns=n_df.select_dtypes(include=['datetime']).columns)

# %%
#n_df.columns = n_df.columns.to_flat_index()

# %%
Cuniq(uncorrelated_df, dependent1)
# Out:
# breast_arm_lymphodema_24m
# 0.0    1628
# 1.0      54
# 2.0       9
# Name: count, dtype: int64

# %% [markdown]
# From above we can see that Grade 3 atrophy is contain 24 cases, g1 and g2 in clinics have the same procedure, so thought doing binary classification is the right option for Erythema.

# %%
# We transform the arm_lymphodema_24 column values to 0 and 1 for a better exploration,

reduced_df = uncorrelated_df.replace(dict(breast_arm_lymphodema_24m={0: 0, 1: 1, 2:1 , 3:1}))

# %%
Cuniq(reduced_df, dependent1)
# Out:
# breast_arm_lymphodema_24m
# 0.0    1628
# 1.0      63
# Name: count, dtype: int64

# %%
# select categorical features in order to transform them to numeric data
cat_columns = reduced_df.select_dtypes(['category']).columns
# trans the values to numeric and apply that to the data
#reduced_df[cat_columns] = reduced_df[cat_columns].apply(lambda x: x.cat.codes)

reduced_df[cat_columns] = (reduced_df[cat_columns].
                           apply(lambda x: x.cat.codes.replace(-1, np.nan)))

# %%
Cuniq(reduced_df, dependent1)
# Out:
# breast_arm_lymphodema_24m
# 0.0    1628
# 1.0      63
# Name: count, dtype: int64

# %%
print(list(reduced_df.columns))
# Out:
# ['breast_arm_lymphodema_24m', 'Subject Id', 'date', 'height_cm', 'age', 'bra_cup_size', 'band_size', 'smoker', 'alcohol_intake', 'alcohol_current_consumption', 'menopausal_status', 'monopause_age_yrs', 'hormone_replacement_therapy', 'diabetes', 'history_of_heart_disease', 'ra', 'systemic_lupus_erythematosus', 'other_collagen_vascular_disease', 'hypertension', 'depression', 'antidiabetic', 'ace_inhibitor', 'other_antihypertensive_drug', 'on_statin', 'other_lipid_lowering_drugs', 'amiodarone', 'analgesics', 'antidepressant', 'breast_cancer_family_history_1st_degree', 'radiotherapy_toxicity_family_history', 'ethnicity', 'education_profession', 'household_members', 'Date', 'surgery_type', 'surgery_date', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'post_operative_infection', 'delayed_healing', 'tumour_side_of_primary', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'tumour_histological_type', 'tumour_size_mm', 't_stage', 'n_stage', 'm_stage', 'r_stage', 'ki_67_status_pc', 'er_status', 'her2_status', 'pr_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'sys_treatment', 'sys_tamoxifen', 'sys_aromatase', 'sys_antiher2', 'radio_breast_startdate', 'radio_breast_enddate', 'radio_interrupted', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_breast_delineation', 'radio_breast_internal_mammary_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_skin_delineation', 'radio_heart_mean_dose_Gy', 'radio_heart_delineation', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'radio_imrt', 'radio_treatment_pos', 'radio_3d', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_boost', 'radio_boost_startdate', 'radio_boost_enddate', 'radio_boost_type', 'radio_bolus', 'radio_boost_sequence', 'surgery_axilla_type', 'radio_breast_fractions_per_week', 'radio_photon_2nd', 'radio_photon_boostdose_precise_Gy', 'radio_photon_boost_fractions', 'radio_photon_boost_dose_per_fraction_Gy', 'Site', 'breast_atrophy_baseline', 'breast_nipple_retraction_baseline', 'breast_oedema_baseline', 'breast_skin_ulceration_baseline', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_skin_induration_tumour_bed_baseline', 'breast_skin_induration_outside_tumour_bed_baseline', 'breast_erythema_baseline', 'breast_arm_lymphodema_baseline', 'breast_skin_hyperpigmentation_baseline', 'breast_pneumontis_baseline', 'breast_pain_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']

# %% [markdown]
# ##Removing Correlated Features
# Feature selection:is very important to remove irrelevant features result in a better performance model, to easier understand the model and to run the model fast**

# %% [markdown]
# **Pairwise correlated feature selection**

# %%
df_clean= pairwisecorr(reduced_df, dependent1, 0.7) # May some feature are missing so compare with below
# Out:
# Highly correlated feature pairs > 0.7:
# diabetes and antidiabetic: 0.90
# hypertension and other_antihypertensive_drug: 0.80
# depression and antidepressant: 0.86
# nodes_involved and n_stage: 0.86
# nodes_examined and surgery_axilla_type: 0.73
# tumour_side_of_primary and radio_treated_breast: 1.00
# her2_status and sys_antiher2: 0.85
# sys_tamoxifen and sys_aromatase: 0.85
# radio_skin_delineation and radio_3d: 0.75
# radio_boost_sequence and radio_photon_boost_fractions: 0.84
#
# Removed features:
# ['other_antihypertensive_drug', 'antidiabetic', 'radio_boost_sequence', 'sys_tamoxifen', 'radio_skin_delineation', 'surgery_axilla_type', 'sys_antiher2', 'antidepressant', 'n_stage', 'tumour_side_of_primary']
#
# Final shape: (2067, 121)

# %%
# remove all date coloums
datetime_cols = df_clean.select_dtypes(include=['datetime64']).columns
print(datetime_cols)
if not datetime_cols.empty:
      df_clean = df_clean.drop(columns=datetime_cols)
# Out:
# Index(['date', 'Date', 'surgery_date', 'radio_breast_startdate',
#        'radio_breast_enddate', 'radio_boost_startdate', 'radio_boost_enddate'],
#       dtype='object')

# %%
print(list(df_clean.columns))
# Out:
# ['breast_arm_lymphodema_24m', 'Subject Id', 'height_cm', 'age', 'bra_cup_size', 'band_size', 'smoker', 'alcohol_intake', 'alcohol_current_consumption', 'menopausal_status', 'monopause_age_yrs', 'hormone_replacement_therapy', 'diabetes', 'history_of_heart_disease', 'ra', 'systemic_lupus_erythematosus', 'other_collagen_vascular_disease', 'hypertension', 'depression', 'ace_inhibitor', 'on_statin', 'other_lipid_lowering_drugs', 'amiodarone', 'analgesics', 'breast_cancer_family_history_1st_degree', 'radiotherapy_toxicity_family_history', 'ethnicity', 'education_profession', 'household_members', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'post_operative_infection', 'delayed_healing', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'tumour_histological_type', 'tumour_size_mm', 't_stage', 'm_stage', 'r_stage', 'ki_67_status_pc', 'er_status', 'her2_status', 'pr_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'sys_treatment', 'sys_aromatase', 'radio_interrupted', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_breast_delineation', 'radio_breast_internal_mammary_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_heart_delineation', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'radio_imrt', 'radio_treatment_pos', 'radio_3d', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_boost', 'radio_boost_type', 'radio_bolus', 'radio_breast_fractions_per_week', 'radio_photon_2nd', 'radio_photon_boostdose_precise_Gy', 'radio_photon_boost_fractions', 'radio_photon_boost_dose_per_fraction_Gy', 'Site', 'breast_atrophy_baseline', 'breast_nipple_retraction_baseline', 'breast_oedema_baseline', 'breast_skin_ulceration_baseline', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_skin_induration_tumour_bed_baseline', 'breast_skin_induration_outside_tumour_bed_baseline', 'breast_erythema_baseline', 'breast_arm_lymphodema_baseline', 'breast_skin_hyperpigmentation_baseline', 'breast_pneumontis_baseline', 'breast_pain_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']

# %%
reduced_df_clinic=reduced_df[['breast_arm_lymphodema_24m', 'Subject Id', 'height_cm', 'age', 'bra_cup_size', 'band_size', 'smoker', 'alcohol_intake', 'alcohol_current_consumption', 'menopausal_status', 'monopause_age_yrs', 'hormone_replacement_therapy', 'diabetes', 'history_of_heart_disease', 'ra', 'systemic_lupus_erythematosus', 'other_collagen_vascular_disease', 'hypertension', 'depression', 'ace_inhibitor', 'on_statin', 'other_lipid_lowering_drugs', 'amiodarone', 'analgesics', 'breast_cancer_family_history_1st_degree', 'radiotherapy_toxicity_family_history', 'ethnicity', 'education_profession', 'household_members', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'post_operative_infection', 'delayed_healing', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'tumour_histological_type', 'tumour_size_mm', 't_stage', 'm_stage', 'r_stage', 'ki_67_status_pc', 'er_status', 'her2_status', 'pr_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'sys_treatment', 'sys_aromatase', 'radio_interrupted', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_breast_delineation', 'radio_breast_internal_mammary_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_heart_delineation', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'radio_imrt', 'radio_treatment_pos', 'radio_3d', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_boost', 'radio_boost_type', 'radio_bolus', 'radio_breast_fractions_per_week', 'radio_photon_2nd', 'radio_photon_boostdose_precise_Gy', 'radio_photon_boost_fractions', 'radio_photon_boost_dose_per_fraction_Gy', 'Site', 'breast_atrophy_baseline', 'breast_nipple_retraction_baseline', 'breast_oedema_baseline', 'breast_skin_ulceration_baseline', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_skin_induration_tumour_bed_baseline', 'breast_skin_induration_outside_tumour_bed_baseline', 'breast_erythema_baseline', 'breast_arm_lymphodema_baseline', 'breast_skin_hyperpigmentation_baseline', 'breast_pneumontis_baseline', 'breast_pain_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline']

]

reduced_df_snp= reduced_df[['breast_arm_lymphodema_24m', 'Subject Id',  'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']]

# %%
# this does have a date and some colrelated cols
reduced_df.shape
# Out:
# (2067, 131)

# %%
df_combined_20=X_per_removed(reduced_df,dependent1, 19)
# Out:
# (2067, 107)
# ['breast_arm_lymphodema_24m', 'Subject Id', 'date', 'height_cm', 'age', 'bra_cup_size', 'band_size', 'smoker', 'alcohol_intake', 'menopausal_status', 'diabetes', 'history_of_heart_disease', 'ra', 'systemic_lupus_erythematosus', 'other_collagen_vascular_disease', 'hypertension', 'depression', 'antidiabetic', 'ace_inhibitor', 'other_antihypertensive_drug', 'on_statin', 'other_lipid_lowering_drugs', 'amiodarone', 'analgesics', 'antidepressant', 'breast_cancer_family_history_1st_degree', 'ethnicity', 'Date', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'post_operative_infection', 'delayed_healing', 'tumour_side_of_primary', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'tumour_histological_type', 'tumour_size_mm', 't_stage', 'n_stage', 'm_stage', 'er_status', 'her2_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'sys_treatment', 'radio_breast_enddate', 'radio_interrupted', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_breast_delineation', 'radio_skin_max_dose_Gy', 'radio_skin_delineation', 'radio_heart_mean_dose_Gy', 'radio_heart_delineation', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'radio_imrt', 'radio_treatment_pos', 'radio_3d', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_boost', 'radio_breast_fractions_per_week', 'radio_photon_2nd', 'Site', 'breast_atrophy_baseline', 'breast_nipple_retraction_baseline', 'breast_oedema_baseline', 'breast_skin_ulceration_baseline', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_skin_induration_tumour_bed_baseline', 'breast_skin_induration_outside_tumour_bed_baseline', 'breast_erythema_baseline', 'breast_arm_lymphodema_baseline', 'breast_skin_hyperpigmentation_baseline', 'breast_pneumontis_baseline', 'breast_pain_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']

# %%
df_clean_20=X_per_removed(df_clean,dependent1, 20)
# Out:
# (2067, 99)
# ['breast_arm_lymphodema_24m', 'Subject Id', 'height_cm', 'age', 'bra_cup_size', 'band_size', 'smoker', 'alcohol_intake', 'menopausal_status', 'diabetes', 'history_of_heart_disease', 'ra', 'systemic_lupus_erythematosus', 'other_collagen_vascular_disease', 'hypertension', 'depression', 'ace_inhibitor', 'on_statin', 'other_lipid_lowering_drugs', 'amiodarone', 'analgesics', 'breast_cancer_family_history_1st_degree', 'ethnicity', 'education_profession', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'post_operative_infection', 'delayed_healing', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'tumour_histological_type', 'tumour_size_mm', 't_stage', 'm_stage', 'er_status', 'her2_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'sys_treatment', 'radio_interrupted', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_breast_delineation', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_heart_delineation', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'radio_imrt', 'radio_treatment_pos', 'radio_3d', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_boost', 'radio_breast_fractions_per_week', 'radio_photon_2nd', 'Site', 'breast_atrophy_baseline', 'breast_nipple_retraction_baseline', 'breast_oedema_baseline', 'breast_skin_ulceration_baseline', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_skin_induration_tumour_bed_baseline', 'breast_skin_induration_outside_tumour_bed_baseline', 'breast_erythema_baseline', 'breast_arm_lymphodema_baseline', 'breast_skin_hyperpigmentation_baseline', 'breast_pneumontis_baseline', 'breast_pain_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']

# %%
nullP(df_combined_20)
# Out:
# breast_arm_lymphodema_24m                 18.0
# her2_status                               13.0
# tumour_quadrant                            9.0
# nodes_examined                             9.0
# nodes_involved                             9.0
#                                           ...
# radio_breast_enddate                       0.0
# radio_skin_delineation                     0.0
# breast_skin_hyperpigmentation_baseline     0.0
# breast_pain_baseline                       0.0
# breast_arm_lymphodema_baseline             0.0
# Length: 107, dtype: float64

# %%
def cross_validated_feature_selection(df, col, splits):

    print('Original Data shape is', df.shape)

    # Drop rows only where target is missing
    df = df.dropna(subset=[col])

    cols_to_drop = [col]
    if 'Subject Id' in df.columns:
        cols_to_drop.append('Subject Id')
    X = df.drop(columns=cols_to_drop)
    y = df[col]

    print('Data shape after dropping missing target:', df.shape)

    X_numeric = X.select_dtypes(include=np.number)

    # Fill missing feature values
    X_numeric = X_numeric.fillna(X_numeric.median()) # filling missing with median

    X_scaled = pd.DataFrame(MinMaxScaler().fit_transform(X_numeric),
                            columns=X_numeric.columns,
                            index=X_numeric.index)

    pipeline = Pipeline([('clf', RandomForestClassifier(n_estimators=100,
                                  max_depth=10, min_samples_split=5,            min_samples_leaf=1, bootstrap=True,            random_state=5))])

    skf = StratifiedKFold(n_splits=splits, shuffle=True, random_state=0)

    auc_scores = cross_val_score(pipeline, X_scaled, y, cv=skf,
                                 scoring='roc_auc')

    print(f"✅ Mean AUC with final selected features: {auc_scores.mean():.4f}")

# %%
cross_validated_feature_selection(df_clean_20, dependent1, 10)
# Out:
# Original Data shape is (2067, 99)
# Data shape after dropping missing target: (1691, 99)
# ✅ Mean AUC with final selected features: 0.8836

# %% [markdown]
# # **3) Feature Selection Methods**

# %%
df_clean_20.shape
# Out:
# (2067, 99)

# %%
k= [10, 15, 20, 25, 30, 35, 40]

# %% [markdown]
# ##First Method:Features selction

# %% [markdown]
# **3.3.1) Univariate Selection** — Statistical tests may be used to pick certain features that have the best relationship to the performance variable. The scikit-learn library provides the SelectKBest class that can be used to select a specific number of features in a suite of different statistical tests. The below following example uses the chi-squared (chi2) statistical test for non-negative features to select 10 of the best features from the Mobile Price Range Prediction Dataset.

# %% [markdown]
# ### not scaled

# %%
# this is my first features selection method, it is weak method because:
# Done on whole dataset, No scaling, Data Leakage, Worse performance due to Chi² needing non-negative scaled data.

def featureselection1(df, dependent, k):

    # Drop rows with missing values
    df = df.dropna(axis=0, how='any', inplace=False)

    # Separate features and target variable
    X = df.drop(columns=[dependent, 'Subject Id'])
    y = df[dependent]

    # Convert categorical variables into numeric
    X = pd.get_dummies(X, drop_first=True)

    #X = X.select_dtypes(include=['number']) # just to select the numbers cols
    #negative_cols = (X < 0).any()
    #print(list(negative_cols))
    # Ensure all feature values are non-negative (Chi-Squared requirement)
    #X = X.applymap(lambda x: max(x, 0))

    # Apply SelectKBest class to extract top k best features using chi2
    bestfeatures = SelectKBest(score_func=chi2, k=k)
    fit = bestfeatures.fit(X, y)

    # Create DataFrames for scores and feature names
    dfscores = pd.DataFrame(fit.scores_, columns=['Score'])
    dfcolumns = pd.DataFrame(X.columns, columns=['TopFeat'])

    # Concatenate the DataFrames for better visualization
    featureScores = pd.concat([dfcolumns, dfscores], axis=1)

    # Sort and select the top k features
    top_features = featureScores.nlargest(k, 'Score')

    # Extract the top k feature names into a list
    top_features_list = top_features['TopFeat'].tolist()

    # Plot the top k features
    plt.figure(figsize=(10, 8))
    plt.barh(top_features['TopFeat'], top_features['Score'], color='skyblue')
    plt.xlabel('Score')
    plt.title(f'Top {k} Features selected by Chi-Squared')
    plt.gca().invert_yaxis()  # Invert y-axis for better visualization
    plt.show()  # Show the plot

    # Print the top k features
    print(tabulate(top_features, headers='keys', tablefmt='psql'))
    # Print the list of top 30 features
    print(f"\nList of top {k} features:\n", top_features_list, '\n\n')


    # Prepare data with selected features only
    X_selected = X[top_features_list]

    # Build pipeline and evaluate using cross-validation
    pipeline = Pipeline([
        ('classifier', RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=1,bootstrap=True, random_state=5))
    ])

    # Use StratifiedKFold and calculate mean AUC
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
    auc_scores = cross_val_score(pipeline, X_selected, y, cv=skf, scoring='roc_auc')

    print(f"Mean AUC score using top {k} features: {auc_scores.mean():.4f}")
    print("\n\t********************************************************************************************************************************************************************")
    return featureScores, auc_scores.mean()

# %%
feature_sets_univariate_nonscaled = {}

for i in k:
    freq_df_nonscaled_auc= featureselection1(df_clean_20, dependent1, k=i)
    feature_sets_univariate_nonscaled[i] = freq_df_nonscaled_auc
# Out:
# +----+-------------------------------------------+-----------+
# |    | TopFeat                                   |     Score |
# |----+-------------------------------------------+-----------|
# | 43 | radio_breast_ct_volume_cm3                | 2912.71   |
# | 24 | nodes_examined                            |  256.382  |
# | 74 | breast_right_arm_circumfrence_mm_baseline |   68.0867 |
# | 46 | radio_heart_mean_dose_Gy                  |   36.5315 |
# | 23 | nodes_involved                            |   35.9625 |
# | 54 | axillary_levels                           |   23.2121 |
# | 69 | breast_arm_lymphodema_baseline            |   21.675  |
# | 55 | radio_supraclavicular_fossa               |   21      |
# | 25 | post_operative_haematoma                  |   17.321  |
# | 76 | rs67342194                                |   16.1009 |
# +----+-------------------------------------------+-----------+
#
# List of top 10 features:
#  ['radio_breast_ct_volume_cm3', 'nodes_examined', 'breast_right_arm_circumfrence_mm_baseline', 'radio_heart_mean_dose_Gy', 'nodes_involved', 'axillary_levels', 'breast_arm_lymphodema_baseline', 'radio_supraclavicular_fossa', 'post_operative_haematoma', 'rs67342194']
#
#
# Mean AUC score using top 10 features: 0.8299
#
# 	********************************************************************************************************************************************************************
# +----+-------------------------------------------+-----------+
# |    | TopFeat                                   |     Score |
# |----+-------------------------------------------+-----------|
# | 43 | radio_breast_ct_volume_cm3                | 2912.71   |
# | 24 | nodes_examined                            |  256.382  |
# | 74 | breast_right_arm_circumfrence_mm_baseline |   68.0867 |
# | 46 | radio_heart_mean_dose_Gy                  |   36.5315 |
# | 23 | nodes_involved                            |   35.9625 |
# | 54 | axillary_levels                           |   23.2121 |
# | 69 | breast_arm_lymphodema_baseline            |   21.675  |
# | 55 | radio_supraclavicular_fossa               |   21      |
# | 25 | post_operative_haematoma                  |   17.321  |
# | 76 | rs67342194                                |   16.1009 |
# | 94 | rs72857489                                |   14.8763 |
# | 85 | rs56402833                                |   13.0817 |
# | 49 | radio_ipsilateral_lung_mean_Gy            |   11.9184 |
# | 73 | breast_swollen_arm_baseline               |   11.83   |
# | 90 | rs74853756                                |    8.1429 |
# +----+-------------------------------------------+-----------+
#
# List of top 15 features:
#  ['radio_breast_ct_volume_cm3', 'nodes_examined', 'breast_right_arm_circumfrence_mm_baseline', 'radio_heart_mean_dose_Gy', 'nodes_involved', 'axillary_levels', 'breast_arm_lymphodema_baseline', 'radio_supraclavicular_fossa', 'post_operative_haematoma', 'rs67342194', 'rs72857489', 'rs56402833', 'radio_ipsilateral_lung_mean_Gy', 'breast_swollen_arm_baseline', 'rs74853756']
#
#
# Mean AUC score using top 15 features: 0.8710
#
# 	********************************************************************************************************************************************************************
# +----+-------------------------------------------+------------+
# |    | TopFeat                                   |      Score |
# |----+-------------------------------------------+------------|
# | 43 | radio_breast_ct_volume_cm3                | 2912.71    |
# | 24 | nodes_examined                            |  256.382   |
# | 74 | breast_right_arm_circumfrence_mm_baseline |   68.0867  |
# | 46 | radio_heart_mean_dose_Gy                  |   36.5315  |
# | 23 | nodes_involved                            |   35.9625  |
# | 54 | axillary_levels                           |   23.2121  |
# | 69 | breast_arm_lymphodema_baseline            |   21.675   |
# | 55 | radio_supraclavicular_fossa               |   21       |
# | 25 | post_operative_haematoma                  |   17.321   |
# | 76 | rs67342194                                |   16.1009  |
# | 94 | rs72857489                                |   14.8763  |
# | 85 | rs56402833                                |   13.0817  |
# | 49 | radio_ipsilateral_lung_mean_Gy            |   11.9184  |
# | 73 | breast_swollen_arm_baseline               |   11.83    |
# | 90 | rs74853756                                |    8.1429  |
# | 29 | tumour_quadrant                           |    8.0807  |
# | 79 | rs7195405                                 |    6.61387 |
# | 33 | tumour_size_mm                            |    6.39883 |
# | 92 | rs461769                                  |    5.93069 |
# | 91 | rs10945395                                |    5.8235  |
# +----+-------------------------------------------+------------+
#
# List of top 20 features:
#  ['radio_breast_ct_volume_cm3', 'nodes_examined', 'breast_right_arm_circumfrence_mm_baseline', 'radio_heart_mean_dose_Gy', 'nodes_involved', 'axillary_levels', 'breast_arm_lymphodema_baseline', 'radio_supraclavicular_fossa', 'post_operative_haematoma', 'rs67342194', 'rs72857489', 'rs56402833', 'radio_ipsilateral_lung_mean_Gy', 'breast_swollen_arm_baseline', 'rs74853756', 'tumour_quadrant', 'rs7195405', 'tumour_size_mm', 'rs461769', 'rs10945395']
#
#
# Mean AUC score using top 20 features: 0.9213
#
# 	********************************************************************************************************************************************************************
# +----+-------------------------------------------+------------+
# |    | TopFeat                                   |      Score |
# |----+-------------------------------------------+------------|
# | 43 | radio_breast_ct_volume_cm3                | 2912.71    |
# | 24 | nodes_examined                            |  256.382   |
# | 74 | breast_right_arm_circumfrence_mm_baseline |   68.0867  |
# | 46 | radio_heart_mean_dose_Gy                  |   36.5315  |
# | 23 | nodes_involved                            |   35.9625  |
# | 54 | axillary_levels                           |   23.2121  |
# | 69 | breast_arm_lymphodema_baseline            |   21.675   |
# | 55 | radio_supraclavicular_fossa               |   21       |
# | 25 | post_operative_haematoma                  |   17.321   |
# | 76 | rs67342194                                |   16.1009  |
# | 94 | rs72857489                                |   14.8763  |
# | 85 | rs56402833                                |   13.0817  |
# | 49 | radio_ipsilateral_lung_mean_Gy            |   11.9184  |
# | 73 | breast_swollen_arm_baseline               |   11.83    |
# | 90 | rs74853756                                |    8.1429  |
# | 29 | tumour_quadrant                           |    8.0807  |
# | 79 | rs7195405                                 |    6.61387 |
# | 33 | tumour_size_mm                            |    6.39883 |
# | 92 | rs461769                                  |    5.93069 |
# | 91 | rs10945395                                |    5.8235  |
# | 81 | rs2954007                                 |    5.74137 |
# | 18 | analgesics                                |    5.6     |
# |  7 | diabetes                                  |    5.28125 |
# | 45 | radio_skin_max_dose_Gy                    |    5.01585 |
# | 75 | rs77405610                                |    4.27777 |
# +----+-------------------------------------------+------------+
#
# List of top 25 features:
#  ['radio_breast_ct_volume_cm3', 'nodes_examined', 'breast_right_arm_circumfrence_mm_baseline', 'radio_heart_mean_dose_Gy', 'nodes_involved', 'axillary_levels', 'breast_arm_lymphodema_baseline', 'radio_supraclavicular_fossa', 'post_operative_haematoma', 'rs67342194', 'rs72857489', 'rs56402833', 'radio_ipsilateral_lung_mean_Gy', 'breast_swollen_arm_baseline', 'rs74853756', 'tumour_quadrant', 'rs7195405', 'tumour_size_mm', 'rs461769', 'rs10945395', 'rs2954007', 'analgesics', 'diabetes', 'radio_skin_max_dose_Gy', 'rs77405610']
#
#
# Mean AUC score using top 25 features: 0.9184
#
# 	********************************************************************************************************************************************************************
# +----+-------------------------------------------+------------+
# |    | TopFeat                                   |      Score |
# |----+-------------------------------------------+------------|
# | 43 | radio_breast_ct_volume_cm3                | 2912.71    |
# | 24 | nodes_examined                            |  256.382   |
# | 74 | breast_right_arm_circumfrence_mm_baseline |   68.0867  |
# | 46 | radio_heart_mean_dose_Gy                  |   36.5315  |
# | 23 | nodes_involved                            |   35.9625  |
# | 54 | axillary_levels                           |   23.2121  |
# | 69 | breast_arm_lymphodema_baseline            |   21.675   |
# | 55 | radio_supraclavicular_fossa               |   21       |
# | 25 | post_operative_haematoma                  |   17.321   |
# | 76 | rs67342194                                |   16.1009  |
# | 94 | rs72857489                                |   14.8763  |
# | 85 | rs56402833                                |   13.0817  |
# | 49 | radio_ipsilateral_lung_mean_Gy            |   11.9184  |
# | 73 | breast_swollen_arm_baseline               |   11.83    |
# | 90 | rs74853756                                |    8.1429  |
# | 29 | tumour_quadrant                           |    8.0807  |
# | 79 | rs7195405                                 |    6.61387 |
# | 33 | tumour_size_mm                            |    6.39883 |
# | 92 | rs461769                                  |    5.93069 |
# | 91 | rs10945395                                |    5.8235  |
# | 81 | rs2954007                                 |    5.74137 |
# | 18 | analgesics                                |    5.6     |
# |  7 | diabetes                                  |    5.28125 |
# | 45 | radio_skin_max_dose_Gy                    |    5.01585 |
# | 75 | rs77405610                                |    4.27777 |
# | 58 | radio_photon_2nd                          |    4.05235 |
# |  8 | history_of_heart_disease                  |    4       |
# | 39 | chemo_adjuvant                            |    3.77978 |
# | 77 | rs1788750                                 |    3.43468 |
# | 38 | chemo_neo_adjuvant                        |    3.2     |
# +----+-------------------------------------------+------------+
#
# List of top 30 features:
#  ['radio_breast_ct_volume_cm3', 'nodes_examined', 'breast_right_arm_circumfrence_mm_baseline', 'radio_heart_mean_dose_Gy', 'nodes_involved', 'axillary_levels', 'breast_arm_lymphodema_baseline', 'radio_supraclavicular_fossa', 'post_operative_haematoma', 'rs67342194', 'rs72857489', 'rs56402833', 'radio_ipsilateral_lung_mean_Gy', 'breast_swollen_arm_baseline', 'rs74853756', 'tumour_quadrant', 'rs7195405', 'tumour_size_mm', 'rs461769', 'rs10945395', 'rs2954007', 'analgesics', 'diabetes', 'radio_skin_max_dose_Gy', 'rs77405610', 'radio_photon_2nd', 'history_of_heart_disease', 'chemo_adjuvant', 'rs1788750', 'chemo_neo_adjuvant']
#
#
# Mean AUC score using top 30 features: 0.9086
#
# 	********************************************************************************************************************************************************************
# +----+-------------------------------------------+------------+
# |    | TopFeat                                   |      Score |
# |----+-------------------------------------------+------------|
# | 43 | radio_breast_ct_volume_cm3                | 2912.71    |
# | 24 | nodes_examined                            |  256.382   |
# | 74 | breast_right_arm_circumfrence_mm_baseline |   68.0867  |
# | 46 | radio_heart_mean_dose_Gy                  |   36.5315  |
# | 23 | nodes_involved                            |   35.9625  |
# | 54 | axillary_levels                           |   23.2121  |
# | 69 | breast_arm_lymphodema_baseline            |   21.675   |
# | 55 | radio_supraclavicular_fossa               |   21       |
# | 25 | post_operative_haematoma                  |   17.321   |
# | 76 | rs67342194                                |   16.1009  |
# | 94 | rs72857489                                |   14.8763  |
# | 85 | rs56402833                                |   13.0817  |
# | 49 | radio_ipsilateral_lung_mean_Gy            |   11.9184  |
# | 73 | breast_swollen_arm_baseline               |   11.83    |
# | 90 | rs74853756                                |    8.1429  |
# | 29 | tumour_quadrant                           |    8.0807  |
# | 79 | rs7195405                                 |    6.61387 |
# | 33 | tumour_size_mm                            |    6.39883 |
# | 92 | rs461769                                  |    5.93069 |
# | 91 | rs10945395                                |    5.8235  |
# | 81 | rs2954007                                 |    5.74137 |
# | 18 | analgesics                                |    5.6     |
# |  7 | diabetes                                  |    5.28125 |
# | 45 | radio_skin_max_dose_Gy                    |    5.01585 |
# | 75 | rs77405610                                |    4.27777 |
# | 58 | radio_photon_2nd                          |    4.05235 |
# |  8 | history_of_heart_disease                  |    4       |
# | 39 | chemo_adjuvant                            |    3.77978 |
# | 77 | rs1788750                                 |    3.43468 |
# | 38 | chemo_neo_adjuvant                        |    3.2     |
# | 86 | rs633502                                  |    3.15408 |
# | 31 | tumour_histological_grade                 |    3.13876 |
# | 82 | rs57288348                                |    2.96262 |
# | 34 | t_stage                                   |    2.91805 |
# | 93 | rs61912468                                |    2.89396 |
# +----+-------------------------------------------+------------+
#
# List of top 35 features:
#  ['radio_breast_ct_volume_cm3', 'nodes_examined', 'breast_right_arm_circumfrence_mm_baseline', 'radio_heart_mean_dose_Gy', 'nodes_involved', 'axillary_levels', 'breast_arm_lymphodema_baseline', 'radio_supraclavicular_fossa', 'post_operative_haematoma', 'rs67342194', 'rs72857489', 'rs56402833', 'radio_ipsilateral_lung_mean_Gy', 'breast_swollen_arm_baseline', 'rs74853756', 'tumour_quadrant', 'rs7195405', 'tumour_size_mm', 'rs461769', 'rs10945395', 'rs2954007', 'analgesics', 'diabetes', 'radio_skin_max_dose_Gy', 'rs77405610', 'radio_photon_2nd', 'history_of_heart_disease', 'chemo_adjuvant', 'rs1788750', 'chemo_neo_adjuvant', 'rs633502', 'tumour_histological_grade', 'rs57288348', 't_stage', 'rs61912468']
#
#
# Mean AUC score using top 35 features: 0.9028
#
# 	********************************************************************************************************************************************************************
# +----+-------------------------------------------+------------+
# |    | TopFeat                                   |      Score |
# |----+-------------------------------------------+------------|
# | 43 | radio_breast_ct_volume_cm3                | 2912.71    |
# | 24 | nodes_examined                            |  256.382   |
# | 74 | breast_right_arm_circumfrence_mm_baseline |   68.0867  |
# | 46 | radio_heart_mean_dose_Gy                  |   36.5315  |
# | 23 | nodes_involved                            |   35.9625  |
# | 54 | axillary_levels                           |   23.2121  |
# | 69 | breast_arm_lymphodema_baseline            |   21.675   |
# | 55 | radio_supraclavicular_fossa               |   21       |
# | 25 | post_operative_haematoma                  |   17.321   |
# | 76 | rs67342194                                |   16.1009  |
# | 94 | rs72857489                                |   14.8763  |
# | 85 | rs56402833                                |   13.0817  |
# | 49 | radio_ipsilateral_lung_mean_Gy            |   11.9184  |
# | 73 | breast_swollen_arm_baseline               |   11.83    |
# | 90 | rs74853756                                |    8.1429  |
# | 29 | tumour_quadrant                           |    8.0807  |
# | 79 | rs7195405                                 |    6.61387 |
# | 33 | tumour_size_mm                            |    6.39883 |
# | 92 | rs461769                                  |    5.93069 |
# | 91 | rs10945395                                |    5.8235  |
# | 81 | rs2954007                                 |    5.74137 |
# | 18 | analgesics                                |    5.6     |
# |  7 | diabetes                                  |    5.28125 |
# | 45 | radio_skin_max_dose_Gy                    |    5.01585 |
# | 75 | rs77405610                                |    4.27777 |
# | 58 | radio_photon_2nd                          |    4.05235 |
# |  8 | history_of_heart_disease                  |    4       |
# | 39 | chemo_adjuvant                            |    3.77978 |
# | 77 | rs1788750                                 |    3.43468 |
# | 38 | chemo_neo_adjuvant                        |    3.2     |
# | 86 | rs633502                                  |    3.15408 |
# | 31 | tumour_histological_grade                 |    3.13876 |
# | 82 | rs57288348                                |    2.96262 |
# | 34 | t_stage                                   |    2.91805 |
# | 93 | rs61912468                                |    2.89396 |
# | 78 | rs10764743                                |    2.86739 |
# | 12 | hypertension                              |    2.738   |
# |  5 | alcohol_intake                            |    2.70937 |
# | 22 | surgery_type                              |    2.7075  |
# | 89 | rs79223472                                |    2.7016  |
# +----+-------------------------------------------+------------+
#
# List of top 40 features:
#  ['radio_breast_ct_volume_cm3', 'nodes_examined', 'breast_right_arm_circumfrence_mm_baseline', 'radio_heart_mean_dose_Gy', 'nodes_involved', 'axillary_levels', 'breast_arm_lymphodema_baseline', 'radio_supraclavicular_fossa', 'post_operative_haematoma', 'rs67342194', 'rs72857489', 'rs56402833', 'radio_ipsilateral_lung_mean_Gy', 'breast_swollen_arm_baseline', 'rs74853756', 'tumour_quadrant', 'rs7195405', 'tumour_size_mm', 'rs461769', 'rs10945395', 'rs2954007', 'analgesics', 'diabetes', 'radio_skin_max_dose_Gy', 'rs77405610', 'radio_photon_2nd', 'history_of_heart_disease', 'chemo_adjuvant', 'rs1788750', 'chemo_neo_adjuvant', 'rs633502', 'tumour_histological_grade', 'rs57288348', 't_stage', 'rs61912468', 'rs10764743', 'hypertension', 'alcohol_intake', 'surgery_type', 'rs79223472']
#
#
# Mean AUC score using top 40 features: 0.9001
#
# 	********************************************************************************************************************************************************************

# %% [markdown]
# Takeaways2: Based on the features that only has less than 20% missing values:
#
# * Mean AUC score using top 10 features: 0.8299
#
# * Mean AUC score using top 15 features: 0.8710
#
# * Mean AUC score using top 20 features: 0.9213
#
# * Mean AUC score using top 25 features: 0.9184
#
# * Mean AUC score using top 30 features: 0.9086

# %%
from collections import Counter

def get_stable_features(feature_sets, threshold_ratio=0.8):
    """
    Select features appearing in at least threshold_ratio of the sets.

    Parameters
    ----------
    feature_sets : dict
        Format:
        {
            k: (dataframe, auc_score)
        }

    threshold_ratio : float
        Minimum proportion of sets a feature must appear in.
        Example:
            0.8 = 80%

    Returns
    -------
    list
        Stable feature names only
    """

    feature_counter = Counter()

    n_sets = len(feature_sets)

    for k, (df, auc) in feature_sets.items():

        # Get top-k features based on score
        top_features = (
            df.sort_values('Score', ascending=False)
              .head(k)['TopFeat']
              .tolist()
        )

        feature_counter.update(top_features)

    threshold = int(threshold_ratio * n_sets)

    stable_features = [
        feature for feature, count in feature_counter.items()
        if count >= threshold
    ]

    return stable_features

# %%
stable_features_univariate_nonscaled = get_stable_features(
    feature_sets_univariate_nonscaled,
    threshold_ratio=0.8
)

print(stable_features_univariate_nonscaled)
print ('Number of features', len(stable_features_univariate_nonscaled))
# Out:
# ['radio_breast_ct_volume_cm3', 'nodes_examined', 'breast_right_arm_circumfrence_mm_baseline', 'radio_heart_mean_dose_Gy', 'nodes_involved', 'axillary_levels', 'breast_arm_lymphodema_baseline', 'radio_supraclavicular_fossa', 'post_operative_haematoma', 'rs67342194', 'rs72857489', 'rs56402833', 'radio_ipsilateral_lung_mean_Gy', 'breast_swollen_arm_baseline', 'rs74853756', 'tumour_quadrant', 'rs7195405', 'tumour_size_mm', 'rs461769', 'rs10945395']
# Number of features 20

# %%
cross_validated_feature_selection(df_clean_20[stable_features_univariate_nonscaled + [dependent1]], dependent1, 10)
# Out:
# Original Data shape is (2067, 21)
# Data shape after dropping missing target: (1691, 21)
# ✅ Mean AUC with final selected features: 0.8787

# %% [markdown]
# ### scaled

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import MinMaxScaler
from collections import Counter
import matplotlib.pyplot as plt
from tabulate import tabulate
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# this function same as above week performance but with scaling
# Done on whole dataset, with scaling, Data Leakage, Overestimates true performance due to leakage.

def featureselection1_scaled(df, dependent, k):
    # Drop rows with missing values
    df = df.dropna(axis=0, how='any')

    # Separate features and target variable
    X = df.drop(columns=[dependent, 'Subject Id'])
    y = df[dependent]

    # Convert categorical variables into numeric
    X = pd.get_dummies(X, drop_first=True)
    # Keep only numeric features and scale for Chi2
    #X = X.select_dtypes(include=['number'])
    X_scaled = pd.DataFrame(MinMaxScaler().fit_transform(X), columns=X.columns)

    # Apply Chi2 feature selection
    selector = SelectKBest(score_func=chi2, k=k)
    selector.fit(X_scaled, y)

    # Score and extract top features
    scores = selector.scores_
    # Create a DataFrame for all features and their scores
    all_features_scores = pd.DataFrame({
        'TopFeat': X.columns,
        'Score': scores
    })
    # Select the top k features for plotting/printing
    top_k_features_for_display = all_features_scores.nlargest(k, 'Score')

    selected_features = top_k_features_for_display['TopFeat'].tolist()

    # Plot
    plt.figure(figsize=(10, 8))
    plt.barh(top_k_features_for_display['TopFeat'], top_k_features_for_display['Score'], color='skyblue')
    plt.xlabel('Score')
    plt.title(f'Top {k} Features selected by Chi-Squared')
    plt.gca().invert_yaxis()
    plt.show()

    # Print results
    print(tabulate(top_k_features_for_display, headers='keys', tablefmt='psql'))
    print(f"\nList of top {k} features:\n", selected_features, '\n\n')

    # Prepare data with selected features only
    X_selected = X_scaled[selected_features]

    # Build pipeline and evaluate using cross-validation
    pipeline = Pipeline([
        ('classifier', RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=1,bootstrap=True, random_state=5))
    ])

    # Use StratifiedKFold and calculate mean AUC
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
    auc_scores = cross_val_score(pipeline, X_selected, y, cv=skf, scoring='roc_auc')

    print(f"Mean AUC score using top {k} features: {auc_scores.mean():.4f}")
    print("\n\t********************************************************************************************************************************************************************")
    return all_features_scores, auc_scores.mean() # Ensure this returns a DataFrame as the first element

# %%
feature_sets_univariate_scaled = {}

for i in k:
    freq_df_scaled_auc= featureselection1_scaled(df_clean_20, dependent1, k=i)
    feature_sets_univariate_scaled[i] = freq_df_scaled_auc
# Out:
# +----+--------------------------------+----------+
# |    | TopFeat                        |    Score |
# |----+--------------------------------+----------|
# | 55 | radio_supraclavicular_fossa    | 21       |
# | 73 | breast_swollen_arm_baseline    | 11.83    |
# | 69 | breast_arm_lymphodema_baseline | 10.8375  |
# | 25 | post_operative_haematoma       |  8.6605  |
# | 76 | rs67342194                     |  8.05045 |
# | 24 | nodes_examined                 |  7.54064 |
# | 94 | rs72857489                     |  7.45677 |
# | 85 | rs56402833                     |  6.54087 |
# | 18 | analgesics                     |  5.6     |
# |  7 | diabetes                       |  5.28125 |
# +----+--------------------------------+----------+
#
# List of top 10 features:
#  ['radio_supraclavicular_fossa', 'breast_swollen_arm_baseline', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs67342194', 'nodes_examined', 'rs72857489', 'rs56402833', 'analgesics', 'diabetes']
#
#
# Mean AUC score using top 10 features: 0.8274
#
# 	********************************************************************************************************************************************************************
# +----+--------------------------------+----------+
# |    | TopFeat                        |    Score |
# |----+--------------------------------+----------|
# | 55 | radio_supraclavicular_fossa    | 21       |
# | 73 | breast_swollen_arm_baseline    | 11.83    |
# | 69 | breast_arm_lymphodema_baseline | 10.8375  |
# | 25 | post_operative_haematoma       |  8.6605  |
# | 76 | rs67342194                     |  8.05045 |
# | 24 | nodes_examined                 |  7.54064 |
# | 94 | rs72857489                     |  7.45677 |
# | 85 | rs56402833                     |  6.54087 |
# | 18 | analgesics                     |  5.6     |
# |  7 | diabetes                       |  5.28125 |
# | 54 | axillary_levels                |  4.64242 |
# | 90 | rs74853756                     |  4.1209  |
# | 58 | radio_photon_2nd               |  4.05235 |
# |  8 | history_of_heart_disease       |  4       |
# | 39 | chemo_adjuvant                 |  3.77978 |
# +----+--------------------------------+----------+
#
# List of top 15 features:
#  ['radio_supraclavicular_fossa', 'breast_swollen_arm_baseline', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs67342194', 'nodes_examined', 'rs72857489', 'rs56402833', 'analgesics', 'diabetes', 'axillary_levels', 'rs74853756', 'radio_photon_2nd', 'history_of_heart_disease', 'chemo_adjuvant']
#
#
# Mean AUC score using top 15 features: 0.8577
#
# 	********************************************************************************************************************************************************************
# +----+--------------------------------+----------+
# |    | TopFeat                        |    Score |
# |----+--------------------------------+----------|
# | 55 | radio_supraclavicular_fossa    | 21       |
# | 73 | breast_swollen_arm_baseline    | 11.83    |
# | 69 | breast_arm_lymphodema_baseline | 10.8375  |
# | 25 | post_operative_haematoma       |  8.6605  |
# | 76 | rs67342194                     |  8.05045 |
# | 24 | nodes_examined                 |  7.54064 |
# | 94 | rs72857489                     |  7.45677 |
# | 85 | rs56402833                     |  6.54087 |
# | 18 | analgesics                     |  5.6     |
# |  7 | diabetes                       |  5.28125 |
# | 54 | axillary_levels                |  4.64242 |
# | 90 | rs74853756                     |  4.1209  |
# | 58 | radio_photon_2nd               |  4.05235 |
# |  8 | history_of_heart_disease       |  4       |
# | 39 | chemo_adjuvant                 |  3.77978 |
# | 79 | rs7195405                      |  3.30694 |
# | 75 | rs77405610                     |  3.26049 |
# | 38 | chemo_neo_adjuvant             |  3.2     |
# | 23 | nodes_involved                 |  2.99688 |
# | 92 | rs461769                       |  2.96534 |
# +----+--------------------------------+----------+
#
# List of top 20 features:
#  ['radio_supraclavicular_fossa', 'breast_swollen_arm_baseline', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs67342194', 'nodes_examined', 'rs72857489', 'rs56402833', 'analgesics', 'diabetes', 'axillary_levels', 'rs74853756', 'radio_photon_2nd', 'history_of_heart_disease', 'chemo_adjuvant', 'rs7195405', 'rs77405610', 'chemo_neo_adjuvant', 'nodes_involved', 'rs461769']
#
#
# Mean AUC score using top 20 features: 0.8671
#
# 	********************************************************************************************************************************************************************
# +----+--------------------------------+----------+
# |    | TopFeat                        |    Score |
# |----+--------------------------------+----------|
# | 55 | radio_supraclavicular_fossa    | 21       |
# | 73 | breast_swollen_arm_baseline    | 11.83    |
# | 69 | breast_arm_lymphodema_baseline | 10.8375  |
# | 25 | post_operative_haematoma       |  8.6605  |
# | 76 | rs67342194                     |  8.05045 |
# | 24 | nodes_examined                 |  7.54064 |
# | 94 | rs72857489                     |  7.45677 |
# | 85 | rs56402833                     |  6.54087 |
# | 18 | analgesics                     |  5.6     |
# |  7 | diabetes                       |  5.28125 |
# | 54 | axillary_levels                |  4.64242 |
# | 90 | rs74853756                     |  4.1209  |
# | 58 | radio_photon_2nd               |  4.05235 |
# |  8 | history_of_heart_disease       |  4       |
# | 39 | chemo_adjuvant                 |  3.77978 |
# | 79 | rs7195405                      |  3.30694 |
# | 75 | rs77405610                     |  3.26049 |
# | 38 | chemo_neo_adjuvant             |  3.2     |
# | 23 | nodes_involved                 |  2.99688 |
# | 92 | rs461769                       |  2.96534 |
# | 91 | rs10945395                     |  2.91175 |
# | 81 | rs2954007                      |  2.88947 |
# | 12 | hypertension                   |  2.738   |
# | 22 | surgery_type                   |  2.7075  |
# | 48 | radio_hot_spots_107            |  2.62656 |
# +----+--------------------------------+----------+
#
# List of top 25 features:
#  ['radio_supraclavicular_fossa', 'breast_swollen_arm_baseline', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs67342194', 'nodes_examined', 'rs72857489', 'rs56402833', 'analgesics', 'diabetes', 'axillary_levels', 'rs74853756', 'radio_photon_2nd', 'history_of_heart_disease', 'chemo_adjuvant', 'rs7195405', 'rs77405610', 'chemo_neo_adjuvant', 'nodes_involved', 'rs461769', 'rs10945395', 'rs2954007', 'hypertension', 'surgery_type', 'radio_hot_spots_107']
#
#
# Mean AUC score using top 25 features: 0.8914
#
# 	********************************************************************************************************************************************************************
# +----+---------------------------------------------------+----------+
# |    | TopFeat                                           |    Score |
# |----+---------------------------------------------------+----------|
# | 55 | radio_supraclavicular_fossa                       | 21       |
# | 73 | breast_swollen_arm_baseline                       | 11.83    |
# | 69 | breast_arm_lymphodema_baseline                    | 10.8375  |
# | 25 | post_operative_haematoma                          |  8.6605  |
# | 76 | rs67342194                                        |  8.05045 |
# | 24 | nodes_examined                                    |  7.54064 |
# | 94 | rs72857489                                        |  7.45677 |
# | 85 | rs56402833                                        |  6.54087 |
# | 18 | analgesics                                        |  5.6     |
# |  7 | diabetes                                          |  5.28125 |
# | 54 | axillary_levels                                   |  4.64242 |
# | 90 | rs74853756                                        |  4.1209  |
# | 58 | radio_photon_2nd                                  |  4.05235 |
# |  8 | history_of_heart_disease                          |  4       |
# | 39 | chemo_adjuvant                                    |  3.77978 |
# | 79 | rs7195405                                         |  3.30694 |
# | 75 | rs77405610                                        |  3.26049 |
# | 38 | chemo_neo_adjuvant                                |  3.2     |
# | 23 | nodes_involved                                    |  2.99688 |
# | 92 | rs461769                                          |  2.96534 |
# | 91 | rs10945395                                        |  2.91175 |
# | 81 | rs2954007                                         |  2.88947 |
# | 12 | hypertension                                      |  2.738   |
# | 22 | surgery_type                                      |  2.7075  |
# | 48 | radio_hot_spots_107                               |  2.62656 |
# | 46 | radio_heart_mean_dose_Gy                          |  2.43057 |
# | 13 | depression                                        |  2.3625  |
# | 28 | delayed_healing                                   |  2.1125  |
# | 65 | breast_telangiectasia_outside_tumour_bed_baseline |  1.875   |
# | 77 | rs1788750                                         |  1.71734 |
# +----+---------------------------------------------------+----------+
#
# List of top 30 features:
#  ['radio_supraclavicular_fossa', 'breast_swollen_arm_baseline', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs67342194', 'nodes_examined', 'rs72857489', 'rs56402833', 'analgesics', 'diabetes', 'axillary_levels', 'rs74853756', 'radio_photon_2nd', 'history_of_heart_disease', 'chemo_adjuvant', 'rs7195405', 'rs77405610', 'chemo_neo_adjuvant', 'nodes_involved', 'rs461769', 'rs10945395', 'rs2954007', 'hypertension', 'surgery_type', 'radio_hot_spots_107', 'radio_heart_mean_dose_Gy', 'depression', 'delayed_healing', 'breast_telangiectasia_outside_tumour_bed_baseline', 'rs1788750']
#
#
# Mean AUC score using top 30 features: 0.9223
#
# 	********************************************************************************************************************************************************************
# +----+---------------------------------------------------+----------+
# |    | TopFeat                                           |    Score |
# |----+---------------------------------------------------+----------|
# | 55 | radio_supraclavicular_fossa                       | 21       |
# | 73 | breast_swollen_arm_baseline                       | 11.83    |
# | 69 | breast_arm_lymphodema_baseline                    | 10.8375  |
# | 25 | post_operative_haematoma                          |  8.6605  |
# | 76 | rs67342194                                        |  8.05045 |
# | 24 | nodes_examined                                    |  7.54064 |
# | 94 | rs72857489                                        |  7.45677 |
# | 85 | rs56402833                                        |  6.54087 |
# | 18 | analgesics                                        |  5.6     |
# |  7 | diabetes                                          |  5.28125 |
# | 54 | axillary_levels                                   |  4.64242 |
# | 90 | rs74853756                                        |  4.1209  |
# | 58 | radio_photon_2nd                                  |  4.05235 |
# |  8 | history_of_heart_disease                          |  4       |
# | 39 | chemo_adjuvant                                    |  3.77978 |
# | 79 | rs7195405                                         |  3.30694 |
# | 75 | rs77405610                                        |  3.26049 |
# | 38 | chemo_neo_adjuvant                                |  3.2     |
# | 23 | nodes_involved                                    |  2.99688 |
# | 92 | rs461769                                          |  2.96534 |
# | 91 | rs10945395                                        |  2.91175 |
# | 81 | rs2954007                                         |  2.88947 |
# | 12 | hypertension                                      |  2.738   |
# | 22 | surgery_type                                      |  2.7075  |
# | 48 | radio_hot_spots_107                               |  2.62656 |
# | 46 | radio_heart_mean_dose_Gy                          |  2.43057 |
# | 13 | depression                                        |  2.3625  |
# | 28 | delayed_healing                                   |  2.1125  |
# | 65 | breast_telangiectasia_outside_tumour_bed_baseline |  1.875   |
# | 77 | rs1788750                                         |  1.71734 |
# | 26 | post_operative_oedema                             |  1.58689 |
# | 86 | rs633502                                          |  1.57704 |
# | 31 | tumour_histological_grade                         |  1.56938 |
# | 14 | ace_inhibitor                                     |  1.49113 |
# | 82 | rs57288348                                        |  1.48131 |
# +----+---------------------------------------------------+----------+
#
# List of top 35 features:
#  ['radio_supraclavicular_fossa', 'breast_swollen_arm_baseline', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs67342194', 'nodes_examined', 'rs72857489', 'rs56402833', 'analgesics', 'diabetes', 'axillary_levels', 'rs74853756', 'radio_photon_2nd', 'history_of_heart_disease', 'chemo_adjuvant', 'rs7195405', 'rs77405610', 'chemo_neo_adjuvant', 'nodes_involved', 'rs461769', 'rs10945395', 'rs2954007', 'hypertension', 'surgery_type', 'radio_hot_spots_107', 'radio_heart_mean_dose_Gy', 'depression', 'delayed_healing', 'breast_telangiectasia_outside_tumour_bed_baseline', 'rs1788750', 'post_operative_oedema', 'rs633502', 'tumour_histological_grade', 'ace_inhibitor', 'rs57288348']
#
#
# Mean AUC score using top 35 features: 0.8934
#
# 	********************************************************************************************************************************************************************
# +----+---------------------------------------------------+----------+
# |    | TopFeat                                           |    Score |
# |----+---------------------------------------------------+----------|
# | 55 | radio_supraclavicular_fossa                       | 21       |
# | 73 | breast_swollen_arm_baseline                       | 11.83    |
# | 69 | breast_arm_lymphodema_baseline                    | 10.8375  |
# | 25 | post_operative_haematoma                          |  8.6605  |
# | 76 | rs67342194                                        |  8.05045 |
# | 24 | nodes_examined                                    |  7.54064 |
# | 94 | rs72857489                                        |  7.45677 |
# | 85 | rs56402833                                        |  6.54087 |
# | 18 | analgesics                                        |  5.6     |
# |  7 | diabetes                                          |  5.28125 |
# | 54 | axillary_levels                                   |  4.64242 |
# | 90 | rs74853756                                        |  4.1209  |
# | 58 | radio_photon_2nd                                  |  4.05235 |
# |  8 | history_of_heart_disease                          |  4       |
# | 39 | chemo_adjuvant                                    |  3.77978 |
# | 79 | rs7195405                                         |  3.30694 |
# | 75 | rs77405610                                        |  3.26049 |
# | 38 | chemo_neo_adjuvant                                |  3.2     |
# | 23 | nodes_involved                                    |  2.99688 |
# | 92 | rs461769                                          |  2.96534 |
# | 91 | rs10945395                                        |  2.91175 |
# | 81 | rs2954007                                         |  2.88947 |
# | 12 | hypertension                                      |  2.738   |
# | 22 | surgery_type                                      |  2.7075  |
# | 48 | radio_hot_spots_107                               |  2.62656 |
# | 46 | radio_heart_mean_dose_Gy                          |  2.43057 |
# | 13 | depression                                        |  2.3625  |
# | 28 | delayed_healing                                   |  2.1125  |
# | 65 | breast_telangiectasia_outside_tumour_bed_baseline |  1.875   |
# | 77 | rs1788750                                         |  1.71734 |
# | 26 | post_operative_oedema                             |  1.58689 |
# | 86 | rs633502                                          |  1.57704 |
# | 31 | tumour_histological_grade                         |  1.56938 |
# | 14 | ace_inhibitor                                     |  1.49113 |
# | 82 | rs57288348                                        |  1.48131 |
# | 93 | rs61912468                                        |  1.44698 |
# | 78 | rs10764743                                        |  1.4337  |
# | 64 | breast_telangiectasia_tumour_bed_baseline         |  1.4     |
# | 89 | rs79223472                                        |  1.3508  |
# | 84 | rs72977387                                        |  1.34452 |
# +----+---------------------------------------------------+----------+
#
# List of top 40 features:
#  ['radio_supraclavicular_fossa', 'breast_swollen_arm_baseline', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs67342194', 'nodes_examined', 'rs72857489', 'rs56402833', 'analgesics', 'diabetes', 'axillary_levels', 'rs74853756', 'radio_photon_2nd', 'history_of_heart_disease', 'chemo_adjuvant', 'rs7195405', 'rs77405610', 'chemo_neo_adjuvant', 'nodes_involved', 'rs461769', 'rs10945395', 'rs2954007', 'hypertension', 'surgery_type', 'radio_hot_spots_107', 'radio_heart_mean_dose_Gy', 'depression', 'delayed_healing', 'breast_telangiectasia_outside_tumour_bed_baseline', 'rs1788750', 'post_operative_oedema', 'rs633502', 'tumour_histological_grade', 'ace_inhibitor', 'rs57288348', 'rs61912468', 'rs10764743', 'breast_telangiectasia_tumour_bed_baseline', 'rs79223472', 'rs72977387']
#
#
# Mean AUC score using top 40 features: 0.9010
#
# 	********************************************************************************************************************************************************************

# %% [markdown]
# Takeaways: After scaling Based on the features that only has less than 20% missing values:
#
# * Mean AUC score using top 10 features: 0.8274
#
# * Mean AUC score using top 15 features: 0.8577
#
# * Mean AUC score using top 20 features: 0.8671
#
# * Mean AUC score using top 25 features: 0.8914
#
# * Mean AUC score using top 30 features: 0.9223
#
#
# AUC Dropped After Scaling overall, for example 0.9213 → 0.8671 (20 features)
# This often happens because:
# * the unscaled method overfit to magnitude-driven leakage
# * huge-valued variables dominated
# * CV became overly optimistic
#
# The scaled version likely reflects reality better because:
#
# * Chi² becomes biased toward large numeric ranges
# * scores become distorted
#
# But still has data leackage which means:
#
# * feature selection sees the ENTIRE dataset
# * including future validation folds

# %%
stable_features_univariate_scaled = get_stable_features(
    feature_sets_univariate_scaled,
    threshold_ratio=0.8
)

print(stable_features_univariate_scaled)
print ('Number of features', len(stable_features_univariate_scaled))
# Out:
# ['radio_supraclavicular_fossa', 'breast_swollen_arm_baseline', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs67342194', 'nodes_examined', 'rs72857489', 'rs56402833', 'analgesics', 'diabetes', 'axillary_levels', 'rs74853756', 'radio_photon_2nd', 'history_of_heart_disease', 'chemo_adjuvant', 'rs7195405', 'rs77405610', 'chemo_neo_adjuvant', 'nodes_involved', 'rs461769']
# Number of features 20

# %%
cross_validated_feature_selection(df_clean_20[stable_features_univariate_scaled + [dependent1]], dependent1, 10)
# Out:
# Original Data shape is (2067, 21)
# Data shape after dropping missing target: (1691, 21)
# ✅ Mean AUC with final selected features: 0.8784

# %% [markdown]
# ### inside CV

# %%
# ✅ Inside CV folds	✅ Yes With scaling	✅ Clean no leakage	📉 True estimate of performance

def featureselection1_pipeline_auc(df, dependent, k):
    df = df.dropna()

    # Separate features and target variable
    X = df.drop(columns=[dependent, 'Subject Id'])
    y = df[dependent]

    # Convert categorical variables into numeric
    X = pd.get_dummies(X, drop_first=True)

    # Build pipeline with scaling, feature selection, and classification
    pipeline = Pipeline([
        ('scaler', MinMaxScaler()),
        ('selectk', SelectKBest(score_func=chi2, k=k)),
        ('classifier', RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=1,bootstrap=True, random_state=5))
    ])

    # Cross-validation setup
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
    auc_scores = cross_val_score(pipeline, X, y, cv=skf, scoring='roc_auc')

    print(f"Mean AUC score using top {k} features (Inside CV): {auc_scores.mean():.2f}")
    return auc_scores.mean()

# %%
# This is the one I took for my feature selection heatmap # The results may vary because I filled remove all missing data and the data could be small
# without seening any features_quick way to see the results
for i in k:
  Mean_auc_scores_CV_inside_pipeline= featureselection1_pipeline_auc(df_clean_20, dependent1, k=i)
# Out:
# Mean AUC score using top 10 features (Inside CV): 0.83
# Mean AUC score using top 15 features (Inside CV): 0.83
# Mean AUC score using top 20 features (Inside CV): 0.83
# Mean AUC score using top 25 features (Inside CV): 0.86
# Mean AUC score using top 30 features (Inside CV): 0.87
# Mean AUC score using top 35 features (Inside CV): 0.84
# Mean AUC score using top 40 features (Inside CV): 0.87

# %% [markdown]
# * Mean AUC score using top 10 features (no leakage): 0.83
#
# * Mean AUC score using top 15 features (no leakage): 0.83
#
# * Mean AUC score using top 20 features (no leakage): 0.83
#
# * Mean AUC score using top 25 features (no leakage): 0.86
#
# * Mean AUC score using top 30 features (no leakage): 0.87

# %% [markdown]
# **Takeaways4,** in above analysis this is a real and true feature selection as only happens in the training set,,, But there is an issue because  it is not only model building I need to look at the important features and observe their importance.

# %% [markdown]
# ### features frequency inside Pipeline

# %%
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import MinMaxScaler
from collections import Counter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

def featureselection1_scaled_inside_pipeline(df, dependent, k, n_splits):
    df = df.dropna(axis=0, how='any')
    # Separate features and target variable
    X = df.drop(columns=[dependent, 'Subject Id'])
    y = df[dependent]

    # Convert categorical variables into numeric
    X = pd.get_dummies(X, drop_first=True)

    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=0)
    feature_counter = Counter()
    auc_scores = []

    #bold("Choosing " + str(k) + " Features:\n")

    for fold_idx, (train_index, test_index) in enumerate(skf.split(X, y), start=1):

        X_train, y_train = X.iloc[train_index], y.iloc[train_index]
        X_test, y_test = X.iloc[test_index], y.iloc[test_index]

        # Apply Chi2 on training fold
        pipeline = Pipeline([
            ('scaler', MinMaxScaler()),
            ('feature_selection', SelectKBest(score_func=chi2, k=k)),
            ('model', RandomForestClassifier(
                n_estimators=100,
                max_depth=10,
                min_samples_split=5,
                min_samples_leaf=1,
                bootstrap=True,
                random_state=5
            ))
        ])

        pipeline.fit(X_train, y_train)

        # Get predicted probabilities for AUC calculation
        y_prob = pipeline.predict_proba(X_test)[:, 1]
        auc = roc_auc_score(y_test, y_prob)
        auc_scores.append(auc)

        selected_mask = pipeline.named_steps['feature_selection'].get_support()
        selected_features = X.columns[selected_mask].tolist()

        feature_counter.update(selected_features)

        print(
            f"Fold {fold_idx}: Selected features: {selected_features} | AUC: {auc:.4f}"
        )

    # Calculate the mean AUC
    mean_auc = np.mean(auc_scores)
    print(f"\nMean AUC using top {k} features across {n_splits} folds: {mean_auc:.4f}\n")

    # Convert to DataFrame
    freq_df = pd.DataFrame.from_dict(feature_counter, orient='index', columns=['Frequency'])
    freq_df = freq_df.sort_values(by='Frequency', ascending=False)

    # Plot feature frequency
    plt.figure(figsize=(10, 12))
    sns.barplot(x='Frequency', y=freq_df.index, data=freq_df, palette='magma')
    plt.xlabel('Selection Frequency')
    plt.ylabel('KBest Features')
    plt.title(f'Chi2 Feature Selection Frequency Across {n_splits} Folds (Top {k} features/fold)')
    plt.xticks(np.arange(0, n_splits+1, 1))
    plt.show()

    print(tabulate(freq_df, headers='keys', tablefmt='psql'))
    top_features_final = freq_df.head(k).index.tolist()

    print(f"Top {k} most frequently Features across {n_splits} folds:", top_features_final)
    #print(top_features_final)
    print("\n\t*****************************************************************************************************************************************************************\n\n")

    return freq_df, mean_auc

# %%
feature_sets_univariate_scaled_inside_pipeline = {}

for i in k:
    freq_df_scaled_auc= featureselection1_scaled_inside_pipeline(df_clean_20, dependent1, k=i, n_splits=10)
    feature_sets_univariate_scaled_inside_pipeline[i] = freq_df_scaled_auc
# Out:
# Fold 1: Selected features: ['history_of_heart_disease', 'nodes_examined', 'post_operative_haematoma', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs72857489'] | AUC: 0.9338
# Fold 2: Selected features: ['diabetes', 'analgesics', 'nodes_examined', 'post_operative_haematoma', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs72857489'] | AUC: 0.8162
# Fold 3: Selected features: ['history_of_heart_disease', 'nodes_examined', 'post_operative_haematoma', 'chemo_adjuvant', 'axillary_levels', 'radio_supraclavicular_fossa', 'rs67342194', 'rs56402833', 'rs74853756', 'rs72857489'] | AUC: 0.6765
# Fold 4: Selected features: ['diabetes', 'nodes_examined', 'post_operative_haematoma', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs72857489'] | AUC: 0.7335
# Fold 5: Selected features: ['diabetes', 'analgesics', 'nodes_examined', 'post_operative_haematoma', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs72857489'] | AUC: 0.9363
# Fold 6: Selected features: ['diabetes', 'analgesics', 'nodes_examined', 'post_operative_haematoma', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs72857489'] | AUC: 0.7794
# Fold 7: Selected features: ['nodes_examined', 'post_operative_haematoma', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs72857489'] | AUC: 0.9657
# Fold 8: Selected features: ['diabetes', 'analgesics', 'nodes_examined', 'post_operative_haematoma', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs72857489'] | AUC: 0.8578
# Fold 9: Selected features: ['analgesics', 'nodes_examined', 'post_operative_haematoma', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs72857489'] | AUC: 0.7696
# Fold 10: Selected features: ['nodes_examined', 'post_operative_haematoma', 'chemo_adjuvant', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs72857489'] | AUC: 0.8480
#
# Mean AUC using top 10 features across 10 folds: 0.8317
# +--------------------------------+-------------+
# |                                |   Frequency |
# |--------------------------------+-------------|
# | nodes_examined                 |          10 |
# | post_operative_haematoma       |          10 |
# | radio_supraclavicular_fossa    |          10 |
# | rs72857489                     |          10 |
# | rs67342194                     |          10 |
# | breast_swollen_arm_baseline    |           9 |
# | breast_arm_lymphodema_baseline |           9 |
# | rs56402833                     |           9 |
# | axillary_levels                |           6 |
# | diabetes                       |           5 |
# | analgesics                     |           5 |
# | radio_photon_2nd               |           2 |
# | history_of_heart_disease       |           2 |
# | chemo_adjuvant                 |           2 |
# | rs74853756                     |           1 |
# +--------------------------------+-------------+
# Top 10 most frequently Features across 10 folds: ['nodes_examined', 'post_operative_haematoma', 'radio_supraclavicular_fossa', 'rs72857489', 'rs67342194', 'breast_swollen_arm_baseline', 'breast_arm_lymphodema_baseline', 'rs56402833', 'axillary_levels', 'diabetes']
#
# 	*****************************************************************************************************************************************************************
#
#
# Fold 1: Selected features: ['diabetes', 'history_of_heart_disease', 'analgesics', 'surgery_type', 'nodes_examined', 'post_operative_haematoma', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs74853756', 'rs10945395', 'rs72857489'] | AUC: 0.9265
# Fold 2: Selected features: ['diabetes', 'hypertension', 'analgesics', 'nodes_examined', 'post_operative_haematoma', 'chemo_adjuvant', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs56402833', 'rs74853756', 'rs72857489'] | AUC: 0.8566
# Fold 3: Selected features: ['diabetes', 'history_of_heart_disease', 'nodes_examined', 'post_operative_haematoma', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'rs77405610', 'rs67342194', 'rs56402833', 'rs74853756', 'rs10945395', 'rs72857489'] | AUC: 0.8051
# Fold 4: Selected features: ['diabetes', 'history_of_heart_disease', 'analgesics', 'nodes_examined', 'post_operative_haematoma', 'chemo_neo_adjuvant', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs72857489'] | AUC: 0.7426
# Fold 5: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'analgesics', 'nodes_examined', 'post_operative_haematoma', 'chemo_adjuvant', 'radio_hot_spots_107', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs72857489'] | AUC: 0.9216
# Fold 6: Selected features: ['diabetes', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'chemo_neo_adjuvant', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs56402833', 'rs74853756', 'rs72857489'] | AUC: 0.7990
# Fold 7: Selected features: ['diabetes', 'history_of_heart_disease', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs461769', 'rs72857489'] | AUC: 0.9363
# Fold 8: Selected features: ['diabetes', 'analgesics', 'nodes_examined', 'post_operative_haematoma', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs74853756', 'rs72857489'] | AUC: 0.8529
# Fold 9: Selected features: ['depression', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs74853756', 'rs72857489'] | AUC: 0.7843
# Fold 10: Selected features: ['analgesics', 'nodes_examined', 'post_operative_haematoma', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs7195405', 'rs56402833', 'rs10945395', 'rs72857489'] | AUC: 0.7083
#
# Mean AUC using top 15 features across 10 folds: 0.8333
# +--------------------------------+-------------+
# |                                |   Frequency |
# |--------------------------------+-------------|
# | nodes_examined                 |          10 |
# | radio_supraclavicular_fossa    |          10 |
# | post_operative_haematoma       |          10 |
# | rs56402833                     |          10 |
# | rs67342194                     |          10 |
# | rs72857489                     |          10 |
# | breast_swollen_arm_baseline    |           9 |
# | breast_arm_lymphodema_baseline |           9 |
# | analgesics                     |           9 |
# | diabetes                       |           8 |
# | axillary_levels                |           7 |
# | radio_photon_2nd               |           6 |
# | rs74853756                     |           6 |
# | chemo_neo_adjuvant             |           6 |
# | chemo_adjuvant                 |           6 |
# | history_of_heart_disease       |           5 |
# | nodes_involved                 |           3 |
# | rs77405610                     |           3 |
# | rs10945395                     |           3 |
# | radio_hot_spots_107            |           3 |
# | hypertension                   |           2 |
# | rs7195405                      |           2 |
# | surgery_type                   |           1 |
# | rs461769                       |           1 |
# | depression                     |           1 |
# +--------------------------------+-------------+
# Top 15 most frequently Features across 10 folds: ['nodes_examined', 'radio_supraclavicular_fossa', 'post_operative_haematoma', 'rs56402833', 'rs67342194', 'rs72857489', 'breast_swollen_arm_baseline', 'breast_arm_lymphodema_baseline', 'analgesics', 'diabetes', 'axillary_levels', 'radio_photon_2nd', 'rs74853756', 'chemo_neo_adjuvant', 'chemo_adjuvant']
#
# 	*****************************************************************************************************************************************************************
#
#
# Fold 1: Selected features: ['diabetes', 'history_of_heart_disease', 'analgesics', 'surgery_type', 'nodes_examined', 'post_operative_haematoma', 'chemo_adjuvant', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs74853756', 'rs10945395', 'rs72857489'] | AUC: 0.8456
# Fold 2: Selected features: ['diabetes', 'hypertension', 'ace_inhibitor', 'analgesics', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs56402833', 'rs74853756', 'rs461769', 'rs72857489'] | AUC: 0.8529
# Fold 3: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_outside_tumour_bed_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489'] | AUC: 0.7904
# Fold 4: Selected features: ['diabetes', 'history_of_heart_disease', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'chemo_neo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs56402833', 'rs74853756', 'rs72857489'] | AUC: 0.6710
# Fold 5: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'analgesics', 'nodes_examined', 'post_operative_haematoma', 'chemo_adjuvant', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs56402833', 'rs74853756', 'rs72857489'] | AUC: 0.9118
# Fold 6: Selected features: ['diabetes', 'history_of_heart_disease', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'chemo_neo_adjuvant', 'radio_heart_mean_dose_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs74853756', 'rs10945395', 'rs72857489'] | AUC: 0.7353
# Fold 7: Selected features: ['diabetes', 'history_of_heart_disease', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'chemo_adjuvant', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs56402833', 'rs74853756', 'rs461769', 'rs72857489'] | AUC: 0.9804
# Fold 8: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs7195405', 'rs56402833', 'rs74853756', 'rs461769', 'rs72857489'] | AUC: 0.8824
# Fold 9: Selected features: ['diabetes', 'history_of_heart_disease', 'depression', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs7195405', 'rs56402833', 'rs74853756', 'rs72857489'] | AUC: 0.8627
# Fold 10: Selected features: ['diabetes', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489'] | AUC: 0.7892
#
# Mean AUC using top 20 features across 10 folds: 0.8322
# +---------------------------------------------------+-------------+
# |                                                   |   Frequency |
# |---------------------------------------------------+-------------|
# | diabetes                                          |          10 |
# | post_operative_haematoma                          |          10 |
# | nodes_examined                                    |          10 |
# | radio_supraclavicular_fossa                       |          10 |
# | rs67342194                                        |          10 |
# | rs74853756                                        |          10 |
# | rs56402833                                        |          10 |
# | rs72857489                                        |          10 |
# | breast_arm_lymphodema_baseline                    |           9 |
# | analgesics                                        |           9 |
# | rs7195405                                         |           9 |
# | breast_swollen_arm_baseline                       |           9 |
# | chemo_adjuvant                                    |           8 |
# | history_of_heart_disease                          |           8 |
# | axillary_levels                                   |           8 |
# | radio_photon_2nd                                  |           8 |
# | rs77405610                                        |           6 |
# | chemo_neo_adjuvant                                |           6 |
# | nodes_involved                                    |           6 |
# | rs461769                                          |           5 |
# | radio_hot_spots_107                               |           4 |
# | breast_telangiectasia_outside_tumour_bed_baseline |           4 |
# | rs10945395                                        |           4 |
# | hypertension                                      |           4 |
# | delayed_healing                                   |           3 |
# | rs2954007                                         |           3 |
# | radio_heart_mean_dose_Gy                          |           3 |
# | surgery_type                                      |           2 |
# | ace_inhibitor                                     |           1 |
# | depression                                        |           1 |
# +---------------------------------------------------+-------------+
# Top 20 most frequently Features across 10 folds: ['diabetes', 'post_operative_haematoma', 'nodes_examined', 'radio_supraclavicular_fossa', 'rs67342194', 'rs74853756', 'rs56402833', 'rs72857489', 'breast_arm_lymphodema_baseline', 'analgesics', 'rs7195405', 'breast_swollen_arm_baseline', 'chemo_adjuvant', 'history_of_heart_disease', 'axillary_levels', 'radio_photon_2nd', 'rs77405610', 'chemo_neo_adjuvant', 'nodes_involved', 'rs461769']
#
# 	*****************************************************************************************************************************************************************
#
#
# Fold 1: Selected features: ['diabetes', 'history_of_heart_disease', 'analgesics', 'surgery_type', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'tumour_locality', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs57288348', 'rs56402833', 'rs74853756', 'rs10945395', 'rs72857489'] | AUC: 0.8493
# Fold 2: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'ace_inhibitor', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'delayed_healing', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs74853756', 'rs461769', 'rs72857489'] | AUC: 0.8934
# Fold 3: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'analgesics', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs57288348', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489'] | AUC: 0.7831
# Fold 4: Selected features: ['diabetes', 'history_of_heart_disease', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'chemo_neo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170'] | AUC: 0.8088
# Fold 5: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'chemo_adjuvant', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs74853756', 'rs461769', 'rs72857489'] | AUC: 0.9314
# Fold 6: Selected features: ['diabetes', 'history_of_heart_disease', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489'] | AUC: 0.8775
# Fold 7: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'chemo_adjuvant', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs74853756', 'rs461769', 'rs61912468', 'rs72857489'] | AUC: 0.9951
# Fold 8: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'ace_inhibitor', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489'] | AUC: 0.8971
# Fold 9: Selected features: ['diabetes', 'history_of_heart_disease', 'depression', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs7195405', 'rs2954007', 'rs57288348', 'rs56402833', 'rs74853756', 'rs461769', 'rs72857489'] | AUC: 0.8725
# Fold 10: Selected features: ['diabetes', 'hypertension', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'er_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs35410275'] | AUC: 0.7304
#
# Mean AUC using top 25 features across 10 folds: 0.8638
# +---------------------------------------------------+-------------+
# |                                                   |   Frequency |
# |---------------------------------------------------+-------------|
# | diabetes                                          |          10 |
# | analgesics                                        |          10 |
# | nodes_examined                                    |          10 |
# | post_operative_haematoma                          |          10 |
# | rs67342194                                        |          10 |
# | rs7195405                                         |          10 |
# | radio_supraclavicular_fossa                       |          10 |
# | rs74853756                                        |          10 |
# | breast_swollen_arm_baseline                       |          10 |
# | rs72857489                                        |          10 |
# | rs56402833                                        |          10 |
# | rs2954007                                         |           9 |
# | chemo_adjuvant                                    |           9 |
# | history_of_heart_disease                          |           9 |
# | breast_arm_lymphodema_baseline                    |           9 |
# | rs461769                                          |           9 |
# | radio_photon_2nd                                  |           8 |
# | axillary_levels                                   |           8 |
# | radio_hot_spots_107                               |           7 |
# | nodes_involved                                    |           7 |
# | delayed_healing                                   |           7 |
# | chemo_neo_adjuvant                                |           7 |
# | radio_heart_mean_dose_Gy                          |           6 |
# | rs77405610                                        |           6 |
# | hypertension                                      |           6 |
# | rs10945395                                        |           6 |
# | surgery_type                                      |           5 |
# | breast_telangiectasia_outside_tumour_bed_baseline |           4 |
# | post_operative_oedema                             |           3 |
# | rs57288348                                        |           3 |
# | ace_inhibitor                                     |           3 |
# | rs61912468                                        |           2 |
# | breast_telangiectasia_tumour_bed_baseline         |           1 |
# | tumour_locality                                   |           1 |
# | rs885170                                          |           1 |
# | depression                                        |           1 |
# | er_status                                         |           1 |
# | radio_treated_breast                              |           1 |
# | rs35410275                                        |           1 |
# +---------------------------------------------------+-------------+
# Top 25 most frequently Features across 10 folds: ['diabetes', 'analgesics', 'nodes_examined', 'post_operative_haematoma', 'rs67342194', 'rs7195405', 'radio_supraclavicular_fossa', 'rs74853756', 'breast_swollen_arm_baseline', 'rs72857489', 'rs56402833', 'rs2954007', 'chemo_adjuvant', 'history_of_heart_disease', 'breast_arm_lymphodema_baseline', 'rs461769', 'radio_photon_2nd', 'axillary_levels', 'radio_hot_spots_107', 'nodes_involved', 'delayed_healing', 'chemo_neo_adjuvant', 'radio_heart_mean_dose_Gy', 'rs77405610', 'hypertension']
#
# 	*****************************************************************************************************************************************************************
#
#
# Fold 1: Selected features: ['diabetes', 'history_of_heart_disease', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'tumour_locality', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs57288348', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489'] | AUC: 0.9301
# Fold 2: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'delayed_healing', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs2954007', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489'] | AUC: 0.9375
# Fold 3: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'analgesics', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'er_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs7195405', 'rs2954007', 'rs57288348', 'rs72977387', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489'] | AUC: 0.7426
# Fold 4: Selected features: ['diabetes', 'history_of_heart_disease', 'depression', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'tumour_locality', 'er_status', 'chemo_neo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170'] | AUC: 0.7684
# Fold 5: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'tumour_histological_grade', 'chemo_adjuvant', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489'] | AUC: 0.9363
# Fold 6: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs72977387', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489'] | AUC: 0.8529
# Fold 7: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'delayed_healing', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs74853756', 'rs461769', 'rs61912468', 'rs72857489'] | AUC: 0.9657
# Fold 8: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'delayed_healing', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs72977387', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489'] | AUC: 0.9167
# Fold 9: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs67342194', 'rs7195405', 'rs2954007', 'rs57288348', 'rs56402833', 'rs79223472', 'rs74853756', 'rs461769', 'rs61912468', 'rs72857489'] | AUC: 0.8824
# Fold 10: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'er_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs35410275'] | AUC: 0.7843
#
# Mean AUC using top 30 features across 10 folds: 0.8717
# +---------------------------------------------------+-------------+
# |                                                   |   Frequency |
# |---------------------------------------------------+-------------|
# | diabetes                                          |          10 |
# | history_of_heart_disease                          |          10 |
# | depression                                        |          10 |
# | analgesics                                        |          10 |
# | post_operative_haematoma                          |          10 |
# | nodes_examined                                    |          10 |
# | rs2954007                                         |          10 |
# | rs56402833                                        |          10 |
# | rs74853756                                        |          10 |
# | rs7195405                                         |          10 |
# | breast_swollen_arm_baseline                       |          10 |
# | radio_supraclavicular_fossa                       |          10 |
# | rs72857489                                        |          10 |
# | rs461769                                          |          10 |
# | rs67342194                                        |          10 |
# | rs77405610                                        |           9 |
# | surgery_type                                      |           9 |
# | nodes_involved                                    |           9 |
# | chemo_adjuvant                                    |           9 |
# | breast_arm_lymphodema_baseline                    |           9 |
# | radio_heart_mean_dose_Gy                          |           8 |
# | axillary_levels                                   |           8 |
# | delayed_healing                                   |           8 |
# | breast_telangiectasia_outside_tumour_bed_baseline |           8 |
# | rs10945395                                        |           8 |
# | hypertension                                      |           8 |
# | radio_photon_2nd                                  |           8 |
# | chemo_neo_adjuvant                                |           7 |
# | radio_hot_spots_107                               |           7 |
# | ace_inhibitor                                     |           5 |
# | post_operative_oedema                             |           5 |
# | rs72977387                                        |           3 |
# | rs61912468                                        |           3 |
# | rs79223472                                        |           3 |
# | rs57288348                                        |           3 |
# | er_status                                         |           3 |
# | tumour_locality                                   |           2 |
# | breast_telangiectasia_tumour_bed_baseline         |           2 |
# | rs1788750                                         |           1 |
# | rs10764743                                        |           1 |
# | rs885170                                          |           1 |
# | tumour_histological_grade                         |           1 |
# | radio_treated_breast                              |           1 |
# | rs35410275                                        |           1 |
# +---------------------------------------------------+-------------+
# Top 30 most frequently Features across 10 folds: ['diabetes', 'history_of_heart_disease', 'depression', 'analgesics', 'post_operative_haematoma', 'nodes_examined', 'rs2954007', 'rs56402833', 'rs74853756', 'rs7195405', 'breast_swollen_arm_baseline', 'radio_supraclavicular_fossa', 'rs72857489', 'rs461769', 'rs67342194', 'rs77405610', 'surgery_type', 'nodes_involved', 'chemo_adjuvant', 'breast_arm_lymphodema_baseline', 'radio_heart_mean_dose_Gy', 'axillary_levels', 'delayed_healing', 'breast_telangiectasia_outside_tumour_bed_baseline', 'rs10945395', 'hypertension', 'radio_photon_2nd', 'chemo_neo_adjuvant', 'radio_hot_spots_107', 'ace_inhibitor']
#
# 	*****************************************************************************************************************************************************************
#
#
# Fold 1: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'tumour_locality', 'tumour_histological_grade', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs56402833', 'rs633502', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489'] | AUC: 0.9007
# Fold 2: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'delayed_healing', 'chemo_adjuvant', 'radio_breast_ct_volume_cm3', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs2954007', 'rs56402833', 'rs633502', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489'] | AUC: 0.9596
# Fold 3: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'analgesics', 'surgery_type', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'tumour_histological_grade', 'er_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs2954007', 'rs57288348', 'rs72977387', 'rs56402833', 'rs633502', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489'] | AUC: 0.7537
# Fold 4: Selected features: ['diabetes', 'history_of_heart_disease', 'depression', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'er_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs56402833', 'rs633502', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170'] | AUC: 0.7702
# Fold 5: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'tumour_histological_grade', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_breast_ct_volume_cm3', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs72977387', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489'] | AUC: 0.9510
# Fold 6: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'tumour_locality', 'tumour_histological_grade', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs7195405', 'rs2954007', 'rs57288348', 'rs72977387', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489'] | AUC: 0.7696
# Fold 7: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'delayed_healing', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs2954007', 'rs56402833', 'rs633502', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489'] | AUC: 0.9755
# Fold 8: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'delayed_healing', 'er_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs2954007', 'rs57288348', 'rs72977387', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170'] | AUC: 0.8088
# Fold 9: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs2954007', 'rs57288348', 'rs56402833', 'rs633502', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489'] | AUC: 0.9559
# Fold 10: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'tumour_histological_grade', 'er_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs2954007', 'rs56402833', 'rs633502', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275'] | AUC: 0.5711
#
# Mean AUC using top 35 features across 10 folds: 0.8416
# +---------------------------------------------------+-------------+
# |                                                   |   Frequency |
# |---------------------------------------------------+-------------|
# | diabetes                                          |          10 |
# | history_of_heart_disease                          |          10 |
# | depression                                        |          10 |
# | analgesics                                        |          10 |
# | surgery_type                                      |          10 |
# | chemo_adjuvant                                    |          10 |
# | post_operative_haematoma                          |          10 |
# | nodes_examined                                    |          10 |
# | radio_heart_mean_dose_Gy                          |          10 |
# | rs2954007                                         |          10 |
# | rs74853756                                        |          10 |
# | rs67342194                                        |          10 |
# | breast_swollen_arm_baseline                       |          10 |
# | rs77405610                                        |          10 |
# | radio_photon_2nd                                  |          10 |
# | radio_supraclavicular_fossa                       |          10 |
# | rs56402833                                        |          10 |
# | rs72857489                                        |          10 |
# | rs461769                                          |          10 |
# | rs10945395                                        |          10 |
# | rs7195405                                         |          10 |
# | nodes_involved                                    |           9 |
# | chemo_neo_adjuvant                                |           9 |
# | hypertension                                      |           9 |
# | breast_arm_lymphodema_baseline                    |           9 |
# | breast_telangiectasia_outside_tumour_bed_baseline |           9 |
# | delayed_healing                                   |           8 |
# | breast_telangiectasia_tumour_bed_baseline         |           8 |
# | axillary_levels                                   |           8 |
# | radio_hot_spots_107                               |           7 |
# | rs633502                                          |           7 |
# | tumour_histological_grade                         |           6 |
# | rs61912468                                        |           5 |
# | post_operative_oedema                             |           5 |
# | ace_inhibitor                                     |           5 |
# | rs57288348                                        |           5 |
# | rs1788750                                         |           5 |
# | rs72977387                                        |           4 |
# | er_status                                         |           4 |
# | rs79223472                                        |           4 |
# | tumour_locality                                   |           3 |
# | rs10764743                                        |           3 |
# | rs885170                                          |           2 |
# | radio_breast_ct_volume_cm3                        |           2 |
# | rs6009631                                         |           1 |
# | tumour_quadrant                                   |           1 |
# | radio_treated_breast                              |           1 |
# | rs35410275                                        |           1 |
# +---------------------------------------------------+-------------+
# Top 35 most frequently Features across 10 folds: ['diabetes', 'history_of_heart_disease', 'depression', 'analgesics', 'surgery_type', 'chemo_adjuvant', 'post_operative_haematoma', 'nodes_examined', 'radio_heart_mean_dose_Gy', 'rs2954007', 'rs74853756', 'rs67342194', 'breast_swollen_arm_baseline', 'rs77405610', 'radio_photon_2nd', 'radio_supraclavicular_fossa', 'rs56402833', 'rs72857489', 'rs461769', 'rs10945395', 'rs7195405', 'nodes_involved', 'chemo_neo_adjuvant', 'hypertension', 'breast_arm_lymphodema_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'delayed_healing', 'breast_telangiectasia_tumour_bed_baseline', 'axillary_levels', 'radio_hot_spots_107', 'rs633502', 'tumour_histological_grade', 'rs61912468', 'post_operative_oedema', 'ace_inhibitor']
#
# 	*****************************************************************************************************************************************************************
#
#
# Fold 1: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs56402833', 'rs633502', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489'] | AUC: 0.9375
# Fold 2: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'post_operative_infection', 'delayed_healing', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'chemo_adjuvant', 'radio_breast_ct_volume_cm3', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs2954007', 'rs56402833', 'rs633502', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489'] | AUC: 0.8971
# Fold 3: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'analgesics', 'surgery_type', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'er_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489'] | AUC: 0.7279
# Fold 4: Selected features: ['smoker', 'diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'tumour_quadrant', 'tumour_locality', 'tumour_histological_grade', 'er_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs2954007', 'rs35035095', 'rs56402833', 'rs633502', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170'] | AUC: 0.7978
# Fold 5: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'tumour_histological_grade', 'er_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_breast_ct_volume_cm3', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs72977387', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489'] | AUC: 0.8824
# Fold 6: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'tumour_locality', 'tumour_histological_grade', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_breast_ct_volume_cm3', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs2954007', 'rs57288348', 'rs72977387', 'rs56402833', 'rs633502', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275'] | AUC: 0.7745
# Fold 7: Selected features: ['alcohol_intake', 'diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'delayed_healing', 'tumour_histological_grade', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs2954007', 'rs57288348', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489'] | AUC: 0.9657
# Fold 8: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'ace_inhibitor', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'post_operative_oedema', 'delayed_healing', 'er_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs2954007', 'rs57288348', 'rs72977387', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170'] | AUC: 0.9216
# Fold 9: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'tumour_quadrant', 'tumour_histological_grade', 'er_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs2954007', 'rs57288348', 'rs72977387', 'rs56402833', 'rs633502', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489'] | AUC: 0.9314
# Fold 10: Selected features: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'analgesics', 'surgery_type', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'delayed_healing', 'tumour_quadrant', 'tumour_histological_grade', 'er_status', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'radio_treated_breast', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_telangiectasia_tumour_bed_baseline', 'breast_telangiectasia_outside_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs2954007', 'rs72977387', 'rs56402833', 'rs633502', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275'] | AUC: 0.8676
#
# Mean AUC using top 40 features across 10 folds: 0.8703
# +---------------------------------------------------+-------------+
# |                                                   |   Frequency |
# |---------------------------------------------------+-------------|
# | diabetes                                          |          10 |
# | history_of_heart_disease                          |          10 |
# | hypertension                                      |          10 |
# | depression                                        |          10 |
# | analgesics                                        |          10 |
# | surgery_type                                      |          10 |
# | nodes_examined                                    |          10 |
# | radio_supraclavicular_fossa                       |          10 |
# | post_operative_haematoma                          |          10 |
# | radio_heart_mean_dose_Gy                          |          10 |
# | chemo_adjuvant                                    |          10 |
# | radio_photon_2nd                                  |          10 |
# | rs72857489                                        |          10 |
# | rs74853756                                        |          10 |
# | rs10945395                                        |          10 |
# | rs56402833                                        |          10 |
# | rs461769                                          |          10 |
# | rs7195405                                         |          10 |
# | rs2954007                                         |          10 |
# | rs1788750                                         |          10 |
# | rs67342194                                        |          10 |
# | rs77405610                                        |          10 |
# | breast_swollen_arm_baseline                       |          10 |
# | chemo_neo_adjuvant                                |           9 |
# | nodes_involved                                    |           9 |
# | breast_telangiectasia_tumour_bed_baseline         |           9 |
# | breast_arm_lymphodema_baseline                    |           9 |
# | radio_hot_spots_107                               |           9 |
# | tumour_histological_grade                         |           9 |
# | axillary_levels                                   |           9 |
# | breast_telangiectasia_outside_tumour_bed_baseline |           9 |
# | delayed_healing                                   |           8 |
# | rs61912468                                        |           8 |
# | rs633502                                          |           8 |
# | rs57288348                                        |           7 |
# | tumour_quadrant                                   |           6 |
# | rs10764743                                        |           6 |
# | rs72977387                                        |           6 |
# | er_status                                         |           6 |
# | post_operative_oedema                             |           5 |
# | tumour_locality                                   |           5 |
# | ace_inhibitor                                     |           5 |
# | radio_treated_breast                              |           4 |
# | rs79223472                                        |           4 |
# | rs6009631                                         |           3 |
# | rs35410275                                        |           3 |
# | radio_breast_ct_volume_cm3                        |           3 |
# | rs3748569                                         |           2 |
# | rs2861705                                         |           2 |
# | rs885170                                          |           2 |
# | post_operative_infection                          |           1 |
# | breast_right_arm_circumfrence_mm_baseline         |           1 |
# | smoker                                            |           1 |
# | rs35035095                                        |           1 |
# | alcohol_intake                                    |           1 |
# +---------------------------------------------------+-------------+
# Top 40 most frequently Features across 10 folds: ['diabetes', 'history_of_heart_disease', 'hypertension', 'depression', 'analgesics', 'surgery_type', 'nodes_examined', 'radio_supraclavicular_fossa', 'post_operative_haematoma', 'radio_heart_mean_dose_Gy', 'chemo_adjuvant', 'radio_photon_2nd', 'rs72857489', 'rs74853756', 'rs10945395', 'rs56402833', 'rs461769', 'rs7195405', 'rs2954007', 'rs1788750', 'rs67342194', 'rs77405610', 'breast_swollen_arm_baseline', 'chemo_neo_adjuvant', 'nodes_involved', 'breast_telangiectasia_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'radio_hot_spots_107', 'tumour_histological_grade', 'axillary_levels', 'breast_telangiectasia_outside_tumour_bed_baseline', 'delayed_healing', 'rs61912468', 'rs633502', 'rs57288348', 'tumour_quadrant', 'rs10764743', 'rs72977387', 'er_status', 'post_operative_oedema']
#
# 	*****************************************************************************************************************************************************************

# %% [markdown]
# Keyways:
# * Mean AUC using top 15 features across 10 folds: 0.8317
# * Mean AUC using top 20 features across 10 folds: 0.8333
# * Mean AUC using top 20 features across 10 folds: 0.8322
# * Mean AUC using top 25 features across 10 folds: 0.8638
# * Mean AUC using top 30 features across 10 folds: 0.8717

# %%
def get_frequent_features(feature_sets, freq_threshold=8):
    """
    Extract stable features from feature frequency tables.

    Works with BOTH formats:

    Format 1:
    {
        k: freq_df
    }

    Format 2:
    {
        k: (freq_df, auc)
    }

    Parameters
    ----------
    feature_sets : dict
        Feature frequency results

    freq_threshold : int
        Minimum frequency required

    Returns
    -------
    list
        Stable feature names
    """

    stable_features = set()

    for k_value, value in feature_sets.items():

        # Handle both dictionary formats
        if isinstance(value, tuple):
            freq_df = value[0]
        else:
            freq_df = value

        selected = freq_df[
            freq_df['Frequency'] >= freq_threshold
        ]

        stable_features.update(
            selected.index.tolist()
        )

    return list(stable_features)

# %%
stable_features_univariate_scaled_inside_pipeline = get_frequent_features(
    feature_sets_univariate_scaled_inside_pipeline,
    freq_threshold=8
)

print(stable_features_univariate_scaled_inside_pipeline)
print(len(stable_features_univariate_scaled_inside_pipeline))
# Out:
# ['nodes_involved', 'rs61912468', 'breast_telangiectasia_tumour_bed_baseline', 'radio_hot_spots_107', 'radio_supraclavicular_fossa', 'rs10945395', 'diabetes', 'tumour_histological_grade', 'rs461769', 'history_of_heart_disease', 'delayed_healing', 'surgery_type', 'rs74853756', 'rs2954007', 'breast_swollen_arm_baseline', 'rs7195405', 'chemo_adjuvant', 'radio_photon_2nd', 'post_operative_haematoma', 'rs1788750', 'breast_telangiectasia_outside_tumour_bed_baseline', 'rs67342194', 'chemo_neo_adjuvant', 'analgesics', 'nodes_examined', 'rs633502', 'rs77405610', 'hypertension', 'breast_arm_lymphodema_baseline', 'rs72857489', 'rs56402833', 'radio_heart_mean_dose_Gy', 'axillary_levels', 'depression']
# 34

# %%
cross_validated_feature_selection(df_clean_20[stable_features_univariate_scaled_inside_pipeline + [dependent1]], dependent1, 10)
# Out:
# Original Data shape is (2067, 35)
# Data shape after dropping missing target: (1691, 35)
# ✅ Mean AUC with final selected features: 0.8853

# %% [markdown]
# ### Nested CV

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.metrics import roc_auc_score
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler

import numpy as np
import pandas as pd
from tqdm import tqdm
from collections import Counter


def get_models(X, y):
    return{

        "RandomForest": RandomForestClassifier(
            n_estimators=100, max_depth=10, random_state=5)}
'''
        "ExtraTrees": ExtraTreesClassifier(
            n_estimators=100, random_state=5
        ),
        "GradientBoosting": GradientBoostingClassifier(
            n_estimators=50, random_state=5
        ),
        "AdaBoost": AdaBoostClassifier(
            n_estimators=50, random_state=5
        ),
        "XGBoost": XGBClassifier(
            random_state=5,
            use_label_encoder=False,
            eval_metric="logloss"
        ),
        "DecisionTree": DecisionTreeClassifier(
            max_depth=5,
            random_state=5,
            class_weight="balanced"
        ),
        "QDA": make_pipeline(
            StandardScaler(),
            QuadraticDiscriminantAnalysis()
        ),
        "GaussianNB": make_pipeline(
            StandardScaler(),
            GaussianNB()
        ),
        "SVC": make_pipeline(
            StandardScaler(),
            SVC(kernel="rbf", probability=True, random_state=5)
        ),
        "KNN": make_pipeline(
            StandardScaler(),
            KNeighborsClassifier(n_neighbors=BestK(X, y))
        ),
        "LogisticRegression": make_pipeline(
            StandardScaler(),
            LogisticRegression(random_state=5)
        ),
        "MLP": make_pipeline(
            StandardScaler(),
            MLPClassifier(hidden_layer_sizes=(100,), random_state=5)
        )
    }'''
# Out:
# '\n        "ExtraTrees": ExtraTreesClassifier(\n            n_estimators=100, random_state=5\n        ),\n        "GradientBoosting": GradientBoostingClassifier(\n            n_estimators=50, random_state=5\n        ),\n        "AdaBoost": AdaBoostClassifier(\n            n_estimators=50, random_state=5\n        ),\n        "XGBoost": XGBClassifier(\n            random_state=5,\n            use_label_encoder=False,\n            eval_metric="logloss"\n        ),\n        "DecisionTree": DecisionTreeClassifier(\n            max_depth=5,\n            random_state=5,\n            class_weight="balanced"\n        ),\n        "QDA": make_pipeline(\n            StandardScaler(),\n            QuadraticDiscriminantAnalysis()\n        ),\n        "GaussianNB": make_pipeline(\n            StandardScaler(),\n            GaussianNB()\n        ),\n        "SVC": make_pipeline(\n            StandardScaler(),\n            SVC(kernel="rbf", probability=True, random_state=5)\n        ),\n        "KNN": make_pipeline(\n            StandardScaler(),\n            KNeighborsClassifier(n_neighbors=BestK(X, y))\n        ),\n        "LogisticRegression": make_pipeline(\n            StandardScaler(),\n            LogisticRegression(random_state=5)\n        ),\n        "MLP": make_pipeline(\n            StandardScaler(),\n            MLPClassifier(hidden_layer_sizes=(100,), random_state=5)\n        )\n    }'

# %%
from itertools import combinations

def jaccard_stability(fold_details, model_name):

    df_model = fold_details[fold_details["model"] == model_name]

    feature_sets = df_model["selected_features"].tolist()

    scores = []

    for a, b in combinations(feature_sets, 2):
        intersection = len(set(a) & set(b))
        union = len(set(a) | set(b))
        scores.append(intersection / union)

    return np.mean(scores)

# %%
def nested_cv_feature_selection_all_features(
    df,
    target,
    k_list,
    outer_splits,
    inner_splits
):

    df = df.dropna()

    # Same style as your second function
    X = df.drop(columns=[target, 'Subject Id'])
    y = df[target]

    # Convert categorical variables to numeric dummy variables
    X = pd.get_dummies(X, drop_first=True)

    outer_cv = StratifiedKFold(
        n_splits=outer_splits,
        shuffle=True,
        random_state=0
    )

    inner_cv = StratifiedKFold(
        n_splits=inner_splits,
        shuffle=True,
        random_state=1
    )

    results = {name: [] for name in get_models(X, y).keys()}
    fold_details = []

    for fold_id, (train_idx, test_idx) in enumerate(
        tqdm(outer_cv.split(X, y), desc="Outer CV"),
        start=1
    ):

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        best_k = None
        best_score = -np.inf

        # ==============================
        # INNER LOOP: choose best k
        # ==============================
        for k in k_list:
            inner_scores = []

            for inner_train_idx, inner_val_idx in inner_cv.split(X_train, y_train):

                X_tr = X_train.iloc[inner_train_idx]
                X_val = X_train.iloc[inner_val_idx]
                y_tr = y_train.iloc[inner_train_idx]
                y_val = y_train.iloc[inner_val_idx]

                pipeline = Pipeline([
                    ('scaler', MinMaxScaler()),
                    ('feature_selection', SelectKBest(score_func=chi2, k=k)),
                    ('model', RandomForestClassifier(
                        n_estimators=100,
                        max_depth=10,
                        min_samples_split=5,
                        min_samples_leaf=1,
                        bootstrap=True,
                        random_state=5
                    ))
                ])

                pipeline.fit(X_tr, y_tr)

                y_pred = pipeline.predict_proba(X_val)[:, 1]
                inner_scores.append(roc_auc_score(y_val, y_pred))

            mean_score = np.mean(inner_scores)

            if mean_score > best_score:
                best_score = mean_score
                best_k = k

        # ==============================
        # OUTER LOOP: train final models
        # ==============================
        models = get_models(X_train, y_train)

        for name, model in models.items():

            pipeline = Pipeline([
                ('scaler', MinMaxScaler()),
                ('feature_selection', SelectKBest(score_func=chi2, k=best_k)),
                ('model', model)
            ])

            pipeline.fit(X_train, y_train)

            y_pred = pipeline.predict_proba(X_test)[:, 1]
            auc_score = roc_auc_score(y_test, y_pred)

            selected_mask = pipeline.named_steps[
                "feature_selection"
            ].get_support()

            selected_features = X_train.columns[selected_mask].tolist()

            results[name].append(auc_score)

            fold_details.append({
                "fold": fold_id,
                "model": name,
                "best_k": best_k,
                "inner_auc": best_score,
                "outer_auc": auc_score,
                "selected_features": selected_features
            })

    summary = {
        model: {
            "mean_auc": np.mean(scores),
            "std_auc": np.std(scores)
        }
        for model, scores in results.items()
    }

    summary = pd.DataFrame(summary).T.sort_values(
        by="mean_auc",
        ascending=False
    )

    fold_details = pd.DataFrame(fold_details)

    all_features = []

    for features in fold_details["selected_features"]:
        all_features.extend(features)

    feature_counts = Counter(all_features)

    feature_frequency = pd.DataFrame({
        "feature": feature_counts.keys(),
        "count": feature_counts.values()
    })

    feature_frequency["percentage"] = (
        100 * feature_frequency["count"] / len(fold_details)
    )

    feature_frequency = feature_frequency.sort_values(
        by="percentage",
        ascending=False
    ).reset_index(drop=True)

    return summary, fold_details, feature_frequency

# %%
summary1, fold_details1, feature_frequency1 = nested_cv_feature_selection_all_features(df_clean_20, dependent1, k_list=k, outer_splits=10, inner_splits=5)
# Out:
# Outer CV: 10it [01:25,  8.54s/it]

# %%
summary1
# Out:
#               mean_auc   std_auc
# RandomForest  0.846385  0.090916

# %%
fold_details1
# Out:
#    fold         model  best_k  inner_auc  outer_auc  \
# 0     1  RandomForest      35   0.837303   0.904412
# 1     2  RandomForest      30   0.853369   0.944853
# 2     3  RandomForest      40   0.887015   0.748162
# 3     4  RandomForest      30   0.868881   0.812500
# 4     5  RandomForest      40   0.875673   0.911765
# 5     6  RandomForest      20   0.873088   0.671569
# 6     7  RandomForest      25   0.861256   0.990196
# 7     8  RandomForest      40   0.859126   0.818627
# 8     9  RandomForest      20   0.841122   0.862745
# 9    10  RandomForest      40   0.860303   0.799020
#
#                                    selected_features
# 0  [diabetes, history_of_heart_disease, hypertens...
# 1  [diabetes, history_of_heart_disease, hypertens...
# 2  [diabetes, history_of_heart_disease, hypertens...
# 3  [diabetes, history_of_heart_disease, depressio...
# 4  [diabetes, history_of_heart_disease, hypertens...
# 5  [diabetes, history_of_heart_disease, analgesic...
# 6  [diabetes, history_of_heart_disease, hypertens...
# 7  [diabetes, history_of_heart_disease, hypertens...
# 8  [diabetes, history_of_heart_disease, depressio...
# 9  [diabetes, history_of_heart_disease, hypertens...

# %%
feature_frequency1
# Out:
#                                               feature  count  percentage
# 0                                            diabetes     10       100.0
# 1                            history_of_heart_disease     10       100.0
# 2                                          analgesics     10       100.0
# 3                                      nodes_examined     10       100.0
# 4                            post_operative_haematoma     10       100.0
# 5                         radio_supraclavicular_fossa     10       100.0
# 6                         breast_swollen_arm_baseline     10       100.0
# 7                                           rs7195405     10       100.0
# 8                                          rs67342194     10       100.0
# 9                                          rs56402833     10       100.0
# 10                                         rs74853756     10       100.0
# 11                                         rs72857489     10       100.0
# 12                     breast_arm_lymphodema_baseline      9        90.0
# 13                                         rs77405610      9        90.0
# 14                                     nodes_involved      9        90.0
# 15                                   radio_photon_2nd      9        90.0
# 16                                          rs2954007      9        90.0
# 17                                       surgery_type      8        80.0
# 18                                         depression      8        80.0
# 19                                           rs461769      8        80.0
# 20                                         rs10945395      8        80.0
# 21                                    axillary_levels      8        80.0
# 22                                 chemo_neo_adjuvant      8        80.0
# 23                                     chemo_adjuvant      8        80.0
# 24                           radio_heart_mean_dose_Gy      8        80.0
# 25                                       hypertension      7        70.0
# 26                                radio_hot_spots_107      7        70.0
# 27  breast_telangiectasia_outside_tumour_bed_baseline      7        70.0
# 28                                    delayed_healing      6        60.0
# 29                                          er_status      5        50.0
# 30                                          rs1788750      5        50.0
# 31                                         rs61912468      5        50.0
# 32                                      ace_inhibitor      4        40.0
# 33          breast_telangiectasia_tumour_bed_baseline      4        40.0
# 34                          tumour_histological_grade      4        40.0
# 35                              post_operative_oedema      4        40.0
# 36                                         rs72977387      4        40.0
# 37                                         rs57288348      4        40.0
# 38                                    tumour_locality      3        30.0
# 39                                          rs6009631      3        30.0
# 40                                         rs79223472      3        30.0
# 41                                           rs633502      3        30.0
# 42                                         rs10764743      3        30.0
# 43                                    tumour_quadrant      2        20.0
# 44                                           rs885170      2        20.0
# 45                                         rs35410275      2        20.0
# 46                               radio_treated_breast      2        20.0
# 47                                          rs2861705      1        10.0
# 48                         radio_breast_ct_volume_cm3      1        10.0

# %%
# Features that appeared in 8 folds and more across 10 folds
stable_features_nested1 = feature_frequency1[feature_frequency1["count"] >= 8]["feature"].tolist()

# %%
print (stable_features_nested1)
# Out:
# ['diabetes', 'history_of_heart_disease', 'analgesics', 'nodes_examined', 'post_operative_haematoma', 'radio_supraclavicular_fossa', 'breast_swollen_arm_baseline', 'rs7195405', 'rs67342194', 'rs56402833', 'rs74853756', 'rs72857489', 'breast_arm_lymphodema_baseline', 'rs77405610', 'nodes_involved', 'radio_photon_2nd', 'rs2954007', 'surgery_type', 'depression', 'rs461769', 'rs10945395', 'axillary_levels', 'chemo_neo_adjuvant', 'chemo_adjuvant', 'radio_heart_mean_dose_Gy']

# %%
print(len(stable_features_nested1))
# Out:
# 25

# %%
jaccard_stability(fold_details1, "RandomForest")
# Out:
# np.float64(0.6224796238901724)

# %%
cross_validated_feature_selection(df_clean_20[stable_features_nested1 + [dependent1]], dependent1, 10)
# Out:
# Original Data shape is (2067, 26)
# Data shape after dropping missing target: (1691, 26)
# ✅ Mean AUC with final selected features: 0.8797

# %% [markdown]
# ## Second feature selectin Method

# %% [markdown]
# **3.3.3) Feature Importance** — You can gain the significance of each feature of your dataset by
# using the Model Characteristics property. Feature value gives you a score for every function of your results, the higher the score the more significant or appropriate the performance variable is. Feature importance is the built-in class that comes with Tree Based Classifiers, we will use the Extra Tree Classifier to extract the top 10 features for the dataset.

# %% [markdown]
# ### outside CV

# %%
def featureselection2(df, col, k):
    # Plot the top k features
    plt.figure(figsize=(10, 10))

    # Initialize the model
    model = ExtraTreesClassifier(random_state=10)

    # Drop rows with missing values
    df = df.dropna(axis=0, how='any', inplace=False)


    # Separate features and target variable
    X = df.drop(columns=[col, 'Subject Id'])
    y = df[col]

    # Convert categorical variables into numeric
    X = pd.get_dummies(X, drop_first=True)


    # Fit the model
    model.fit(X, y)

    # Get feature importances
    feat_importances = pd.Series(model.feature_importances_, index=X.columns)

    # Select the top k important features
    top_features = feat_importances.nlargest(k)

    # Plot the top k features
    bold("Choosing " + str(k) + " Features:\n")

    top_features.plot(kind='barh')
    #sns.barplot(x=top_features, y=feat_importances, data=df, palette='viridis')
    plt.xlabel("Feature Importance")
    plt.title(f"Top {k} Important Features")
    plt.show()
    print(f"\n\n Important {k} features:", top_features.index.tolist())

    # Prepare data with selected features only
    X_selected = X[top_features.index.tolist()]
    # Build pipeline and evaluate using cross-validation
    pipeline = Pipeline([
        ('classifier', RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=1,bootstrap=True, random_state=5))
    ])

    # Use StratifiedKFold and calculate mean AUC
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
    auc_scores = cross_val_score(pipeline, X_selected, y, cv=skf, scoring='roc_auc')

    print(f"Mean AUC score using top {k} features: {auc_scores.mean():.4f}")
    return top_features.index.tolist(), auc_scores.mean()

# %%
feature_sets_featimportance = {}

for i in k:
    freq_df2_auc= featureselection2(df_clean_20, dependent1, k=i)
    feature_sets_featimportance[i] = freq_df2_auc
# Out:
# <p style='font-size:16pt;'>Choosing 10 Features:
# </p>
#  Important 10 features: ['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy']
# Mean AUC score using top 10 features: 0.8794
# <p style='font-size:16pt;'>Choosing 15 Features:
# </p>
#  Important 15 features: ['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy', 'rs79223472', 'rs10945395', 'rs57288348', 'radio_ipsilateral_lung_mean_Gy', 'rs1788750']
# Mean AUC score using top 15 features: 0.9031
# <p style='font-size:16pt;'>Choosing 20 Features:
# </p>
#  Important 20 features: ['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy', 'rs79223472', 'rs10945395', 'rs57288348', 'radio_ipsilateral_lung_mean_Gy', 'rs1788750', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs633502', 'rs72977387', 'rs885170']
# Mean AUC score using top 20 features: 0.8993
# <p style='font-size:16pt;'>Choosing 25 Features:
# </p>
#  Important 25 features: ['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy', 'rs79223472', 'rs10945395', 'rs57288348', 'radio_ipsilateral_lung_mean_Gy', 'rs1788750', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs633502', 'rs72977387', 'rs885170', 'rs35410275', 'radio_skin_max_dose_Gy', 'rs6009631', 'history_of_heart_disease', 'rs10764743']
# Mean AUC score using top 25 features: 0.8989
# <p style='font-size:16pt;'>Choosing 30 Features:
# </p>
#  Important 30 features: ['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy', 'rs79223472', 'rs10945395', 'rs57288348', 'radio_ipsilateral_lung_mean_Gy', 'rs1788750', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs633502', 'rs72977387', 'rs885170', 'rs35410275', 'radio_skin_max_dose_Gy', 'rs6009631', 'history_of_heart_disease', 'rs10764743', 'rs2861705', 'rs7195405', 'rs35035095', 'radio_breast_ct_volume_cm3', 'breast_right_arm_circumfrence_mm_baseline']
# Mean AUC score using top 30 features: 0.8958
# <p style='font-size:16pt;'>Choosing 35 Features:
# </p>
#  Important 35 features: ['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy', 'rs79223472', 'rs10945395', 'rs57288348', 'radio_ipsilateral_lung_mean_Gy', 'rs1788750', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs633502', 'rs72977387', 'rs885170', 'rs35410275', 'radio_skin_max_dose_Gy', 'rs6009631', 'history_of_heart_disease', 'rs10764743', 'rs2861705', 'rs7195405', 'rs35035095', 'radio_breast_ct_volume_cm3', 'breast_right_arm_circumfrence_mm_baseline', 'axillary_levels', 'height_cm', 'rs2954007', 'analgesics', 'radio_photon_2nd']
# Mean AUC score using top 35 features: 0.9087
# <p style='font-size:16pt;'>Choosing 40 Features:
# </p>
#  Important 40 features: ['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy', 'rs79223472', 'rs10945395', 'rs57288348', 'radio_ipsilateral_lung_mean_Gy', 'rs1788750', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs633502', 'rs72977387', 'rs885170', 'rs35410275', 'radio_skin_max_dose_Gy', 'rs6009631', 'history_of_heart_disease', 'rs10764743', 'rs2861705', 'rs7195405', 'rs35035095', 'radio_breast_ct_volume_cm3', 'breast_right_arm_circumfrence_mm_baseline', 'axillary_levels', 'height_cm', 'rs2954007', 'analgesics', 'radio_photon_2nd', 'age', 'Site', 'band_size', 'tumour_quadrant', 'tumour_size_mm']
# Mean AUC score using top 40 features: 0.8960

# %% [markdown]
# Takeaways4: These based on df_clean_20
#
# * Mean AUC score using top 10 features: 0.8794
#
# * Mean AUC score using top 15 features: 0.9031
#
# * Mean AUC score using top 20 features: 0.8993
#
# * Mean AUC score using top 25 features: 0.8989
#
# * Mean AUC score using top 30 features: 0.8958

# %%
print(feature_sets_featimportance)
# Out:
# {10: (['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy'], np.float64(0.8793504901960784)), 15: (['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy', 'rs79223472', 'rs10945395', 'rs57288348', 'radio_ipsilateral_lung_mean_Gy', 'rs1788750'], np.float64(0.903063725490196)), 20: (['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy', 'rs79223472', 'rs10945395', 'rs57288348', 'radio_ipsilateral_lung_mean_Gy', 'rs1788750', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs633502', 'rs72977387', 'rs885170'], np.float64(0.8992647058823531)), 25: (['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy', 'rs79223472', 'rs10945395', 'rs57288348', 'radio_ipsilateral_lung_mean_Gy', 'rs1788750', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs633502', 'rs72977387', 'rs885170', 'rs35410275', 'radio_skin_max_dose_Gy', 'rs6009631', 'history_of_heart_disease', 'rs10764743'], np.float64(0.8988970588235293)), 30: (['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy', 'rs79223472', 'rs10945395', 'rs57288348', 'radio_ipsilateral_lung_mean_Gy', 'rs1788750', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs633502', 'rs72977387', 'rs885170', 'rs35410275', 'radio_skin_max_dose_Gy', 'rs6009631', 'history_of_heart_disease', 'rs10764743', 'rs2861705', 'rs7195405', 'rs35035095', 'radio_breast_ct_volume_cm3', 'breast_right_arm_circumfrence_mm_baseline'], np.float64(0.8958333333333333)), 35: (['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy', 'rs79223472', 'rs10945395', 'rs57288348', 'radio_ipsilateral_lung_mean_Gy', 'rs1788750', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs633502', 'rs72977387', 'rs885170', 'rs35410275', 'radio_skin_max_dose_Gy', 'rs6009631', 'history_of_heart_disease', 'rs10764743', 'rs2861705', 'rs7195405', 'rs35035095', 'radio_breast_ct_volume_cm3', 'breast_right_arm_circumfrence_mm_baseline', 'axillary_levels', 'height_cm', 'rs2954007', 'analgesics', 'radio_photon_2nd'], np.float64(0.908700980392157)), 40: (['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy', 'rs79223472', 'rs10945395', 'rs57288348', 'radio_ipsilateral_lung_mean_Gy', 'rs1788750', 'breast_arm_lymphodema_baseline', 'post_operative_haematoma', 'rs633502', 'rs72977387', 'rs885170', 'rs35410275', 'radio_skin_max_dose_Gy', 'rs6009631', 'history_of_heart_disease', 'rs10764743', 'rs2861705', 'rs7195405', 'rs35035095', 'radio_breast_ct_volume_cm3', 'breast_right_arm_circumfrence_mm_baseline', 'axillary_levels', 'height_cm', 'rs2954007', 'analgesics', 'radio_photon_2nd', 'age', 'Site', 'band_size', 'tumour_quadrant', 'tumour_size_mm'], np.float64(0.8959558823529411))}

# %%
from collections import Counter
import math

feature_counter = Counter()

for features, _ in feature_sets_featimportance.values():
    feature_counter.update(features)

# 60% threshold
threshold = math.ceil(0.8 * len(feature_sets_featimportance))

stable_features_featimportance = [
    feature
    for feature, count in feature_counter.items()
    if count >= threshold
]

print(stable_features_featimportance)
print(len(stable_features_featimportance))
# Out:
# ['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'rs74853756', 'rs61912468', 'radio_heart_mean_dose_Gy', 'rs79223472', 'rs10945395', 'rs57288348', 'radio_ipsilateral_lung_mean_Gy', 'rs1788750']
# 15

# %%
cross_validated_feature_selection(df_clean_20[stable_features_featimportance + [dependent1]], dependent1, 10)
# Out:
# Original Data shape is (2067, 16)
# Data shape after dropping missing target: (1691, 16)
# ✅ Mean AUC with final selected features: 0.8706

# %% [markdown]
# ### inside CV

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import MinMaxScaler

def featureselection2_pipeline_auc(df, dependent, k):
    df = df.dropna()


    # Separate features and target variable
    X = df.drop(columns=[dependent, 'Subject Id'])
    y = df[dependent]

    # Convert categorical variables into numeric
    X = pd.get_dummies(X, drop_first=True)

    # Build pipeline with scaling, feature selection, and classification
    pipeline = Pipeline([
        ('scaler', MinMaxScaler()), # Added scaler back, assuming it's intended to be part of the pipeline
        ('feature_selection', SelectFromModel(
            ExtraTreesClassifier(random_state=10),
            threshold=-np.inf, # Set a very low threshold so we can control selection purely by max_features
            max_features=k
        )),
        ('classifier', RandomForestClassifier(n_estimators=100,
                              max_depth=10,
                              min_samples_split=5,
                              min_samples_leaf=1,
                              bootstrap=True,
                              random_state=5))
    ])

    # Cross-validation setup
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
    auc_scores = cross_val_score(pipeline, X, y, cv=skf, scoring='roc_auc')

    print(f"Mean AUC score using top {k} features (Inside CV): {auc_scores.mean():.3f}")
    return auc_scores.mean()

# %%
# This is the method that I used to compare among features number, heatmaps
for i in k:
  Mean_auc_scores_CV_inside_pipeline2= featureselection2_pipeline_auc(df_clean_20, dependent1, k=i)
# Out:
# Mean AUC score using top 10 features (Inside CV): 0.795
# Mean AUC score using top 15 features (Inside CV): 0.860
# Mean AUC score using top 20 features (Inside CV): 0.847
# Mean AUC score using top 25 features (Inside CV): 0.863
# Mean AUC score using top 30 features (Inside CV): 0.851
# Mean AUC score using top 35 features (Inside CV): 0.872
# Mean AUC score using top 40 features (Inside CV): 0.862

# %% [markdown]
# Keyways:
# with scale:
# * Mean AUC score using top 10 features (Inside CV): 0.80
# * Mean AUC score using top 15 features (Inside CV): 0.86
# * Mean AUC score using top 20 features (Inside CV): 0.85
# * Mean AUC score using top 25 features (Inside CV): 0.86
# * Mean AUC score using top 30 features (Inside CV): 0.85
#
# without scaled:
#
#
# * Mean AUC score using top 10 features (Inside CV): 0.80
# * Mean AUC score using top 15 features (Inside CV): 0.86
# * Mean AUC score using top 20 features (Inside CV): 0.85
# * Mean AUC score using top 25 features (Inside CV): 0.86
# * Mean AUC score using top 30 features (Inside CV): 0.85

# %% [markdown]
# ### features frequency inside pipline

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score
from collections import Counter
import numpy as np
import pandas as pd

def featureselection2_freq(df, col, k, n_splits):
    df = df.dropna()

    # Prepare X and y
    X = df.drop(columns=[col, 'Subject Id'])
    y = df[col]

    # Convert categorical variables into numeric
    X = pd.get_dummies(X, drop_first=True)
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=0)

    feature_counts = Counter()
    auc_scores = []

    for fold_idx, (train_index, test_index) in enumerate(skf.split(X, y)):
        X_train, y_train = X.iloc[train_index], y.iloc[train_index]
        X_test, y_test = X.iloc[test_index], y.iloc[test_index]

        pipeline = Pipeline([
            ('feature_selection', SelectFromModel(
                estimator=ExtraTreesClassifier(random_state=10),
                max_features=k,
                threshold=-np.inf  # keep exactly top k features
            )),

            ('model', RandomForestClassifier(
                n_estimators=100,
                max_depth=10,
                min_samples_split=5,
                min_samples_leaf=1,
                bootstrap=True,
                random_state=5
            ))
        ])

        pipeline.fit(X_train, y_train)
        # Get predicted probabilities for AUC calculation
        y_prob = pipeline.predict_proba(X_test)[:, 1]
        auc = roc_auc_score(y_test, y_prob)
        auc_scores.append(auc)


        selector = pipeline.named_steps['feature_selection']
        top_features = X_train.columns[selector.get_support()].tolist()

        # Count selected features
        feature_counts.update(top_features)
        print(f"Fold {fold_idx+1}: Selected features: {list(top_features)}| AUC: {auc:.4f}"
        )

    # Calculate the mean AUC
    mean_auc = np.mean(auc_scores)
    print(f"Mean AUC using top {k} features across {n_splits} folds: {mean_auc:.4f}")

   # Convert to DataFrame
    freq_df = pd.DataFrame.from_dict(feature_counts, orient='index', columns=['Frequency'])
    freq_df = freq_df.sort_values(by='Frequency', ascending=False)

    # Plot
    plt.figure(figsize=(10, 12))
    sns.barplot(x='Frequency', y=freq_df.index, data=freq_df, palette='viridis')
    plt.xlabel('Selection Frequency')
    plt.ylabel('Feature Importances with ETC')
    plt.title(f'Feature Importances Frequency Across {n_splits} Folds (Top {k} features/fold)')
    plt.xticks(np.arange(0, n_splits+1, 1))
    #plt.gca().invert_yaxis()
    plt.show()
    #print(tabulate(freq_df, headers='keys', tablefmt='psql'))
    print(tabulate(freq_df, headers='keys', tablefmt='psql'))
    top_features_final = freq_df.head(k).index.tolist()
    print(f"Top {k} most frequently Features across {n_splits} folds:", top_features_final)
    print("\n\t*****************************************************************************************************************************************************************\n\n")

    return freq_df

# %%
feature_sets_featimportance_inside_pipeline = {}

for i in k:
    freq_df2= featureselection2_freq(df_clean_20, dependent1, k=i, n_splits=10)
    feature_sets_featimportance_inside_pipeline[i] = freq_df2
# Out:
# Fold 1: Selected features: ['nodes_examined', 'radio_supraclavicular_fossa', 'rs77405610', 'rs67342194', 'rs57288348', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs72857489']| AUC: 0.8015
# Fold 2: Selected features: ['nodes_examined', 'post_operative_haematoma', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'rs77405610', 'rs67342194', 'rs56402833', 'rs74853756', 'rs461769', 'rs72857489']| AUC: 0.8640
# Fold 3: Selected features: ['nodes_examined', 'radio_supraclavicular_fossa', 'rs77405610', 'rs67342194', 'rs1788750', 'rs56402833', 'rs79223472', 'rs74853756', 'rs461769', 'rs885170']| AUC: 0.8051
# Fold 4: Selected features: ['nodes_examined', 'radio_heart_mean_dose_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'rs67342194', 'rs35035095', 'rs56402833', 'rs74853756', 'rs72857489', 'rs885170']| AUC: 0.5993
# Fold 5: Selected features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'rs77405610', 'rs67342194', 'rs56402833', 'rs79223472', 'rs461769', 'rs72857489']| AUC: 0.8676
# Fold 6: Selected features: ['nodes_examined', 'post_operative_haematoma', 'radio_supraclavicular_fossa', 'rs77405610', 'rs67342194', 'rs56402833', 'rs74853756', 'rs10945395', 'rs72857489', 'rs885170']| AUC: 0.6152
# Fold 7: Selected features: ['nodes_examined', 'radio_ipsilateral_lung_mean_Gy', 'rs77405610', 'rs67342194', 'rs1788750', 'rs6009631', 'rs56402833', 'rs74853756', 'rs461769', 'rs72857489']| AUC: 0.9559
# Fold 8: Selected features: ['nodes_examined', 'post_operative_haematoma', 'breast_arm_lymphodema_baseline', 'rs77405610', 'rs67342194', 'rs79223472', 'rs74853756', 'rs461769', 'rs72857489', 'rs885170']| AUC: 0.8676
# Fold 9: Selected features: ['nodes_examined', 'radio_supraclavicular_fossa', 'rs77405610', 'rs67342194', 'rs7195405', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489']| AUC: 0.9755
# Fold 10: Selected features: ['nodes_examined', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs56402833', 'rs10945395', 'rs461769', 'rs72857489']| AUC: 0.5980
# Mean AUC using top 10 features across 10 folds: 0.7950
# +--------------------------------+-------------+
# |                                |   Frequency |
# |--------------------------------+-------------|
# | nodes_examined                 |          10 |
# | rs67342194                     |          10 |
# | rs77405610                     |           9 |
# | rs72857489                     |           9 |
# | rs56402833                     |           9 |
# | rs74853756                     |           8 |
# | radio_supraclavicular_fossa    |           7 |
# | rs461769                       |           7 |
# | rs10945395                     |           4 |
# | rs885170                       |           4 |
# | breast_arm_lymphodema_baseline |           4 |
# | rs79223472                     |           4 |
# | post_operative_haematoma       |           3 |
# | rs7195405                      |           2 |
# | radio_heart_mean_dose_Gy       |           2 |
# | radio_ipsilateral_lung_mean_Gy |           2 |
# | rs1788750                      |           2 |
# | rs57288348                     |           1 |
# | rs35035095                     |           1 |
# | radio_breast_ct_volume_cm3     |           1 |
# | rs6009631                      |           1 |
# +--------------------------------+-------------+
# Top 10 most frequently Features across 10 folds: ['nodes_examined', 'rs67342194', 'rs77405610', 'rs72857489', 'rs56402833', 'rs74853756', 'radio_supraclavicular_fossa', 'rs461769', 'rs10945395', 'rs885170']
#
# 	*****************************************************************************************************************************************************************
#
#
# Fold 1: Selected features: ['nodes_examined', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs57288348', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489']| AUC: 0.9559
# Fold 2: Selected features: ['nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs72977387', 'rs56402833', 'rs74853756', 'rs461769', 'rs72857489']| AUC: 0.8603
# Fold 3: Selected features: ['nodes_examined', 'radio_supraclavicular_fossa', 'rs77405610', 'rs67342194', 'rs1788750', 'rs72977387', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.6857
# Fold 4: Selected features: ['nodes_involved', 'nodes_examined', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'rs67342194', 'rs35035095', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs885170']| AUC: 0.8199
# Fold 5: Selected features: ['history_of_heart_disease', 'nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs56402833', 'rs79223472', 'rs461769', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.9216
# Fold 6: Selected features: ['nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs72857489', 'rs885170']| AUC: 0.8235
# Fold 7: Selected features: ['nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'rs77405610', 'rs67342194', 'rs1788750', 'rs6009631', 'rs56402833', 'rs2861705', 'rs74853756', 'rs461769', 'rs72857489']| AUC: 0.9412
# Fold 8: Selected features: ['nodes_examined', 'post_operative_haematoma', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'rs77405610', 'rs67342194', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']| AUC: 0.8529
# Fold 9: Selected features: ['nodes_examined', 'radio_heart_mean_dose_Gy', 'radio_supraclavicular_fossa', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs885170']| AUC: 0.9559
# Fold 10: Selected features: ['nodes_examined', 'radio_heart_mean_dose_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs6009631', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']| AUC: 0.7843
# Mean AUC using top 15 features across 10 folds: 0.8601
# +-------------------------------------------+-------------+
# |                                           |   Frequency |
# |-------------------------------------------+-------------|
# | nodes_examined                            |          10 |
# | rs67342194                                |          10 |
# | rs56402833                                |          10 |
# | rs72857489                                |          10 |
# | rs74853756                                |           9 |
# | rs77405610                                |           9 |
# | rs461769                                  |           9 |
# | radio_supraclavicular_fossa               |           9 |
# | radio_heart_mean_dose_Gy                  |           7 |
# | rs10945395                                |           7 |
# | rs885170                                  |           7 |
# | rs79223472                                |           6 |
# | radio_ipsilateral_lung_mean_Gy            |           6 |
# | rs7195405                                 |           5 |
# | breast_arm_lymphodema_baseline            |           4 |
# | post_operative_haematoma                  |           4 |
# | rs1788750                                 |           4 |
# | radio_breast_ct_volume_cm3                |           3 |
# | breast_right_arm_circumfrence_mm_baseline |           3 |
# | rs2861705                                 |           2 |
# | rs35410275                                |           2 |
# | rs72977387                                |           2 |
# | rs6009631                                 |           2 |
# | radio_skin_max_dose_Gy                    |           2 |
# | rs61912468                                |           2 |
# | nodes_involved                            |           2 |
# | rs10764743                                |           1 |
# | rs57288348                                |           1 |
# | rs35035095                                |           1 |
# | history_of_heart_disease                  |           1 |
# +-------------------------------------------+-------------+
# Top 15 most frequently Features across 10 folds: ['nodes_examined', 'rs67342194', 'rs56402833', 'rs72857489', 'rs74853756', 'rs77405610', 'rs461769', 'radio_supraclavicular_fossa', 'radio_heart_mean_dose_Gy', 'rs10945395', 'rs885170', 'rs79223472', 'radio_ipsilateral_lung_mean_Gy', 'rs7195405', 'breast_arm_lymphodema_baseline']
#
# 	*****************************************************************************************************************************************************************
#
#
# Fold 1: Selected features: ['nodes_examined', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489']| AUC: 0.9449
# Fold 2: Selected features: ['nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs72977387', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8934
# Fold 3: Selected features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_supraclavicular_fossa', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs35035095', 'rs72977387', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.7151
# Fold 4: Selected features: ['history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs35035095', 'rs56402833', 'rs2861705', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs885170']| AUC: 0.7151
# Fold 5: Selected features: ['history_of_heart_disease', 'nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs6009631', 'rs56402833', 'rs79223472', 'rs74853756', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8529
# Fold 6: Selected features: ['nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs6009631', 'rs72977387', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']| AUC: 0.8578
# Fold 7: Selected features: ['nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs6009631', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs461769', 'rs61912468', 'rs72857489']| AUC: 0.9118
# Fold 8: Selected features: ['analgesics', 'nodes_examined', 'post_operative_haematoma', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']| AUC: 0.8529
# Fold 9: Selected features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs72977387', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.9118
# Fold 10: Selected features: ['nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_size_mm', 'her2_status', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs6009631', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']| AUC: 0.8137
# Mean AUC using top 20 features across 10 folds: 0.8469
# +-------------------------------------------+-------------+
# |                                           |   Frequency |
# |-------------------------------------------+-------------|
# | nodes_examined                            |          10 |
# | radio_supraclavicular_fossa               |          10 |
# | rs56402833                                |          10 |
# | rs74853756                                |          10 |
# | rs67342194                                |          10 |
# | rs77405610                                |          10 |
# | rs461769                                  |          10 |
# | rs72857489                                |          10 |
# | radio_heart_mean_dose_Gy                  |           9 |
# | radio_ipsilateral_lung_mean_Gy            |           8 |
# | rs885170                                  |           8 |
# | breast_arm_lymphodema_baseline            |           8 |
# | rs79223472                                |           8 |
# | rs10945395                                |           8 |
# | rs7195405                                 |           7 |
# | radio_skin_max_dose_Gy                    |           6 |
# | rs1788750                                 |           6 |
# | post_operative_haematoma                  |           5 |
# | rs6009631                                 |           5 |
# | rs61912468                                |           5 |
# | rs72977387                                |           4 |
# | rs35410275                                |           4 |
# | rs2861705                                 |           4 |
# | breast_right_arm_circumfrence_mm_baseline |           4 |
# | nodes_involved                            |           4 |
# | radio_breast_ct_volume_cm3                |           3 |
# | history_of_heart_disease                  |           2 |
# | rs35035095                                |           2 |
# | radio_photon_2nd                          |           1 |
# | rs57288348                                |           1 |
# | rs2954007                                 |           1 |
# | rs10764743                                |           1 |
# | radio_hot_spots_107                       |           1 |
# | breast_swollen_arm_baseline               |           1 |
# | analgesics                                |           1 |
# | axillary_levels                           |           1 |
# | tumour_size_mm                            |           1 |
# | her2_status                               |           1 |
# +-------------------------------------------+-------------+
# Top 20 most frequently Features across 10 folds: ['nodes_examined', 'radio_supraclavicular_fossa', 'rs56402833', 'rs74853756', 'rs67342194', 'rs77405610', 'rs461769', 'rs72857489', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'rs885170', 'breast_arm_lymphodema_baseline', 'rs79223472', 'rs10945395', 'rs7195405', 'radio_skin_max_dose_Gy', 'rs1788750', 'post_operative_haematoma', 'rs6009631', 'rs61912468']
#
# 	*****************************************************************************************************************************************************************
#
#
# Fold 1: Selected features: ['history_of_heart_disease', 'nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs72977387', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']| AUC: 0.9816
# Fold 2: Selected features: ['age', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs72977387', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8787
# Fold 3: Selected features: ['history_of_heart_disease', 'nodes_examined', 'post_operative_haematoma', 'her2_status', 'radio_skin_max_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.7426
# Fold 4: Selected features: ['history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs7195405', 'rs6009631', 'rs35035095', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8015
# Fold 5: Selected features: ['history_of_heart_disease', 'nodes_examined', 'her2_status', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs6009631', 'rs57288348', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8578
# Fold 6: Selected features: ['nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_size_mm', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs57288348', 'rs72977387', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']| AUC: 0.8088
# Fold 7: Selected features: ['history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs6009631', 'rs57288348', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs885170']| AUC: 0.9755
# Fold 8: Selected features: ['analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs35035095', 'rs72977387', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs885170']| AUC: 0.9167
# Fold 9: Selected features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.9265
# Fold 10: Selected features: ['history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_size_mm', 'her2_status', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs6009631', 'rs56402833', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.7353
# Mean AUC using top 25 features across 10 folds: 0.8625
# +-------------------------------------------+-------------+
# |                                           |   Frequency |
# |-------------------------------------------+-------------|
# | nodes_examined                            |          10 |
# | radio_supraclavicular_fossa               |          10 |
# | rs74853756                                |          10 |
# | rs56402833                                |          10 |
# | rs461769                                  |          10 |
# | rs77405610                                |          10 |
# | rs67342194                                |          10 |
# | rs885170                                  |          10 |
# | rs10945395                                |          10 |
# | rs72857489                                |          10 |
# | rs79223472                                |           9 |
# | radio_heart_mean_dose_Gy                  |           9 |
# | rs7195405                                 |           9 |
# | breast_arm_lymphodema_baseline            |           9 |
# | radio_ipsilateral_lung_mean_Gy            |           9 |
# | rs1788750                                 |           9 |
# | radio_skin_max_dose_Gy                    |           7 |
# | post_operative_haematoma                  |           7 |
# | breast_right_arm_circumfrence_mm_baseline |           7 |
# | rs6009631                                 |           7 |
# | rs61912468                                |           7 |
# | rs57288348                                |           6 |
# | history_of_heart_disease                  |           6 |
# | nodes_involved                            |           6 |
# | rs35410275                                |           6 |
# | rs72977387                                |           6 |
# | radio_breast_ct_volume_cm3                |           4 |
# | rs2861705                                 |           4 |
# | rs35035095                                |           4 |
# | rs10764743                                |           4 |
# | her2_status                               |           3 |
# | tumour_size_mm                            |           2 |
# | radio_photon_2nd                          |           2 |
# | axillary_levels                           |           2 |
# | breast_swollen_arm_baseline               |           2 |
# | rs2954007                                 |           1 |
# | age                                       |           1 |
# | radio_hot_spots_107                       |           1 |
# | analgesics                                |           1 |
# +-------------------------------------------+-------------+
# Top 25 most frequently Features across 10 folds: ['nodes_examined', 'radio_supraclavicular_fossa', 'rs74853756', 'rs56402833', 'rs461769', 'rs77405610', 'rs67342194', 'rs885170', 'rs10945395', 'rs72857489', 'rs79223472', 'radio_heart_mean_dose_Gy', 'rs7195405', 'breast_arm_lymphodema_baseline', 'radio_ipsilateral_lung_mean_Gy', 'rs1788750', 'radio_skin_max_dose_Gy', 'post_operative_haematoma', 'breast_right_arm_circumfrence_mm_baseline', 'rs6009631', 'rs61912468', 'rs57288348', 'history_of_heart_disease', 'nodes_involved', 'rs35410275']
#
# 	*****************************************************************************************************************************************************************
#
#
# Fold 1: Selected features: ['history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs885170']| AUC: 0.9779
# Fold 2: Selected features: ['age', 'band_size', 'history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs72977387', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8456
# Fold 3: Selected features: ['history_of_heart_disease', 'nodes_examined', 'post_operative_haematoma', 'her2_status', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.7206
# Fold 4: Selected features: ['history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8199
# Fold 5: Selected features: ['history_of_heart_disease', 'nodes_examined', 'her2_status', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8333
# Fold 6: Selected features: ['nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs57288348', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs885170']| AUC: 0.8431
# Fold 7: Selected features: ['history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8873
# Fold 8: Selected features: ['analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs6009631', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.9069
# Fold 9: Selected features: ['nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs6009631', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.9608
# Fold 10: Selected features: ['history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_size_mm', 'her2_status', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs6009631', 'rs2954007', 'rs35035095', 'rs56402833', 'rs633502', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.7157
# Mean AUC using top 30 features across 10 folds: 0.8511
# +-------------------------------------------+-------------+
# |                                           |   Frequency |
# |-------------------------------------------+-------------|
# | nodes_examined                            |          10 |
# | radio_ipsilateral_lung_mean_Gy            |          10 |
# | radio_supraclavicular_fossa               |          10 |
# | radio_heart_mean_dose_Gy                  |          10 |
# | rs56402833                                |          10 |
# | rs74853756                                |          10 |
# | rs67342194                                |          10 |
# | rs77405610                                |          10 |
# | breast_right_arm_circumfrence_mm_baseline |          10 |
# | rs885170                                  |          10 |
# | rs72857489                                |          10 |
# | rs461769                                  |          10 |
# | rs10945395                                |          10 |
# | post_operative_haematoma                  |           9 |
# | rs6009631                                 |           9 |
# | radio_skin_max_dose_Gy                    |           9 |
# | rs61912468                                |           9 |
# | rs79223472                                |           9 |
# | rs7195405                                 |           9 |
# | rs1788750                                 |           9 |
# | breast_arm_lymphodema_baseline            |           9 |
# | rs72977387                                |           8 |
# | rs35035095                                |           8 |
# | nodes_involved                            |           8 |
# | radio_breast_ct_volume_cm3                |           8 |
# | rs35410275                                |           8 |
# | history_of_heart_disease                  |           7 |
# | rs57288348                                |           7 |
# | rs2954007                                 |           7 |
# | rs2861705                                 |           6 |
# | rs10764743                                |           6 |
# | breast_swollen_arm_baseline               |           5 |
# | rs633502                                  |           5 |
# | radio_photon_2nd                          |           3 |
# | her2_status                               |           3 |
# | axillary_levels                           |           3 |
# | tumour_size_mm                            |           2 |
# | band_size                                 |           1 |
# | age                                       |           1 |
# | radio_hot_spots_107                       |           1 |
# | analgesics                                |           1 |
# +-------------------------------------------+-------------+
# Top 30 most frequently Features across 10 folds: ['nodes_examined', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'radio_heart_mean_dose_Gy', 'rs56402833', 'rs74853756', 'rs67342194', 'rs77405610', 'breast_right_arm_circumfrence_mm_baseline', 'rs885170', 'rs72857489', 'rs461769', 'rs10945395', 'post_operative_haematoma', 'rs6009631', 'radio_skin_max_dose_Gy', 'rs61912468', 'rs79223472', 'rs7195405', 'rs1788750', 'breast_arm_lymphodema_baseline', 'rs72977387', 'rs35035095', 'nodes_involved', 'radio_breast_ct_volume_cm3', 'rs35410275', 'history_of_heart_disease', 'rs57288348', 'rs2954007', 'rs2861705']
#
# 	*****************************************************************************************************************************************************************
#
#
# Fold 1: Selected features: ['height_cm', 'history_of_heart_disease', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_locality', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs885170']| AUC: 0.9632
# Fold 2: Selected features: ['age', 'band_size', 'history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_locality', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8199
# Fold 3: Selected features: ['bra_cup_size', 'band_size', 'history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'her2_status', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.7831
# Fold 4: Selected features: ['history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8971
# Fold 5: Selected features: ['history_of_heart_disease', 'nodes_examined', 'post_operative_haematoma', 'tumour_size_mm', 'her2_status', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.9069
# Fold 6: Selected features: ['nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_locality', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8431
# Fold 7: Selected features: ['height_cm', 'age', 'history_of_heart_disease', 'education_profession', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.9314
# Fold 8: Selected features: ['diabetes', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_locality', 't_stage', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8971
# Fold 9: Selected features: ['height_cm', 'analgesics', 'education_profession', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.9118
# Fold 10: Selected features: ['history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_quadrant', 'tumour_locality', 'tumour_size_mm', 'her2_status', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs6009631', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.7696
# Mean AUC using top 35 features across 10 folds: 0.8723
# +-------------------------------------------+-------------+
# |                                           |   Frequency |
# |-------------------------------------------+-------------|
# | nodes_examined                            |          10 |
# | rs67342194                                |          10 |
# | radio_skin_max_dose_Gy                    |          10 |
# | radio_breast_ct_volume_cm3                |          10 |
# | post_operative_haematoma                  |          10 |
# | breast_right_arm_circumfrence_mm_baseline |          10 |
# | radio_supraclavicular_fossa               |          10 |
# | radio_ipsilateral_lung_mean_Gy            |          10 |
# | radio_heart_mean_dose_Gy                  |          10 |
# | rs77405610                                |          10 |
# | rs79223472                                |          10 |
# | rs10945395                                |          10 |
# | rs74853756                                |          10 |
# | rs72977387                                |          10 |
# | rs6009631                                 |          10 |
# | rs7195405                                 |          10 |
# | rs1788750                                 |          10 |
# | rs461769                                  |          10 |
# | rs61912468                                |          10 |
# | rs885170                                  |          10 |
# | rs72857489                                |          10 |
# | rs56402833                                |          10 |
# | rs633502                                  |           9 |
# | breast_arm_lymphodema_baseline            |           9 |
# | nodes_involved                            |           9 |
# | rs2954007                                 |           9 |
# | rs35410275                                |           9 |
# | rs35035095                                |           9 |
# | rs10764743                                |           8 |
# | history_of_heart_disease                  |           7 |
# | rs57288348                                |           7 |
# | breast_swollen_arm_baseline               |           6 |
# | rs2861705                                 |           6 |
# | axillary_levels                           |           5 |
# | radio_photon_2nd                          |           5 |
# | tumour_locality                           |           5 |
# | tumour_size_mm                            |           4 |
# | analgesics                                |           3 |
# | height_cm                                 |           3 |
# | rs3748569                                 |           3 |
# | her2_status                               |           3 |
# | age                                       |           2 |
# | band_size                                 |           2 |
# | education_profession                      |           2 |
# | bra_cup_size                              |           1 |
# | radio_hot_spots_107                       |           1 |
# | diabetes                                  |           1 |
# | t_stage                                   |           1 |
# | tumour_quadrant                           |           1 |
# +-------------------------------------------+-------------+
# Top 35 most frequently Features across 10 folds: ['nodes_examined', 'rs67342194', 'radio_skin_max_dose_Gy', 'radio_breast_ct_volume_cm3', 'post_operative_haematoma', 'breast_right_arm_circumfrence_mm_baseline', 'radio_supraclavicular_fossa', 'radio_ipsilateral_lung_mean_Gy', 'radio_heart_mean_dose_Gy', 'rs77405610', 'rs79223472', 'rs10945395', 'rs74853756', 'rs72977387', 'rs6009631', 'rs7195405', 'rs1788750', 'rs461769', 'rs61912468', 'rs885170', 'rs72857489', 'rs56402833', 'rs633502', 'breast_arm_lymphodema_baseline', 'nodes_involved', 'rs2954007', 'rs35410275', 'rs35035095', 'rs10764743', 'history_of_heart_disease', 'rs57288348', 'breast_swollen_arm_baseline', 'rs2861705', 'axillary_levels', 'radio_photon_2nd']
#
# 	*****************************************************************************************************************************************************************
#
#
# Fold 1: Selected features: ['height_cm', 'age', 'bra_cup_size', 'history_of_heart_disease', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_locality', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.9926
# Fold 2: Selected features: ['age', 'band_size', 'history_of_heart_disease', 'education_profession', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_locality', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_atrophy_baseline', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8787
# Fold 3: Selected features: ['age', 'bra_cup_size', 'band_size', 'history_of_heart_disease', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_locality', 'tumour_size_mm', 'her2_status', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.7757
# Fold 4: Selected features: ['age', 'band_size', 'diabetes', 'history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_locality', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.9044
# Fold 5: Selected features: ['history_of_heart_disease', 'hypertension', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_locality', 'tumour_size_mm', 'her2_status', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_atrophy_baseline', 'breast_skin_induration_tumour_bed_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8529
# Fold 6: Selected features: ['height_cm', 'age', 'band_size', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_locality', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_hot_spots_107', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.7353
# Fold 7: Selected features: ['height_cm', 'age', 'band_size', 'history_of_heart_disease', 'education_profession', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'Site', 'breast_atrophy_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.9314
# Fold 8: Selected features: ['height_cm', 'band_size', 'diabetes', 'analgesics', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_locality', 'tumour_histological_grade', 't_stage', 'her2_status', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.9167
# Fold 9: Selected features: ['height_cm', 'history_of_heart_disease', 'analgesics', 'education_profession', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_quadrant', 'her2_status', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'breast_atrophy_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.8971
# Fold 10: Selected features: ['band_size', 'history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_quadrant', 'tumour_locality', 'tumour_size_mm', 'her2_status', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'radio_photon_2nd', 'Site', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']| AUC: 0.7304
# Mean AUC using top 40 features across 10 folds: 0.8615
# +--------------------------------------------+-------------+
# |                                            |   Frequency |
# |--------------------------------------------+-------------|
# | nodes_involved                             |          10 |
# | radio_heart_mean_dose_Gy                   |          10 |
# | radio_breast_ct_volume_cm3                 |          10 |
# | radio_skin_max_dose_Gy                     |          10 |
# | post_operative_haematoma                   |          10 |
# | nodes_examined                             |          10 |
# | rs1788750                                  |          10 |
# | rs77405610                                 |          10 |
# | rs67342194                                 |          10 |
# | radio_supraclavicular_fossa                |          10 |
# | breast_right_arm_circumfrence_mm_baseline  |          10 |
# | radio_ipsilateral_lung_mean_Gy             |          10 |
# | rs461769                                   |          10 |
# | rs61912468                                 |          10 |
# | rs2861705                                  |          10 |
# | rs79223472                                 |          10 |
# | rs56402833                                 |          10 |
# | rs633502                                   |          10 |
# | rs72977387                                 |          10 |
# | rs57288348                                 |          10 |
# | rs6009631                                  |          10 |
# | rs7195405                                  |          10 |
# | rs72857489                                 |          10 |
# | rs35410275                                 |          10 |
# | rs74853756                                 |          10 |
# | rs10945395                                 |          10 |
# | rs885170                                   |          10 |
# | breast_arm_lymphodema_baseline             |           9 |
# | rs35035095                                 |           9 |
# | rs2954007                                  |           9 |
# | history_of_heart_disease                   |           8 |
# | rs10764743                                 |           8 |
# | tumour_locality                            |           8 |
# | radio_photon_2nd                           |           8 |
# | band_size                                  |           7 |
# | age                                        |           6 |
# | breast_swollen_arm_baseline                |           6 |
# | tumour_size_mm                             |           6 |
# | axillary_levels                            |           5 |
# | analgesics                                 |           5 |
# | height_cm                                  |           5 |
# | her2_status                                |           5 |
# | breast_atrophy_baseline                    |           4 |
# | rs3748569                                  |           4 |
# | radio_hot_spots_107                        |           3 |
# | education_profession                       |           3 |
# | bra_cup_size                               |           2 |
# | diabetes                                   |           2 |
# | tumour_quadrant                            |           2 |
# | Site                                       |           2 |
# | breast_skin_induration_tumour_bed_baseline |           1 |
# | hypertension                               |           1 |
# | tumour_histological_grade                  |           1 |
# | t_stage                                    |           1 |
# +--------------------------------------------+-------------+
# Top 40 most frequently Features across 10 folds: ['nodes_involved', 'radio_heart_mean_dose_Gy', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'post_operative_haematoma', 'nodes_examined', 'rs1788750', 'rs77405610', 'rs67342194', 'radio_supraclavicular_fossa', 'breast_right_arm_circumfrence_mm_baseline', 'radio_ipsilateral_lung_mean_Gy', 'rs461769', 'rs61912468', 'rs2861705', 'rs79223472', 'rs56402833', 'rs633502', 'rs72977387', 'rs57288348', 'rs6009631', 'rs7195405', 'rs72857489', 'rs35410275', 'rs74853756', 'rs10945395', 'rs885170', 'breast_arm_lymphodema_baseline', 'rs35035095', 'rs2954007', 'history_of_heart_disease', 'rs10764743', 'tumour_locality', 'radio_photon_2nd', 'band_size', 'age', 'breast_swollen_arm_baseline', 'tumour_size_mm', 'axillary_levels', 'analgesics']
#
# 	*****************************************************************************************************************************************************************

# %%
#print(feature_sets_featimportance_inside_pipeline)
stable_features_featimportance_inside_pipeline = get_frequent_features(
    feature_sets_featimportance_inside_pipeline,
    freq_threshold=8
)

print(stable_features_featimportance_inside_pipeline)
print(len(stable_features_featimportance_inside_pipeline))
# Out:
# ['tumour_locality', 'rs61912468', 'radio_skin_max_dose_Gy', 'rs79223472', 'rs6009631', 'breast_right_arm_circumfrence_mm_baseline', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'rs10945395', 'rs461769', 'rs57288348', 'history_of_heart_disease', 'rs74853756', 'rs2954007', 'rs10764743', 'rs7195405', 'radio_photon_2nd', 'post_operative_haematoma', 'rs1788750', 'rs35410275', 'rs67342194', 'radio_breast_ct_volume_cm3', 'nodes_examined', 'rs2861705', 'rs633502', 'rs885170', 'rs77405610', 'rs35035095', 'rs72977387', 'breast_arm_lymphodema_baseline', 'rs72857489', 'rs56402833', 'radio_heart_mean_dose_Gy', 'nodes_involved']
# 34

# %%
#df_Top_selected = df_20[top_features_final + [dependent1]]
cross_validated_feature_selection(df_clean_20[stable_features_featimportance_inside_pipeline + [dependent1]], dependent1, splits=10)
# Out:
# Original Data shape is (2067, 35)
# Data shape after dropping missing target: (1691, 35)
# ✅ Mean AUC with final selected features: 0.9079

# %% [markdown]
# ### Nested CV

# %%
def nested_cv_feature_selection2(
    df,
    target,
    k_list,
    outer_splits,
    inner_splits
):

    df = df.dropna()

    X = df.drop(columns=[target]).select_dtypes(include=["number"])
    y = df[target]

    outer_cv = StratifiedKFold(
        n_splits=outer_splits,
        shuffle=True,
        random_state=0
    )

    inner_cv = StratifiedKFold(
        n_splits=inner_splits,
        shuffle=True,
        random_state=1
    )

    results = {name: [] for name in get_models(X, y).keys()}
    fold_details = []

    for fold_id, (train_idx, test_idx) in enumerate(
        tqdm(outer_cv.split(X, y), desc="Outer CV"),
        start=1
    ):

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        best_k = None
        best_score = -np.inf

        # ==============================
        # INNER LOOP: choose best k
        # ==============================
        for k in k_list:
            inner_scores = []

            for inner_train_idx, inner_val_idx in inner_cv.split(X_train, y_train):

                X_tr = X_train.iloc[inner_train_idx]
                X_val = X_train.iloc[inner_val_idx]
                y_tr = y_train.iloc[inner_train_idx]
                y_val = y_train.iloc[inner_val_idx]

                selector = SelectFromModel(
                    ExtraTreesClassifier(random_state=10),
                    threshold=-np.inf,
                    max_features=k
                )

                pipeline = Pipeline([
                    ("feature_selection", selector),
                    ("model", RandomForestClassifier(
                        n_estimators=100,
                        random_state=5
                    ))

                ])

                pipeline.fit(X_tr, y_tr)

                y_pred = pipeline.predict_proba(X_val)[:, 1]
                inner_scores.append(roc_auc_score(y_val, y_pred))

            mean_score = np.mean(inner_scores)

            if mean_score > best_score:
                best_score = mean_score
                best_k = k

        # ==============================
        # OUTER LOOP: train final models
        # ==============================
        models = get_models(X_train, y_train)

        for name, model in models.items():

            selector = SelectFromModel(
                ExtraTreesClassifier(random_state=10),
                threshold=-np.inf,
                max_features=best_k
            )

            pipeline = Pipeline([
                ("feature_selection", selector),
                ("model", model)
            ])

            pipeline.fit(X_train, y_train)

            y_pred = pipeline.predict_proba(X_test)[:, 1]
            auc_score = roc_auc_score(y_test, y_pred)

            selected_mask = pipeline.named_steps[
                "feature_selection"
            ].get_support()

            selected_features = X_train.columns[selected_mask].tolist()

            results[name].append(auc_score)

            fold_details.append({
                "fold": fold_id,
                "model": name,
                "best_k": best_k,
                "inner_auc": best_score,
                "outer_auc": auc_score,
                "selected_features": selected_features
            })

    # ==============================
    # Model AUC summary
    # ==============================
    summary = {
        model: {
            "mean_auc": np.mean(scores),
            "std_auc": np.std(scores)
        }
        for model, scores in results.items()
    }

    summary = pd.DataFrame(summary).T.sort_values(
        by="mean_auc",
        ascending=False
    )

    fold_details = pd.DataFrame(fold_details)

    # ==============================
    # Feature frequency percentage
    # ==============================
    all_features = []

    for features in fold_details["selected_features"]:
        all_features.extend(features)

    feature_counts = Counter(all_features)

    feature_frequency = pd.DataFrame({
        "feature": feature_counts.keys(),
        "count": feature_counts.values()
    })

    feature_frequency["percentage"] = (
        100 * feature_frequency["count"] / len(fold_details)
    )

    feature_frequency = feature_frequency.sort_values(
        by="percentage",
        ascending=False
    ).reset_index(drop=True)

    return summary, fold_details, feature_frequency

# %%
summary2, fold_details2, feature_frequency2 = nested_cv_feature_selection2(df_clean_20, dependent1, k_list=k, outer_splits=10, inner_splits=5)
# Out:
# Outer CV: 10it [02:53, 17.31s/it]

# %%
summary2
# Out:
#               mean_auc   std_auc
# RandomForest  0.861642  0.082172

# %%
fold_details2
# Out:
#    fold         model  best_k  inner_auc  outer_auc  \
# 0     1  RandomForest      25   0.837155   0.992647
# 1     2  RandomForest      40   0.874884   0.882353
# 2     3  RandomForest      25   0.910408   0.792279
# 3     4  RandomForest      30   0.867436   0.733456
# 4     5  RandomForest      40   0.863076   0.887255
# 5     6  RandomForest      40   0.853933   0.759804
# 6     7  RandomForest      40   0.857964   0.955882
# 7     8  RandomForest      40   0.894161   0.838235
# 8     9  RandomForest      35   0.857736   0.946078
# 9    10  RandomForest      20   0.879610   0.828431
#
#                                    selected_features
# 0  [history_of_heart_disease, nodes_examined, pos...
# 1  [age, band_size, history_of_heart_disease, edu...
# 2  [history_of_heart_disease, nodes_examined, pos...
# 3  [history_of_heart_disease, nodes_involved, nod...
# 4  [history_of_heart_disease, hypertension, nodes...
# 5  [height_cm, age, band_size, analgesics, nodes_...
# 6  [height_cm, age, band_size, history_of_heart_d...
# 7  [height_cm, band_size, diabetes, analgesics, n...
# 8  [height_cm, analgesics, education_profession, ...
# 9  [nodes_involved, nodes_examined, post_operativ...

# %%
#print(feature_frequency.head(40))
display(feature_frequency2.head(100))
# Out:
#                                        feature  count  percentage
# 0                               nodes_examined     10       100.0
# 1                     post_operative_haematoma     10       100.0
# 2                  radio_supraclavicular_fossa     10       100.0
# 3               radio_ipsilateral_lung_mean_Gy     10       100.0
# 4                                   rs56402833     10       100.0
# 5                                    rs7195405     10       100.0
# 6                                   rs67342194     10       100.0
# 7                                   rs77405610     10       100.0
# 8                                   rs72857489     10       100.0
# 9                                     rs461769     10       100.0
# 10                                  rs10945395     10       100.0
# 11                                  rs74853756     10       100.0
# 12                                    rs885170     10       100.0
# 13                                  rs72977387      9        90.0
# 14   breast_right_arm_circumfrence_mm_baseline      9        90.0
# 15                                   rs6009631      9        90.0
# 16                                  rs79223472      9        90.0
# 17                    radio_heart_mean_dose_Gy      9        90.0
# 18              breast_arm_lymphodema_baseline      9        90.0
# 19                                   rs1788750      8        80.0
# 20                                  rs61912468      8        80.0
# 21                                  rs35410275      8        80.0
# 22                              nodes_involved      8        80.0
# 23                      radio_skin_max_dose_Gy      8        80.0
# 24                                  rs57288348      8        80.0
# 25                  radio_breast_ct_volume_cm3      7        70.0
# 26                                   rs2954007      7        70.0
# 27                                  rs10764743      7        70.0
# 28                                  rs35035095      7        70.0
# 29                                   rs2861705      7        70.0
# 30                                    rs633502      6        60.0
# 31                    history_of_heart_disease      6        60.0
# 32                 breast_swollen_arm_baseline      6        60.0
# 33                            radio_photon_2nd      5        50.0
# 34                                   band_size      4        40.0
# 35                              tumour_size_mm      4        40.0
# 36                             tumour_locality      4        40.0
# 37                                 her2_status      4        40.0
# 38                                   height_cm      4        40.0
# 39                        education_profession      3        30.0
# 40                         radio_hot_spots_107      3        30.0
# 41                     breast_atrophy_baseline      3        30.0
# 42                                         age      3        30.0
# 43                                  analgesics      3        30.0
# 44                             axillary_levels      2        20.0
# 45                                   rs3748569      2        20.0
# 46  breast_skin_induration_tumour_bed_baseline      1        10.0
# 47                                hypertension      1        10.0
# 48                                        Site      1        10.0
# 49                                    diabetes      1        10.0
# 50                   tumour_histological_grade      1        10.0
# 51                                     t_stage      1        10.0

# %%
# Features that appeared in 8 folds and more across 10 folds
stable_features2 = feature_frequency2[feature_frequency2["count"] >= 8]["feature"].tolist()

# %%
print (stable_features2)
# Out:
# ['nodes_examined', 'post_operative_haematoma', 'radio_supraclavicular_fossa', 'radio_ipsilateral_lung_mean_Gy', 'rs56402833', 'rs7195405', 'rs67342194', 'rs77405610', 'rs72857489', 'rs461769', 'rs10945395', 'rs74853756', 'rs885170', 'rs72977387', 'breast_right_arm_circumfrence_mm_baseline', 'rs6009631', 'rs79223472', 'radio_heart_mean_dose_Gy', 'breast_arm_lymphodema_baseline', 'rs1788750', 'rs61912468', 'rs35410275', 'nodes_involved', 'radio_skin_max_dose_Gy', 'rs57288348']

# %%
print(len(stable_features2))
# Out:
# 25

# %%
jaccard_stability(fold_details2, "RandomForest")
# Out:
# np.float64(0.633975142765204)

# %%
cross_validated_feature_selection(df_clean_20[stable_features2 + [dependent1]], dependent1, 10)
# Out:
# Original Data shape is (2067, 26)
# Data shape after dropping missing target: (1691, 26)
# ✅ Mean AUC with final selected features: 0.8989

# %% [markdown]
# ## Third feature selection method

# %% [markdown]
# **3.3.4 Recursive Feature Elimination (RFE)**
#
# ---
#
#
# Recursive Feature Elimination (RFE) is a feature selection method used in machine learning to identify the most relevant features for a predictive model. It works by recursively removing less important features and building the model on the remaining features to determine their importance.

# %% [markdown]
# ### outside CV

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import make_scorer, roc_auc_score
# This method ranking for example 20 features as rank 1 and other varies if set the features to 20 and so on

def rfe_feature_selection3(df, target_col, n_features):

    model = RandomForestClassifier(
                n_estimators=100,
                max_depth=10,
                min_samples_split=5,
                min_samples_leaf=1,
                bootstrap=True,
                random_state=5)

    # Drop rows with missing values
    df = df.dropna()

    # Separate features and target
    X = df.drop(columns=[target_col, 'Subject Id'])
    y = df[target_col]

    # Encode target if it's categorical
    #if y.dtype == 'object':
     #   y = LabelEncoder().fit_transform(y)

    # Split once for RFE
    X_train, _, y_train, _ = train_test_split(X, y, test_size=0.2, random_state=10)

    # RFE for top features
    rfe = RFE(estimator=model, n_features_to_select=n_features)
    rfe.fit(X_train, y_train)

    selected_features = X.columns[rfe.support_].tolist()
    bold('Process with'+ str(n_features) + ' Features:')
    print(f"\nList of top {n_features} features:\n", selected_features, '\n\n')

    # Cross-validated AUC on selected features
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
    auc_scores = cross_val_score(model, X[selected_features], y, cv=skf, scoring='roc_auc')

    #print(f"Cross-Validated AUC Scores: {auc_scores}")
    print(f"Mean AUC: {auc_scores.mean():.4f} | Std: {auc_scores.std():.4f}")

    # Feature ranking
    feature_ranking = pd.DataFrame({
        'Feature': X.columns,
        'Ranking': rfe.ranking_
    }).sort_values(by='Ranking')

    # Plot the feature ranking
    plt.figure(figsize=(10, 20))
    sns.barplot(
        x='Ranking',
        y='Feature',
        data=feature_ranking,
        palette='viridis',
        order=feature_ranking.sort_values('Ranking')['Feature']
    )
    plt.title("Feature Ranking (RFE)")
    plt.xlabel("RFE Ranking (1 = Most Important)")
    plt.ylabel("Features")
    plt.tight_layout()
    plt.show()

    return selected_features, auc_scores.mean(), feature_ranking

# %%
feature_sets_rfe = {}

for i in k:
    freq_df_scaled_auc= rfe_feature_selection3(df_clean_20, dependent1, i)
    feature_sets_rfe[i] = freq_df_scaled_auc
# Out:
# <p style='font-size:16pt;'>Process with10 Features:</p>
# List of top 10 features:
#  ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs7195405', 'rs461769', 'rs61912468']
#
#
# Mean AUC: 0.8462 | Std: 0.0929
# <p style='font-size:16pt;'>Process with15 Features:</p>
# List of top 15 features:
#  ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs2861705', 'rs10945395', 'rs461769', 'rs61912468', 'rs885170']
#
#
# Mean AUC: 0.8620 | Std: 0.0958
# <p style='font-size:16pt;'>Process with20 Features:</p>
# List of top 20 features:
#  ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs57288348', 'rs72977387', 'rs56402833', 'rs2861705', 'rs10945395', 'rs461769', 'rs61912468', 'rs35410275', 'rs885170']
#
#
# Mean AUC: 0.8610 | Std: 0.1072
# <p style='font-size:16pt;'>Process with25 Features:</p>
# List of top 25 features:
#  ['nodes_examined', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs2954007', 'rs57288348', 'rs72977387', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs35410275', 'rs885170']
#
#
# Mean AUC: 0.9037 | Std: 0.0576
# <p style='font-size:16pt;'>Process with30 Features:</p>
# List of top 30 features:
#  ['nodes_involved', 'nodes_examined', 'tumour_quadrant', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
#
#
# Mean AUC: 0.8549 | Std: 0.0689
# <p style='font-size:16pt;'>Process with35 Features:</p>
# List of top 35 features:
#  ['height_cm', 'age', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_quadrant', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
#
#
# Mean AUC: 0.8961 | Std: 0.0681
# <p style='font-size:16pt;'>Process with40 Features:</p>
# List of top 40 features:
#  ['height_cm', 'age', 'bra_cup_size', 'band_size', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_quadrant', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'Site', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
#
#
# Mean AUC: 0.8839 | Std: 0.0693

# %% [markdown]
# Takeaway6:
#
# * Mean AUC score using top 10 features: 0.84
#
# * Mean AUC score using top 15 features: 0.86
#
# * Mean AUC score using top 20 features: 0.86
#
# * Mean AUC score using top 25 features: 0.90
#
# * Mean AUC score using top 30 features: 0.85

# %%
from collections import Counter
import math

def get_stable_rfe_features(feature_sets_rfe, threshold_ratio=0.8):
    feature_counter = Counter()

    n_sets = len(feature_sets_rfe)
    threshold = math.ceil(threshold_ratio * n_sets)

    for k_value, (selected_features, auc, ranking_df) in feature_sets_rfe.items():

        # Features selected by RFE have Ranking == 1
        rfe_features = ranking_df.loc[
            ranking_df['Ranking'] == 1,
            'Feature'
        ].tolist()

        feature_counter.update(rfe_features)

    stable_features = [
        feature for feature, count in feature_counter.items()
        if count >= threshold
    ]

    return stable_features

# %%
stable_rfe_features = get_stable_rfe_features(
    feature_sets_rfe,
    threshold_ratio=0.8
)

print(stable_rfe_features)
print(len(stable_rfe_features))
# Out:
# ['nodes_examined', 'radio_ipsilateral_lung_mean_Gy', 'radio_heart_mean_dose_Gy', 'radio_skin_max_dose_Gy', 'rs77405610', 'breast_right_arm_circumfrence_mm_baseline', 'rs7195405', 'rs67342194', 'rs461769', 'rs61912468', 'radio_breast_ct_volume_cm3', 'rs885170', 'rs10945395', 'rs2861705', 'rs1788750']
# 15

# %%
cross_validated_feature_selection(df_clean_20[stable_rfe_features + [dependent1]], dependent1, 10)
# Out:
# Original Data shape is (2067, 16)
# Data shape after dropping missing target: (1691, 16)
# ✅ Mean AUC with final selected features: 0.8544

# %% [markdown]
# ### inside CV

# %%
def run_pipeline_with_feature_selection3(df, target_column, k):

    df = df.dropna()

    X = df.drop(columns=[target_column, 'Subject Id'])
    y = df[target_column]

    rf_for_rfe = RandomForestClassifier(n_estimators=100, max_depth=10,
                                        min_samples_split=5, min_samples_leaf=1,        bootstrap=True, random_state=5, n_jobs=-1)

    rf_classifier = RandomForestClassifier(n_estimators=100, max_depth=10,
                                          min_samples_split=5, min_samples_leaf=1,
                                          bootstrap=True,  random_state=5, n_jobs=-1)

    rfe_selector = RFE(estimator=rf_for_rfe, n_features_to_select=k, step=0.1)

    pipeline_rfe = Pipeline([('rfe', rfe_selector), ('classifier', rf_classifier)])

    cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)

    scores = cross_val_score(pipeline_rfe, X, y, cv=cv, scoring='roc_auc', n_jobs=-1)

    print(f"Mean AUC score using top {k} features Inside CV: {scores.mean():.2f}")
    return scores.mean()

# %%
#rfe_feature_selection3(df_cl20, dependent1, 20)

auc_scores_rfe_inside_pipeline = {}

for i in k:
    freq_df_scaled_auc= run_pipeline_with_feature_selection3(df_clean_20, dependent1, i)
    auc_scores_rfe_inside_pipeline[i] = freq_df_scaled_auc
# Out:
# Mean AUC score using top 10 features Inside CV: 0.79
# Mean AUC score using top 15 features Inside CV: 0.83
# Mean AUC score using top 20 features Inside CV: 0.85
# Mean AUC score using top 25 features Inside CV: 0.88
# Mean AUC score using top 30 features Inside CV: 0.89
# Mean AUC score using top 35 features Inside CV: 0.88
# Mean AUC score using top 40 features Inside CV: 0.86

# %% [markdown]
# ### Features frequency inside pipeline

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

def featureselection3_freq(df, target_col, n_features, n_splits):

    from collections import Counter
    import matplotlib.pyplot as plt
    import seaborn as sns
    from tabulate import tabulate

    df = df.dropna()

    X = df.drop(columns=[target_col, 'Subject Id'])
    y = df[target_col]

    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=0
    )

    auc_scores = []
    feature_counts = Counter()
    bold('Process with '+ str(n_features) + ' Features:')
    for fold, (train_idx, test_idx) in enumerate(skf.split(X, y)):

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        rfe_model = RandomForestClassifier(
            n_estimators=100,
            max_depth=10,
            min_samples_split=5,
            min_samples_leaf=1,
            bootstrap=True,
            random_state=5,
            n_jobs=-1
        )

        final_model = RandomForestClassifier(
            n_estimators=100,
            max_depth=10,
            min_samples_split=5,
            min_samples_leaf=1,
            bootstrap=True,
            random_state=5,
            n_jobs=-1
        )

        rfe = RFE(
            estimator=rfe_model,
            n_features_to_select=n_features,
            step=0.1
        )

        rfe.fit(X_train, y_train)

        selected_features = X_train.columns[rfe.support_].tolist()

        final_model.fit(X_train[selected_features], y_train)

        y_pred_proba = final_model.predict_proba(
            X_test[selected_features]
        )[:, 1]

        auc = roc_auc_score(y_test, y_pred_proba)

        auc_scores.append(auc)

        feature_counts.update(selected_features)


        print(
            f"Fold {fold+1}: "
            f"AUC = {auc:.4f} | "
            f"Selected Features: {selected_features}"
        )

    print(
        f"\nMean AUC: {np.mean(auc_scores):.4f} across {n_features} features"
        f"| Std: {np.std(auc_scores):.4f}"
    )

    freq_df = pd.DataFrame.from_dict(
        feature_counts,
        orient='index',
        columns=['Frequency']
    ).sort_values(by='Frequency', ascending=False)

    plt.figure(figsize=(10, 12))

    sns.barplot(
        x='Frequency',
        y=freq_df.index,
        data=freq_df
    )

    plt.xlabel('Selection Frequency')
    plt.ylabel('Features')

    plt.title(f'Feature Selection Frequency Across {n_splits} Folds' )

    plt.xticks(np.arange(0, n_splits + 1, 1))

    plt.show()

    print(tabulate(freq_df, headers='keys', tablefmt='psql'))

    return freq_df

# %%
feature_set_rfe_CV_inside_pipeline = {}
for i in k:
  feature_set_rfe_CV_inside_pipeline[i] = featureselection3_freq(df_clean_20, dependent1, i, 10)
# Out:
# <p style='font-size:16pt;'>Process with 10 Features:</p>
# Fold 1: AUC = 0.9522 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'rs77405610', 'rs67342194', 'rs10764743', 'rs35035095', 'rs10945395', 'rs72857489']
# Fold 2: AUC = 0.6434 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs35035095']
# Fold 3: AUC = 0.7390 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs72977387', 'rs56402833', 'rs72857489']
# Fold 4: AUC = 0.6949 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'rs67342194', 'rs2954007', 'rs35035095', 'rs56402833', 'rs461769', 'rs72857489']
# Fold 5: AUC = 0.7745 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs461769', 'rs72857489']
# Fold 6: AUC = 0.8725 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs56402833', 'rs461769', 'rs72857489']
# Fold 7: AUC = 0.8725 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'rs77405610', 'rs67342194', 'rs1788750', 'rs461769', 'rs72857489', 'rs885170']
# Fold 8: AUC = 0.7917 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs67342194', 'rs72977387', 'rs79223472', 'rs461769', 'rs72857489']
# Fold 9: AUC = 0.8922 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs72977387', 'rs72857489']
# Fold 10: AUC = 0.6789 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs67342194', 'rs1788750', 'rs7195405', 'rs10945395', 'rs461769', 'rs72857489']
#
# Mean AUC: 0.7912 across 10 features| Std: 0.0980
# +-------------------------------------------+-------------+
# |                                           |   Frequency |
# |-------------------------------------------+-------------|
# | nodes_examined                            |          10 |
# | radio_skin_max_dose_Gy                    |          10 |
# | rs67342194                                |          10 |
# | rs72857489                                |           9 |
# | radio_ipsilateral_lung_mean_Gy            |           8 |
# | radio_heart_mean_dose_Gy                  |           7 |
# | breast_right_arm_circumfrence_mm_baseline |           7 |
# | rs77405610                                |           7 |
# | rs461769                                  |           6 |
# | rs10764743                                |           5 |
# | radio_breast_ct_volume_cm3                |           4 |
# | rs35035095                                |           3 |
# | rs56402833                                |           3 |
# | rs72977387                                |           3 |
# | rs10945395                                |           2 |
# | rs1788750                                 |           2 |
# | rs2954007                                 |           1 |
# | rs885170                                  |           1 |
# | rs79223472                                |           1 |
# | rs7195405                                 |           1 |
# +-------------------------------------------+-------------+
# <p style='font-size:16pt;'>Process with 15 Features:</p>
# Fold 1: AUC = 1.0000 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs2954007', 'rs35035095', 'rs56402833', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']
# Fold 2: AUC = 0.7904 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs35035095', 'rs10945395', 'rs461769', 'rs72857489']
# Fold 3: AUC = 0.6801 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs72977387', 'rs56402833', 'rs10945395', 'rs61912468', 'rs72857489', 'rs885170']
# Fold 4: AUC = 0.8529 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs2954007', 'rs35035095', 'rs56402833', 'rs74853756', 'rs461769', 'rs72857489', 'rs885170']
# Fold 5: AUC = 0.8578 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs72977387', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 6: AUC = 0.9216 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs56402833', 'rs79223472', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']
# Fold 7: AUC = 0.8824 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs2954007', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']
# Fold 8: AUC = 0.9363 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs67342194', 'rs10764743', 'rs72977387', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs35410275']
# Fold 9: AUC = 0.8186 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs7195405', 'rs72977387', 'rs56402833', 'rs79223472', 'rs461769', 'rs72857489', 'rs885170']
# Fold 10: AUC = 0.5931 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs35035095', 'rs72977387', 'rs10945395', 'rs461769', 'rs72857489', 'rs35410275', 'rs885170']
#
# Mean AUC: 0.8333 across 15 features| Std: 0.1152
# +-------------------------------------------+-------------+
# |                                           |   Frequency |
# |-------------------------------------------+-------------|
# | nodes_examined                            |          10 |
# | radio_skin_max_dose_Gy                    |          10 |
# | radio_heart_mean_dose_Gy                  |          10 |
# | breast_right_arm_circumfrence_mm_baseline |          10 |
# | rs67342194                                |          10 |
# | rs72857489                                |          10 |
# | radio_ipsilateral_lung_mean_Gy            |           9 |
# | rs77405610                                |           9 |
# | rs461769                                  |           9 |
# | rs10764743                                |           8 |
# | rs885170                                  |           8 |
# | rs10945395                                |           7 |
# | rs56402833                                |           5 |
# | rs1788750                                 |           5 |
# | radio_breast_ct_volume_cm3                |           5 |
# | rs72977387                                |           5 |
# | rs35035095                                |           4 |
# | rs2954007                                 |           3 |
# | rs7195405                                 |           3 |
# | rs79223472                                |           3 |
# | rs35410275                                |           3 |
# | rs74853756                                |           2 |
# | rs61912468                                |           2 |
# +-------------------------------------------+-------------+
# <p style='font-size:16pt;'>Process with 20 Features:</p>
# Fold 1: AUC = 0.9890 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs7195405', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']
# Fold 2: AUC = 0.7831 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489']
# Fold 3: AUC = 0.7059 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs2861705', 'rs74853756', 'rs10945395', 'rs61912468', 'rs72857489', 'rs885170']
# Fold 4: AUC = 0.7978 | Selected Features: ['nodes_involved', 'nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs2954007', 'rs35035095', 'rs56402833', 'rs2861705', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']
# Fold 5: AUC = 0.8775 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs6009631', 'rs2954007', 'rs72977387', 'rs74853756', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 6: AUC = 0.9216 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']
# Fold 7: AUC = 0.9118 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs2954007', 'rs72977387', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs885170']
# Fold 8: AUC = 0.8922 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs2954007', 'rs72977387', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 9: AUC = 0.9363 | Selected Features: ['nodes_examined', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs7195405', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs79223472', 'rs74853756', 'rs461769', 'rs61912468', 'rs72857489', 'rs885170']
# Fold 10: AUC = 0.6495 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs7195405', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs79223472', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
#
# Mean AUC: 0.8464 across 20 features| Std: 0.1031
# +-------------------------------------------+-------------+
# |                                           |   Frequency |
# |-------------------------------------------+-------------|
# | nodes_examined                            |          10 |
# | radio_skin_max_dose_Gy                    |          10 |
# | radio_heart_mean_dose_Gy                  |          10 |
# | breast_right_arm_circumfrence_mm_baseline |          10 |
# | rs77405610                                |          10 |
# | rs67342194                                |          10 |
# | rs72857489                                |          10 |
# | rs10764743                                |           9 |
# | radio_ipsilateral_lung_mean_Gy            |           9 |
# | rs885170                                  |           9 |
# | rs461769                                  |           9 |
# | rs74853756                                |           9 |
# | rs72977387                                |           9 |
# | rs10945395                                |           8 |
# | rs2954007                                 |           8 |
# | rs35035095                                |           7 |
# | rs56402833                                |           7 |
# | rs61912468                                |           7 |
# | rs1788750                                 |           7 |
# | radio_breast_ct_volume_cm3                |           6 |
# | rs7195405                                 |           5 |
# | rs79223472                                |           5 |
# | rs57288348                                |           3 |
# | rs633502                                  |           3 |
# | rs2861705                                 |           3 |
# | rs35410275                                |           3 |
# | breast_arm_lymphodema_baseline            |           2 |
# | nodes_involved                            |           1 |
# | rs6009631                                 |           1 |
# +-------------------------------------------+-------------+
# <p style='font-size:16pt;'>Process with 25 Features:</p>
# Fold 1: AUC = 0.9816 | Selected Features: ['age', 'nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']
# Fold 2: AUC = 0.8713 | Selected Features: ['nodes_involved', 'nodes_examined', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs3748569', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275']
# Fold 3: AUC = 0.7353 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs885170']
# Fold 4: AUC = 0.8640 | Selected Features: ['nodes_involved', 'nodes_examined', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 5: AUC = 0.8284 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs6009631', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 6: AUC = 0.8922 | Selected Features: ['nodes_involved', 'nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs885170']
# Fold 7: AUC = 0.9118 | Selected Features: ['nodes_involved', 'nodes_examined', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs2954007', 'rs57288348', 'rs72977387', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs885170']
# Fold 8: AUC = 0.8873 | Selected Features: ['age', 'nodes_examined', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs72977387', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 9: AUC = 0.9559 | Selected Features: ['nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs885170']
# Fold 10: AUC = 0.8284 | Selected Features: ['nodes_involved', 'nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs2861705', 'rs79223472', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
#
# Mean AUC: 0.8756 across 25 features| Std: 0.0661
# +-------------------------------------------+-------------+
# |                                           |   Frequency |
# |-------------------------------------------+-------------|
# | nodes_examined                            |          10 |
# | radio_breast_ct_volume_cm3                |          10 |
# | radio_skin_max_dose_Gy                    |          10 |
# | radio_heart_mean_dose_Gy                  |          10 |
# | breast_right_arm_circumfrence_mm_baseline |          10 |
# | rs10764743                                |          10 |
# | rs67342194                                |          10 |
# | rs77405610                                |          10 |
# | rs10945395                                |          10 |
# | rs461769                                  |          10 |
# | rs72857489                                |          10 |
# | rs72977387                                |          10 |
# | radio_ipsilateral_lung_mean_Gy            |           9 |
# | rs885170                                  |           9 |
# | rs74853756                                |           9 |
# | rs79223472                                |           9 |
# | rs7195405                                 |           8 |
# | rs6009631                                 |           8 |
# | rs2954007                                 |           8 |
# | rs35035095                                |           8 |
# | breast_arm_lymphodema_baseline            |           8 |
# | rs56402833                                |           8 |
# | rs61912468                                |           7 |
# | rs1788750                                 |           7 |
# | rs2861705                                 |           5 |
# | rs57288348                                |           5 |
# | rs633502                                  |           5 |
# | nodes_involved                            |           5 |
# | rs35410275                                |           5 |
# | tumour_size_mm                            |           4 |
# | age                                       |           2 |
# | rs3748569                                 |           1 |
# +-------------------------------------------+-------------+
# <p style='font-size:16pt;'>Process with 30 Features:</p>
# Fold 1: AUC = 1.0000 | Selected Features: ['age', 'nodes_examined', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 2: AUC = 0.9007 | Selected Features: ['age', 'nodes_involved', 'nodes_examined', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 3: AUC = 0.7279 | Selected Features: ['height_cm', 'nodes_involved', 'nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 4: AUC = 0.8713 | Selected Features: ['height_cm', 'nodes_involved', 'nodes_examined', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 5: AUC = 0.9363 | Selected Features: ['nodes_involved', 'nodes_examined', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 6: AUC = 0.9167 | Selected Features: ['height_cm', 'age', 'nodes_involved', 'nodes_examined', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 7: AUC = 0.8382 | Selected Features: ['nodes_involved', 'nodes_examined', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 8: AUC = 0.9265 | Selected Features: ['age', 'nodes_examined', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 9: AUC = 0.9559 | Selected Features: ['height_cm', 'age', 'nodes_involved', 'nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 10: AUC = 0.7941 | Selected Features: ['nodes_involved', 'nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
#
# Mean AUC: 0.8868 across 30 features| Std: 0.0769
# +-------------------------------------------+-------------+
# |                                           |   Frequency |
# |-------------------------------------------+-------------|
# | nodes_examined                            |          10 |
# | radio_breast_ct_volume_cm3                |          10 |
# | rs885170                                  |          10 |
# | radio_skin_max_dose_Gy                    |          10 |
# | radio_heart_mean_dose_Gy                  |          10 |
# | radio_ipsilateral_lung_mean_Gy            |          10 |
# | rs77405610                                |          10 |
# | breast_right_arm_circumfrence_mm_baseline |          10 |
# | rs1788750                                 |          10 |
# | rs67342194                                |          10 |
# | rs6009631                                 |          10 |
# | rs2954007                                 |          10 |
# | rs10764743                                |          10 |
# | rs7195405                                 |          10 |
# | rs35035095                                |          10 |
# | rs10945395                                |          10 |
# | rs633502                                  |          10 |
# | rs72977387                                |          10 |
# | rs72857489                                |          10 |
# | rs35410275                                |          10 |
# | rs461769                                  |          10 |
# | rs79223472                                |           9 |
# | breast_arm_lymphodema_baseline            |           9 |
# | rs74853756                                |           9 |
# | rs56402833                                |           9 |
# | rs61912468                                |           8 |
# | nodes_involved                            |           8 |
# | rs2861705                                 |           8 |
# | rs57288348                                |           7 |
# | tumour_size_mm                            |           7 |
# | age                                       |           5 |
# | rs3748569                                 |           4 |
# | height_cm                                 |           4 |
# | axillary_levels                           |           3 |
# +-------------------------------------------+-------------+
# <p style='font-size:16pt;'>Process with 35 Features:</p>
# Fold 1: AUC = 0.9890 | Selected Features: ['age', 'nodes_involved', 'nodes_examined', 'tumour_quadrant', 'tumour_size_mm', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'Site', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 2: AUC = 0.7904 | Selected Features: ['height_cm', 'age', 'band_size', 'nodes_involved', 'nodes_examined', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 3: AUC = 0.7831 | Selected Features: ['height_cm', 'age', 'band_size', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_quadrant', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 4: AUC = 0.8419 | Selected Features: ['height_cm', 'age', 'nodes_involved', 'nodes_examined', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'Site', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 5: AUC = 0.8873 | Selected Features: ['height_cm', 'age', 'nodes_involved', 'nodes_examined', 'tumour_quadrant', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'Site', 'breast_atrophy_baseline', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 6: AUC = 0.9069 | Selected Features: ['height_cm', 'age', 'nodes_involved', 'nodes_examined', 'tumour_quadrant', 'tumour_size_mm', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 7: AUC = 0.8873 | Selected Features: ['height_cm', 'nodes_involved', 'nodes_examined', 'tumour_size_mm', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'Site', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 8: AUC = 0.9559 | Selected Features: ['height_cm', 'age', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 9: AUC = 0.9020 | Selected Features: ['height_cm', 'age', 'nodes_involved', 'nodes_examined', 'tumour_quadrant', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 10: AUC = 0.8480 | Selected Features: ['height_cm', 'age', 'band_size', 'nodes_involved', 'nodes_examined', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'Site', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
#
# Mean AUC: 0.8792 across 35 features| Std: 0.0623
# +-------------------------------------------+-------------+
# |                                           |   Frequency |
# |-------------------------------------------+-------------|
# | nodes_involved                            |          10 |
# | nodes_examined                            |          10 |
# | radio_ipsilateral_lung_mean_Gy            |          10 |
# | radio_heart_mean_dose_Gy                  |          10 |
# | radio_skin_max_dose_Gy                    |          10 |
# | radio_breast_ct_volume_cm3                |          10 |
# | rs67342194                                |          10 |
# | rs1788750                                 |          10 |
# | breast_right_arm_circumfrence_mm_baseline |          10 |
# | rs77405610                                |          10 |
# | rs72857489                                |          10 |
# | rs61912468                                |          10 |
# | rs35410275                                |          10 |
# | rs461769                                  |          10 |
# | rs10764743                                |          10 |
# | rs7195405                                 |          10 |
# | rs2954007                                 |          10 |
# | rs6009631                                 |          10 |
# | rs633502                                  |          10 |
# | rs56402833                                |          10 |
# | rs35035095                                |          10 |
# | rs72977387                                |          10 |
# | rs2861705                                 |          10 |
# | rs10945395                                |          10 |
# | rs74853756                                |          10 |
# | rs79223472                                |          10 |
# | rs885170                                  |          10 |
# | height_cm                                 |           9 |
# | tumour_size_mm                            |           9 |
# | age                                       |           9 |
# | breast_arm_lymphodema_baseline            |           9 |
# | rs57288348                                |           9 |
# | axillary_levels                           |           7 |
# | tumour_quadrant                           |           5 |
# | rs3748569                                 |           5 |
# | Site                                      |           5 |
# | radio_photon_dose_MV                      |           3 |
# | band_size                                 |           3 |
# | breast_swollen_arm_baseline               |           3 |
# | post_operative_haematoma                  |           2 |
# | radio_supraclavicular_fossa               |           1 |
# | breast_atrophy_baseline                   |           1 |
# +-------------------------------------------+-------------+
# <p style='font-size:16pt;'>Process with 40 Features:</p>
# Fold 1: AUC = 0.9926 | Selected Features: ['height_cm', 'age', 'bra_cup_size', 'history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_quadrant', 'tumour_size_mm', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'Site', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 2: AUC = 0.8897 | Selected Features: ['height_cm', 'age', 'bra_cup_size', 'band_size', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_quadrant', 'tumour_size_mm', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_supraclavicular_fossa', 'Site', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 3: AUC = 0.7941 | Selected Features: ['height_cm', 'age', 'band_size', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_quadrant', 'tumour_size_mm', 'her2_status', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'Site', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 4: AUC = 0.8824 | Selected Features: ['height_cm', 'age', 'history_of_heart_disease', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_size_mm', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'Site', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 5: AUC = 0.7794 | Selected Features: ['height_cm', 'age', 'nodes_involved', 'nodes_examined', 'tumour_quadrant', 'tumour_size_mm', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'Site', 'breast_atrophy_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 6: AUC = 0.8922 | Selected Features: ['height_cm', 'age', 'nodes_involved', 'nodes_examined', 'tumour_quadrant', 'tumour_size_mm', 't_stage', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_atrophy_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 7: AUC = 0.9216 | Selected Features: ['height_cm', 'age', 'nodes_involved', 'nodes_examined', 'tumour_quadrant', 'tumour_size_mm', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_photon_2nd', 'Site', 'breast_atrophy_baseline', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 8: AUC = 0.7745 | Selected Features: ['height_cm', 'age', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_quadrant', 'tumour_size_mm', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'Site', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 9: AUC = 0.9363 | Selected Features: ['height_cm', 'age', 'nodes_involved', 'nodes_examined', 'post_operative_haematoma', 'tumour_quadrant', 'tumour_size_mm', 't_stage', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'breast_arm_lymphodema_baseline', 'breast_swollen_arm_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
# Fold 10: AUC = 0.7500 | Selected Features: ['height_cm', 'age', 'band_size', 'nodes_involved', 'nodes_examined', 'tumour_quadrant', 'tumour_size_mm', 'radio_photon_dose_MV', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'axillary_levels', 'radio_supraclavicular_fossa', 'Site', 'breast_atrophy_baseline', 'breast_arm_lymphodema_baseline', 'breast_right_arm_circumfrence_mm_baseline', 'rs77405610', 'rs67342194', 'rs1788750', 'rs10764743', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'rs72977387', 'rs56402833', 'rs633502', 'rs2861705', 'rs3748569', 'rs79223472', 'rs74853756', 'rs10945395', 'rs461769', 'rs61912468', 'rs72857489', 'rs35410275', 'rs885170']
#
# Mean AUC: 0.8613 across 40 features| Std: 0.0774
# +-------------------------------------------+-------------+
# |                                           |   Frequency |
# |-------------------------------------------+-------------|
# | height_cm                                 |          10 |
# | age                                       |          10 |
# | nodes_involved                            |          10 |
# | nodes_examined                            |          10 |
# | radio_heart_mean_dose_Gy                  |          10 |
# | radio_breast_ct_volume_cm3                |          10 |
# | tumour_size_mm                            |          10 |
# | radio_ipsilateral_lung_mean_Gy            |          10 |
# | radio_skin_max_dose_Gy                    |          10 |
# | rs7195405                                 |          10 |
# | rs10764743                                |          10 |
# | rs67342194                                |          10 |
# | rs1788750                                 |          10 |
# | breast_right_arm_circumfrence_mm_baseline |          10 |
# | rs77405610                                |          10 |
# | rs885170                                  |          10 |
# | rs61912468                                |          10 |
# | rs74853756                                |          10 |
# | rs10945395                                |          10 |
# | rs461769                                  |          10 |
# | rs35410275                                |          10 |
# | rs2954007                                 |          10 |
# | rs6009631                                 |          10 |
# | rs72977387                                |          10 |
# | rs56402833                                |          10 |
# | rs57288348                                |          10 |
# | rs35035095                                |          10 |
# | rs633502                                  |          10 |
# | rs2861705                                 |          10 |
# | rs79223472                                |          10 |
# | rs3748569                                 |          10 |
# | rs72857489                                |          10 |
# | radio_photon_dose_MV                      |           9 |
# | tumour_quadrant                           |           9 |
# | radio_supraclavicular_fossa               |           9 |
# | breast_arm_lymphodema_baseline            |           9 |
# | Site                                      |           8 |
# | axillary_levels                           |           8 |
# | breast_swollen_arm_baseline               |           7 |
# | post_operative_haematoma                  |           6 |
# | breast_atrophy_baseline                   |           4 |
# | band_size                                 |           3 |
# | history_of_heart_disease                  |           2 |
# | bra_cup_size                              |           2 |
# | t_stage                                   |           2 |
# | her2_status                               |           1 |
# | radio_photon_2nd                          |           1 |
# +-------------------------------------------+-------------+

# %%
#feature_set_rfe_CV_inside_pipeline

stable_features_rfe_inside_pipeline = get_frequent_features(
    feature_set_rfe_CV_inside_pipeline,
    freq_threshold=8
)

print(stable_features_rfe_inside_pipeline)
print(len(stable_features_rfe_inside_pipeline))
# Out:
# ['rs61912468', 'radio_skin_max_dose_Gy', 'tumour_size_mm', 'rs79223472', 'Site', 'rs6009631', 'breast_right_arm_circumfrence_mm_baseline', 'radio_ipsilateral_lung_mean_Gy', 'tumour_quadrant', 'radio_supraclavicular_fossa', 'rs10945395', 'age', 'rs461769', 'height_cm', 'rs3748569', 'rs57288348', 'radio_photon_dose_MV', 'rs74853756', 'rs2954007', 'rs10764743', 'rs7195405', 'rs1788750', 'rs35410275', 'rs67342194', 'radio_breast_ct_volume_cm3', 'nodes_examined', 'rs2861705', 'rs633502', 'rs885170', 'rs77405610', 'rs35035095', 'rs72977387', 'breast_arm_lymphodema_baseline', 'rs72857489', 'rs56402833', 'radio_heart_mean_dose_Gy', 'axillary_levels', 'nodes_involved']
# 38

# %%
cross_validated_feature_selection(df_clean_20[stable_features_rfe_inside_pipeline + [dependent1]], dependent1, splits=10)
# Out:
# Original Data shape is (2067, 39)
# Data shape after dropping missing target: (1691, 39)
# ✅ Mean AUC with final selected features: 0.8834

# %% [markdown]
# ### Nested CV

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from collections import Counter
import numpy as np
import pandas as pd
from tqdm import tqdm


def nested_cv_feature_selection_rfe(
    df,
    target,
    k_list,
    outer_splits,
    inner_splits
):

    df = df.dropna(subset=[target])

    X = df.drop(columns=[target]).select_dtypes(include=["number"])
    y = df[target]

    X = X.fillna(X.median())

    outer_cv = StratifiedKFold(
        n_splits=outer_splits,
        shuffle=True,
        random_state=0
    )

    inner_cv = StratifiedKFold(
        n_splits=inner_splits,
        shuffle=True,
        random_state=1
    )

    results = {name: [] for name in get_models(X, y).keys()}
    fold_details = []

    for fold_id, (train_idx, test_idx) in enumerate(
        tqdm(outer_cv.split(X, y), desc="Outer CV"),
        start=1
    ):

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        best_k = None
        best_score = -np.inf

        # INNER LOOP: choose best number of features
        for k in k_list:
            inner_scores = []

            for inner_train_idx, inner_val_idx in inner_cv.split(X_train, y_train):

                X_tr = X_train.iloc[inner_train_idx]
                X_val = X_train.iloc[inner_val_idx]
                y_tr = y_train.iloc[inner_train_idx]
                y_val = y_train.iloc[inner_val_idx]

                rfe_estimator = RandomForestClassifier(
                    n_estimators=30,
                    max_depth=10,
                    min_samples_split=5,
                    min_samples_leaf=1,
                    bootstrap=True,
                    random_state=5,
                    n_jobs=-1
                )

                pipeline = Pipeline([
                    ("scaler", MinMaxScaler()),
                    ("feature_selection", RFE(
                        estimator=rfe_estimator,
                        n_features_to_select=k,
                        step=0.5
                    )),
                    ("model", RandomForestClassifier(
                        n_estimators=100,
                        max_depth=10,
                        min_samples_split=5,
                        min_samples_leaf=1,
                        bootstrap=True,
                        random_state=5,
                        n_jobs=-1
                    ))
                ])

                pipeline.fit(X_tr, y_tr)

                y_pred = pipeline.predict_proba(X_val)[:, 1]
                inner_scores.append(roc_auc_score(y_val, y_pred))

            mean_score = np.mean(inner_scores)

            if mean_score > best_score:
                best_score = mean_score
                best_k = k

        # OUTER LOOP: train final models using best_k
        models = get_models(X_train, y_train)

        for name, model in models.items():

            rfe_estimator = RandomForestClassifier(
                n_estimators=100,
                max_depth=10,
                min_samples_split=5,
                min_samples_leaf=1,
                bootstrap=True,
                random_state=5,
                n_jobs=-1
            )

            pipeline = Pipeline([
                ("scaler", MinMaxScaler()),
                ("feature_selection", RFE(
                    estimator=rfe_estimator,
                    n_features_to_select=best_k,
                    step=0.1
                )),
                ("model", model)
            ])

            pipeline.fit(X_train, y_train)

            y_pred = pipeline.predict_proba(X_test)[:, 1]
            auc_score = roc_auc_score(y_test, y_pred)

            selected_mask = pipeline.named_steps["feature_selection"].get_support()
            selected_features = X_train.columns[selected_mask].tolist()

            results[name].append(auc_score)

            fold_details.append({
                "fold": fold_id,
                "model": name,
                "best_k": best_k,
                "inner_auc": best_score,
                "outer_auc": auc_score,
                "selected_features": selected_features
            })

    summary = pd.DataFrame({
        model: {
            "mean_auc": np.mean(scores),
            "std_auc": np.std(scores)
        }
        for model, scores in results.items()
    }).T.sort_values(by="mean_auc", ascending=False)

    fold_details = pd.DataFrame(fold_details)

    all_features = []
    for features in fold_details["selected_features"]:
        all_features.extend(features)

    feature_counts = Counter(all_features)

    feature_frequency = pd.DataFrame({
        "feature": feature_counts.keys(),
        "count": feature_counts.values()
    })

    feature_frequency["percentage"] = (
        100 * feature_frequency["count"] / len(fold_details)
    )

    feature_frequency = feature_frequency.sort_values(
        by="percentage",
        ascending=False
    ).reset_index(drop=True)

    return summary, fold_details, feature_frequency

# %%
summary3, fold_details3, feature_frequency3 = nested_cv_feature_selection_rfe(df_clean_20, dependent1, k_list=k, outer_splits=10, inner_splits=5)
# Out:
# Outer CV: 10it [06:44, 40.44s/it]

# %%
summary3  #
# Out:
#               mean_auc   std_auc
# RandomForest  0.878965  0.050708

# %%
fold_details3
# Out:
#    fold         model  best_k  inner_auc  outer_auc  \
# 0     1  RandomForest      40   0.881223   0.840491
# 1     2  RandomForest      40   0.884068   0.950920
# 2     3  RandomForest      25   0.885208   0.936605
# 3     4  RandomForest      40   0.887067   0.862986
# 4     5  RandomForest      40   0.866693   0.817996
# 5     6  RandomForest      40   0.874067   0.806748
# 6     7  RandomForest      35   0.895594   0.898773
# 7     8  RandomForest      35   0.902012   0.843558
# 8     9  RandomForest      40   0.862450   0.948854
# 9    10  RandomForest      35   0.889341   0.882716
#
#                                    selected_features
# 0  [height_cm, age, nodes_involved, nodes_examine...
# 1  [age, bra_cup_size, education_profession, node...
# 2  [age, nodes_examined, radio_breast_ct_volume_c...
# 3  [height_cm, age, bra_cup_size, education_profe...
# 4  [height_cm, age, bra_cup_size, analgesics, nod...
# 5  [height_cm, age, bra_cup_size, education_profe...
# 6  [height_cm, age, nodes_involved, nodes_examine...
# 7  [height_cm, age, nodes_involved, nodes_examine...
# 8  [height_cm, age, education_profession, nodes_i...
# 9  [age, education_profession, nodes_involved, no...

# %%
display(feature_frequency3.head(100))
# Out:
#                                       feature  count  percentage
# 0                                         age     10       100.0
# 1                              nodes_examined     10       100.0
# 2                    radio_heart_mean_dose_Gy     10       100.0
# 3              radio_ipsilateral_lung_mean_Gy     10       100.0
# 4                  radio_breast_ct_volume_cm3     10       100.0
# 5                      radio_skin_max_dose_Gy     10       100.0
# 6                                   rs7195405     10       100.0
# 7                                   rs6009631     10       100.0
# 8                                   rs2954007     10       100.0
# 9                                  rs57288348     10       100.0
# 10                                 rs35035095     10       100.0
# 11  breast_right_arm_circumfrence_mm_baseline     10       100.0
# 12                                 rs67342194     10       100.0
# 13                                 rs35410275     10       100.0
# 14                                 rs72857489     10       100.0
# 15                                   rs885170     10       100.0
# 16                                 rs61912468     10       100.0
# 17                                 rs10945395     10       100.0
# 18                                   rs461769     10       100.0
# 19                                 rs79223472     10       100.0
# 20                                 rs10764743     10       100.0
# 21                                 rs72977387     10       100.0
# 22                                 rs56402833     10       100.0
# 23                                  rs2861705     10       100.0
# 24                                   rs633502      9        90.0
# 25                radio_supraclavicular_fossa      9        90.0
# 26                             nodes_involved      9        90.0
# 27                             tumour_size_mm      9        90.0
# 28                                  rs3748569      9        90.0
# 29                                 rs77405610      9        90.0
# 30             breast_arm_lymphodema_baseline      9        90.0
# 31                                  rs1788750      9        90.0
# 32                       radio_photon_dose_MV      8        80.0
# 33                                 rs74853756      7        70.0
# 34                                  height_cm      7        70.0
# 35                                       Site      6        60.0
# 36                       education_profession      5        50.0
# 37                               bra_cup_size      4        40.0
# 38                            axillary_levels      4        40.0
# 39                   post_operative_haematoma      4        40.0
# 40                breast_swollen_arm_baseline      4        40.0
# 41                            tumour_quadrant      3        30.0
# 42                   radio_breast_delineation      3        30.0
# 43                    breast_atrophy_baseline      2        20.0
# 44                                 analgesics      1        10.0

# %%
# Features that appeared in 8 folds and more across 10 folds
stable_features3 = feature_frequency3[feature_frequency3["count"] >= 8]["feature"].tolist()

# %%
print(stable_features3)
# Out:
# ['age', 'nodes_examined', 'radio_heart_mean_dose_Gy', 'radio_ipsilateral_lung_mean_Gy', 'radio_breast_ct_volume_cm3', 'radio_skin_max_dose_Gy', 'rs7195405', 'rs6009631', 'rs2954007', 'rs57288348', 'rs35035095', 'breast_right_arm_circumfrence_mm_baseline', 'rs67342194', 'rs35410275', 'rs72857489', 'rs885170', 'rs61912468', 'rs10945395', 'rs461769', 'rs79223472', 'rs10764743', 'rs72977387', 'rs56402833', 'rs2861705', 'rs633502', 'radio_supraclavicular_fossa', 'nodes_involved', 'tumour_size_mm', 'rs3748569', 'rs77405610', 'breast_arm_lymphodema_baseline', 'rs1788750', 'radio_photon_dose_MV']

# %%
print(len(stable_features3))
# Out:
# 33

# %%
jaccard_stability(fold_details3, "RandomForest")
# Out:
# np.float64(0.8122143874547076)

# %%
cross_validated_feature_selection(df_clean_20[stable_features3 + [dependent1]], dependent1, splits=10)
# Out:
# Original Data shape is (2067, 34)
# Data shape after dropping missing target: (1691, 34)
# ✅ Mean AUC with final selected features: 0.8884

# %% [markdown]
# ## Feature Selection 4

# %% [markdown]
# **3.3.5 AutoEncoder feature selection (AE)**
#
# ---
#
#
# Autoencoder is a type of neural network used to compress data (encode) and then reconstruct it (decode). It's unsupervised — you don’t need labels to train it.The trick is — the middle layer has fewer neurons (features), so it must learn the most important information to recreate the original. For feature selection method, it is used to extract features with Hidden Patterns. Let’s say you're working with:
#
# Medical data with 200+ features (demographics, genomics, imaging, etc.)
#
# Training an autoencoder to reduce this to 10–20 learned features helps:
#
# Find underlying structure
#
# Reduce noise/redundancy
#
# Improve model generalization.

# %% [markdown]
# ### Encoding features only

# %%
#
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
import keras # Assuming keras is already imported and configured

def auto_encoder_feature_selection(df, col, feat):
  # Drop rows with any missing values as specified in the original function
  df = df.dropna(axis=0, how='any', inplace=False)

  # Separate features (X) and target (Y)
  # Drop target column and 'Subject Id'
  X = df.drop(columns=[col, 'Subject Id'])
  Y = df[col]

  # Explicitly drop all datetime columns before further processing
  # This ensures StandardScaler does not encounter them.
  datetime_cols = X.select_dtypes(include=['datetime64']).columns
  if not datetime_cols.empty:
      X = X.drop(columns=datetime_cols)

  # Convert categorical columns to numeric using one-hot encoding
  X = pd.get_dummies(X, drop_first=True)

  # Ensure all remaining columns are numeric before scaling
  # This acts as a safeguard, though explicit datetime dropping should prevent the specific error.
  X = X.select_dtypes(include=np.number)

  # Normalize features
  scaler = StandardScaler()
  X_scaled = scaler.fit_transform(X)

  # -------------------------------
  # Step 2: Autoencoder Architecture
  # -------------------------------
  input_dim = X_scaled.shape[1]
  encoding_dim = feat  # Set number of features you want to reduce to

  # Define the model
  input_layer = Input(shape=(input_dim,))
  #encoded = Dense(encoding_dim, activation='relu')(input_layer)
  #decoded = Dense(input_dim, activation='sigmoid')(encoded)

  encoded = keras.layers.Dense(encoding_dim, activation="relu")(input_layer)
  decoded = keras.layers.Dense(input_dim, activation="sigmoid")(encoded)



  autoencoder = Model(inputs=input_layer, outputs=decoded)
  autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
  autoencoder.summary()

  # ----------------------------
  # Step 3: Train the Autoencoder
  # ----------------------------
  # Ensure Y has the same index as X after dropping NaNs and columns
  Y = Y.loc[X.index]
  X_train, X_test = train_test_split(X_scaled, test_size=0.2, random_state=42, stratify=Y)
  autoencoder.fit(X_train, X_train,
                  epochs=50,
                  batch_size=32,
                  shuffle=True,
                  validation_data=(X_test, X_test),
                  verbose=0)

  # ----------------------------
  # Step 4: Extract Encoded Features
  # ----------------------------
  encoder = Model(inputs=autoencoder.input, outputs=autoencoder.layers[1].output)
  encoded_features = encoder.predict(X_scaled)

  return encoded_features, Y

# %%
encoded_features, Y= auto_encoder_feature_selection(df_clean_20, dependent1, 20)
# Out:
# Model: "functional_522"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_261 (InputLayer)    │ (None, 97)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_522 (Dense)               │ (None, 20)             │         1,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_523 (Dense)               │ (None, 97)             │         2,037 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,997 (15.61 KB)
#  Trainable params: 3,997 (15.61 KB)
#  Non-trainable params: 0 (0.00 B)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
encoded_features.shape
# Out:
# (714, 20)

# %% [markdown]
# ### Inside the pipline

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
import numpy as np

class AutoencoderFeatureSelector(BaseEstimator, TransformerMixin):
    def __init__(self, encoding_dim=10, epochs=50, batch_size=32, verbose=0):
        self.encoding_dim = encoding_dim
        self.epochs = epochs
        self.batch_size = batch_size
        self.verbose = verbose

    def fit(self, X, y=None):
        input_dim = X.shape[1]
        input_layer = Input(shape=(input_dim,))
        encoded = Dense(self.encoding_dim, activation='relu',
                        activity_regularizer=regularizers.l1(1e-5))(input_layer)
        decoded = Dense(input_dim, activation='linear')(encoded)

        self.autoencoder = Model(inputs=input_layer, outputs=decoded)
        self.encoder = Model(inputs=input_layer, outputs=encoded)

        self.autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
        self.autoencoder.fit(X, X,
                             epochs=self.epochs,
                             batch_size=self.batch_size,
                             shuffle=True,
                             verbose=self.verbose)
        return self

    def transform(self, X):
        return self.encoder.predict(X)

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler

def autoencoder_feature_pipeline(df, dependent, encoding_dim):
    df = df.dropna()
    X = df.drop(columns=[dependent]).select_dtypes(include=['number'])
    y = df[dependent]

    bold('Precess with ' + str(encoding_dim) + ' encoding dimensions')

    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('autoencoder_selector', AutoencoderFeatureSelector(encoding_dim=encoding_dim, epochs=50)),
        ('classifier', RandomForestClassifier(n_estimators=100, max_depth=10, random_state=5))
    ])

    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
    auc_scores = cross_val_score(pipeline, X, y, cv=skf, scoring='roc_auc')

    print(f"Mean AUC with Autoencoder-{encoding_dim} encoding dimension: {auc_scores.mean():.2f}")
    return auc_scores.mean()

# %%
for i in k:
  autoencoder_feature_pipeline(df_clean_20, dependent1, i)
# Out:
# <p style='font-size:16pt;'>Precess with 10 encoding dimensions</p>
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Mean AUC with Autoencoder-10 encoding dimension: 0.69
# <p style='font-size:16pt;'>Precess with 15 encoding dimensions</p>
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Mean AUC with Autoencoder-15 encoding dimension: 0.76
# <p style='font-size:16pt;'>Precess with 20 encoding dimensions</p>
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Mean AUC with Autoencoder-20 encoding dimension: 0.80
# <p style='font-size:16pt;'>Precess with 25 encoding dimensions</p>
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Mean AUC with Autoencoder-25 encoding dimension: 0.77
# <p style='font-size:16pt;'>Precess with 30 encoding dimensions</p>
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Mean AUC with Autoencoder-30 encoding dimension: 0.79
# <p style='font-size:16pt;'>Precess with 35 encoding dimensions</p>
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Mean AUC with Autoencoder-35 encoding dimension: 0.82
# <p style='font-size:16pt;'>Precess with 40 encoding dimensions</p>
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Mean AUC with Autoencoder-40 encoding dimension: 0.84

# %% [markdown]
# ### Nested CV

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
import numpy as np

# %%
class AutoencoderFeatureSelectorNew(BaseEstimator, TransformerMixin):
    def __init__(self, encoding_dim=10, epochs=30, batch_size=32, verbose=0):
        self.encoding_dim = encoding_dim
        self.epochs = epochs
        self.batch_size = batch_size
        self.verbose = verbose

    def fit(self, X, y=None):
        input_dim = X.shape[1]

        input_layer = Input(shape=(input_dim,))

        encoded = Dense(
            self.encoding_dim,
            activation="relu",
            activity_regularizer=regularizers.l1(1e-5)
        )(input_layer)

        decoded = Dense(input_dim, activation="linear")(encoded)

        self.autoencoder = Model(inputs=input_layer, outputs=decoded)
        self.encoder = Model(inputs=input_layer, outputs=encoded)

        self.autoencoder.compile(
            optimizer=Adam(learning_rate=0.001),
            loss="mse"
        )

        self.autoencoder.fit(
            X,
            X,
            epochs=self.epochs,
            batch_size=self.batch_size,
            shuffle=True,
            verbose=self.verbose
        )

        return self

    def transform(self, X):
        return self.encoder.predict(X, verbose=0)

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
import numpy as np
from sklearn.impute import SimpleImputer
def nested_cv_autoencoder(df, target, encoding_dims,
                          outer_splits=10, inner_splits=3):

    df = df.dropna(subset=[target])

    X = df.drop(columns=[target]).select_dtypes(include=["number"])
    y = df[target]

    outer_cv = StratifiedKFold(
        n_splits=outer_splits,
        shuffle=True,
        random_state=0
    )

    inner_cv = StratifiedKFold(
        n_splits=inner_splits,
        shuffle=True,
        random_state=1
    )

    results = []

    for fold_id, (train_idx, test_idx) in enumerate(outer_cv.split(X, y), start=1):

        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        best_dim = None
        best_score = -np.inf

        for dim in encoding_dims:
            inner_scores = []
            for inner_train_idx, inner_val_idx in inner_cv.split(X_train, y_train):

                X_tr = X_train.iloc[inner_train_idx]
                X_val = X_train.iloc[inner_val_idx]
                y_tr = y_train.iloc[inner_train_idx]
                y_val = y_train.iloc[inner_val_idx]

                pipeline = Pipeline([
                    ("imputer", SimpleImputer(strategy="median")),
                    ("scaler", MinMaxScaler()),
                    ("autoencoder", AutoencoderFeatureSelectorNew(
                        encoding_dim=dim,
                        epochs=30,
                        batch_size=32,
                        verbose=0
                    )),
                    ("model", RandomForestClassifier(
                        n_estimators=100,
                        max_depth=10,
                        random_state=5,
                        n_jobs=-1
                    ))
                ])

                pipeline.fit(X_tr, y_tr)

                y_pred = pipeline.predict_proba(X_val)[:, 1]
                inner_scores.append(roc_auc_score(y_val, y_pred))

            mean_score = np.mean(inner_scores)

            if mean_score > best_score:
                best_score = mean_score
                best_dim = dim

        final_pipeline = Pipeline([
            ("imputer", SimpleImputer(strategy="median")),
            ("scaler", MinMaxScaler()),
            ("autoencoder", AutoencoderFeatureSelectorNew(
                encoding_dim=best_dim,
                epochs=30,
                batch_size=32,
                verbose=0
            )),
            ("model", RandomForestClassifier(
                n_estimators=100,
                max_depth=10,
                random_state=5,
                n_jobs=-1
            ))
        ])

        final_pipeline.fit(X_train, y_train)

        y_pred = final_pipeline.predict_proba(X_test)[:, 1]
        outer_auc = roc_auc_score(y_test, y_pred)

        results.append({
            "fold": fold_id,
            "best_encoding_dim": best_dim,
            "inner_auc": best_score,
            "outer_auc": outer_auc
        })

    results = pd.DataFrame(results)

    print(results)
    print("Mean AUC:", results["outer_auc"].mean())
    print("STD AUC:", results["outer_auc"].std())

    return results

# %%
ae_results = nested_cv_autoencoder(df_clean_20, dependent1,
                                   encoding_dims=k,
                                   outer_splits=10, inner_splits=5)
# Out:
#    fold  best_encoding_dim  inner_auc  outer_auc
# 0     1                 35   0.849922   0.718668
# 1     2                 40   0.799374   0.929448
# 2     3                 40   0.836022   0.760736
# 3     4                 40   0.830898   0.738241
# 4     5                 40   0.817047   0.877301
# 5     6                 35   0.837263   0.793456
# 6     7                 35   0.801288   0.817996
# 7     8                 35   0.834031   0.791411
# 8     9                 30   0.826001   0.875661
# 9    10                 35   0.837110   0.768959
# Mean AUC: 0.8071877603574945
# STD AUC: 0.06775347679377203
